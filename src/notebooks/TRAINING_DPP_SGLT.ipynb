# %%
import pandas as pd
import numpy as np
import random
from matplotlib.pyplot import pie, axis, show
import seaborn as sns
import missingno as msno
from scipy import stats
import matplotlib.pyplot as plt
import yaml
import sys
import os

from sklearn.preprocessing import LabelEncoder, StandardScaler, MinMaxScaler
from sklearn.model_selection import train_test_split, KFold
from sklearn.feature_selection import RFE, SelectKBest, f_regression, mutual_info_regression
from sklearn.impute import SimpleImputer, KNNImputer
from sklearn import linear_model
from sklearn.neural_network import MLPRegressor
from sklearn.linear_model import Ridge
from sklearn.ensemble import RandomForestRegressor, VotingRegressor
import statsmodels.regression.linear_model as sm
from sklearn.gaussian_process import GaussianProcessRegressor as GPR
from sklearn.gaussian_process.kernels import DotProduct, WhiteKernel, CompoundKernel
import sklearn_relief as sr
from skrebate import ReliefF
from sklearn.ensemble import GradientBoostingRegressor
from catboost import CatBoostRegressor
from sklearn.linear_model import ElasticNet
import lightgbm as ltb
from sklearn.svm import SVR
from scipy.stats import ks_2samp
from tabulate import tabulate

from xgboost.sklearn import XGBRegressor
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import mean_squared_error, r2_score
from imblearn.over_sampling import RandomOverSampler
from collections import Counter
from imblearn.over_sampling import SMOTE, ADASYN
from imblearn.over_sampling import BorderlineSMOTE

from sklearn.multioutput import RegressorChain, MultiOutputRegressor
from sklearn.exceptions import DataConversionWarning

import tensorflow as tf
from tensorflow import keras
import warnings

sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '../../'))) 

from helper import preprocess, get_test_train_data, get_features_kbest, get_features_ref, get_features_ref_multiout,\
    get_features_relieff, get_model_name, cross_val, get_scores, outlier_detect, train_models, pred_all,\
    find_lowest_respponse_value, find_highest_respponse_value, find_closest_to_42, check_aggreement,\
    get_concordant_discordant, print_change_mean, get_perc, percentage_change_original_data, calculate_percentage_change,\
    calculate_percentage_change_othre_responses, calculate_count_diff, calculate_change_diff,\
    drug_class_outlier_remove, plot_scatter_with_CI, plot_scatter

from constants import TRAIN_PATH_WO_LDL_IMPUTATION, TEST_PATH_WO_LDL_IMPUTATION, COMMON_VARIABLE_PATH
warnings.filterwarnings('ignore')

# %matplotlib inline

is_train_with_all=False 

# Read common variables from a YAML file
with open('../'+COMMON_VARIABLE_PATH, 'r') as file:
    common_data = yaml.safe_load(file)
    
response_variable_list = common_data['response_variable_list']

correlated_variables = common_data['correlated_variables']

thresh = common_data['thresh']
keep = []
rem = []
# feature selection
items = ['drug_class']




if(is_train_with_all):
    sglt_val = 0.375
    dpp_val = 0.25
else:
    sglt_val = 1
    dpp_val = 0

 
    
def check_distribution(df, df_act, response_variable, predicted_change):
    
    # Find outliers using z-score
    z_scores_col1 = (df_act[response_variable] - np.mean(df_act[response_variable])) / np.std(df_act[response_variable])
    outliers_col1 = df_act[abs(z_scores_col1) > 3]
    outliers_act = outliers_col1.index.to_list()

    z_scores_col2 = (df[predicted_change] - np.mean(df[predicted_change])) / np.std(df[predicted_change])
    outliers_col2 = df[abs(z_scores_col2) > 3]
    outliers_pred = outliers_col2.index.to_list()
    return outliers_act, outliers_pred
    


def drug_class_visualization(df, df_act, response_variable, predicted_change, assigned_drug, baseline_val):
    # glp strata predicted by the model
    df_ = df[[response_variable, predicted_change, 'drug_class', assigned_drug, baseline_val]]
    # glp strata in real
    df_act_ = df_act[[response_variable
                      , predicted_change, 'drug_class', assigned_drug, baseline_val]]

    outliers_act, outliers_pred = check_distribution(df_, df_act_, response_variable, predicted_change)
    
    df_ = df_.drop(outliers_pred)
    df_act_ = df_act_.drop(outliers_act)
    return df_

def train_models(models, X_test, Y_test, X_train, Y_train, train,scaler,X_test_original):
    model_results = {}
    model_results_drugs = {}
    for model in models:
#         print('\n ------------- ' + str(get_model_name(model))+ ' ---------------')
        if str(get_model_name(model)) == 'Sequential':
            model.compile(optimizer='adam', loss='mean_squared_error')
            random.seed(42)
            model = cross_val(model, train, X_test, Y_test, X_train, Y_train, response_variable_list)
            random.seed(42)
            model.fit(X_train, Y_train, epochs=250, batch_size=16, verbose=0)
        else:
            random.seed(42)
            model = cross_val(model, train, X_test, Y_test, X_train, Y_train, response_variable_list)
            random.seed(42)
            model.fit(X_train, Y_train)
        data_pred, model_results, model_results_drugs, score = get_scores(model, X_test, Y_test, X_train, Y_train, model_results, model_results_drugs)

        
    X = X_test.copy()
    X_test_copy = X_test.copy()
    X_test_copy['assigned_drug_hba1c'] = np.nan
    X_test_copy['predicted_change_hba1c'] = np.nan
    X_test_copy['assigned_drug_ldl'] = np.nan
    X_test_copy['predicted_change_ldl'] = np.nan
    X_test_copy['assigned_drug_hdl'] = np.nan
    X_test_copy['predicted_change_hdl'] = np.nan
    X_test_copy['assigned_drug_bmi'] = np.nan
    X_test_copy['predicted_change_bmi'] = np.nan
    
    assigned_drug_class_list = [np.nan] * Y_train.shape[1]
    max_change_list = [np.nan] * Y_train.shape[1]
    
    for index, row in X.iterrows():
        drug_class = row['drug_class']

        pred_original = model.predict(row.values[None])[0]
        pred_sglt, pred_dpp = pred_all(model, row, drug_class) 

        for j in range(Y_train.shape[1]):
            if (Y_train.iloc[:,j].name == 'hdl_12m'):
                temp_max_change, temp_assigned_drug_class = find_highest_respponse_value(pred_sglt[j], pred_dpp[j])
            else:
                temp_max_change, temp_assigned_drug_class = find_lowest_respponse_value(pred_sglt[j], pred_dpp[j])
            
            max_change_list[j] = temp_max_change
            assigned_drug_class_list[j] = temp_assigned_drug_class
            
        X_test_copy.at[index, 'assigned_drug_hba1c'] = assigned_drug_class_list[0]
        X_test_copy.at[index, 'predicted_change_hba1c'] = max_change_list[0]

        X_test_copy.at[index, 'assigned_drug_ldl'] = assigned_drug_class_list[1]
        X_test_copy.at[index, 'predicted_change_ldl'] = max_change_list[1]

        X_test_copy.at[index, 'assigned_drug_hdl'] = assigned_drug_class_list[2]
        X_test_copy.at[index, 'predicted_change_hdl'] = max_change_list[2]

        X_test_copy.at[index, 'assigned_drug_bmi'] = assigned_drug_class_list[3]
        X_test_copy.at[index, 'predicted_change_bmi'] = max_change_list[3]
        
    denormalized_test_data = scaler.inverse_transform(X_test_original)
    denormalized_test_df = pd.DataFrame(denormalized_test_data, columns=X_test_original.columns)
    denormalized_test_df = denormalized_test_df.drop(['drug_class'], axis = 1)

    data = denormalized_test_df
    X_test_ = X_test_copy.copy()
    X_test_= X_test_.reset_index()
    Y_test_ = pd.DataFrame(Y_test)
    Y_test_ = Y_test_.reset_index()
    
    data[response_variable_list] = Y_test_[response_variable_list]
    data['assigned_drug_hba1c'] = X_test_['assigned_drug_hba1c']
    data['predicted_change_hba1c'] = X_test_['predicted_change_hba1c']
    data['assigned_drug_ldl'] = X_test_['assigned_drug_ldl']
    data['predicted_change_ldl'] = X_test_['predicted_change_ldl']
    data['assigned_drug_hdl'] = X_test_['assigned_drug_hdl']
    data['predicted_change_hdl'] = X_test_['predicted_change_hdl']
    data['assigned_drug_bmi'] = X_test_['assigned_drug_bmi']
    data['predicted_change_bmi'] = X_test_['predicted_change_bmi']
    data['drug_class'] = X_test_['drug_class']

    dpp_strata_hba1c = data[(data['assigned_drug_hba1c'] == dpp_val)]
    sglt_strata_hba1c = data[(data['assigned_drug_hba1c'] == sglt_val)] 

    dpp_strata_ldl = data[(data['assigned_drug_ldl'] == dpp_val)]
    sglt_strata_ldl = data[(data['assigned_drug_ldl'] == sglt_val)] 

    dpp_strata_hdl = data[(data['assigned_drug_hdl'] == dpp_val)]
    sglt_strata_hdl = data[(data['assigned_drug_hdl'] == sglt_val)] 

    dpp_strata_bmi = data[(data['assigned_drug_bmi'] == dpp_val)]
    sglt_strata_bmi = data[(data['assigned_drug_bmi'] == sglt_val)] 

    dpp_strata_actual = data[(data['drug_class'] == dpp_val)]
    sglt_strata_actual = data[(data['drug_class'] == sglt_val)]  
    
    dpp_df_hba1c = drug_class_visualization(dpp_strata_hba1c, dpp_strata_actual, 'hba1c_12m','predicted_change_hba1c', 'assigned_drug_hba1c', 'hba1c_bl_6m')
    sglt_df_hba1c = drug_class_visualization(sglt_strata_hba1c, sglt_strata_actual,'hba1c_12m',
                                            'predicted_change_hba1c', 'assigned_drug_hba1c', 'hba1c_bl_6m')
    
    dpp_df_ldl = drug_class_visualization(dpp_strata_ldl, dpp_strata_actual, 'ldl_12m',
                                         'predicted_change_ldl', 'assigned_drug_ldl', 'ldl')
    sglt_df_ldl = drug_class_visualization(sglt_strata_ldl, sglt_strata_actual, 'ldl_12m',
                                          'predicted_change_ldl', 'assigned_drug_ldl', 'ldl')
    
    dpp_df_hdl = drug_class_visualization(dpp_strata_hdl, dpp_strata_actual, 'hdl_12m',
                                         'predicted_change_hdl', 'assigned_drug_hdl', 'hdl')
    sglt_df_hdl = drug_class_visualization(sglt_strata_hdl, sglt_strata_actual, 'hdl_12m',
                                          'predicted_change_hdl', 'assigned_drug_hdl', 'hdl')
    
    dpp_df_bmi = drug_class_visualization(dpp_strata_bmi, dpp_strata_actual, 'bmi_12m',
                                         'predicted_change_bmi', 'assigned_drug_bmi', 'bmi')
    sglt_df_bmi = drug_class_visualization(sglt_strata_bmi, sglt_strata_actual, 'bmi_12m',
                                          'predicted_change_bmi', 'assigned_drug_bmi', 'bmi')

    
    (concordant_dpp_hba1c, discordant_dpp_sglt_hba1c,
    concordant_sglt_hba1c, discordant_sglt_dpp_hba1c ) = get_concordant_discordant(dpp_df_hba1c,sglt_df_hba1c, data,
                                                                                   dpp_strata_actual, sglt_strata_actual,
                                                                                  variable_name = 'assigned_drug_hba1c')
    (concordant_dpp_ldl, discordant_dpp_sglt_ldl,
    concordant_sglt_ldl, discordant_sglt_dpp_ldl ) = get_concordant_discordant(dpp_df_ldl,sglt_df_ldl, data,
                                                                                   dpp_strata_actual, sglt_strata_actual,
                                                                                  variable_name = 'assigned_drug_ldl')
    (concordant_dpp_hdl, discordant_dpp_sglt_hdl,
    concordant_sglt_hdl, discordant_sglt_dpp_hdl ) = get_concordant_discordant(dpp_df_hdl,sglt_df_hdl, data,
                                                                                   dpp_strata_actual, sglt_strata_actual,
                                                                                  variable_name = 'assigned_drug_hdl')
    (concordant_dpp_bmi, discordant_dpp_sglt_bmi,
    concordant_sglt_bmi, discordant_sglt_dpp_bmi ) = get_concordant_discordant(dpp_df_bmi,sglt_df_bmi, data,
                                                                                   dpp_strata_actual, sglt_strata_actual,
                                                                                  variable_name = 'assigned_drug_bmi')


    print('\n -------- Percentage HBA1C  ---------')
    calculate_percentage_change(concordant_dpp_hba1c, discordant_dpp_sglt_hba1c,
                concordant_sglt_hba1c, discordant_sglt_dpp_hba1c, response_variable = 'hba1c_12m', baseline_val='hba1c_bl_6m')
    
    print('\n -------- Percentage LDL  ---------')
    calculate_percentage_change(concordant_dpp_ldl, discordant_dpp_sglt_ldl,
                concordant_sglt_ldl, discordant_sglt_dpp_ldl, response_variable = 'ldl_12m', baseline_val='ldl')
    
    print('\n -------- Percentage HDL  ---------')
    calculate_percentage_change(concordant_dpp_hdl, discordant_dpp_sglt_hdl,
                concordant_sglt_hdl, discordant_sglt_dpp_hdl, response_variable = 'hdl_12m', baseline_val='hdl')
    
    print('\n -------- Percentage BMI  ---------')
    calculate_percentage_change(concordant_dpp_bmi, discordant_dpp_sglt_bmi,
                concordant_sglt_bmi, discordant_sglt_dpp_bmi, response_variable = 'bmi_12m', baseline_val='bmi')
    
    
    return model_results

#         if hasattr(model, 'feature_importances_'):
#             feat_importances = pd.Series(model.feature_importances_, index=X_train.columns)
#             feat_importances.nlargest(20).plot(kind='barh')
#             plt.show()
#         elif hasattr(model, 'coef_'):
#             coef_importances = pd.Series(abs(model.coef_), index=X_train.columns)
#             top_20_features = coef_importances.nlargest(20)
#             top_20_features.plot(kind='barh')
#             plt.show()

# %%
def run(algo, i, feats_hc = []):
    df_X_train = pd.read_csv('../../'+TRAIN_PATH_WO_LDL_IMPUTATION, sep = ',',decimal = '.', encoding = 'utf-8', engine ='python',index_col=0)
    df_X_test = pd.read_csv('../../'+TEST_PATH_WO_LDL_IMPUTATION, sep = ',',decimal = '.', encoding = 'utf-8', engine ='python',index_col=0)

    X_train_ = preprocess(df_X_train, response_variable_list)
    X_test_ = preprocess(df_X_test, response_variable_list)
    df, X_train, X_test, Y_train, Y_test, X, Y, scaler, X_test_before_scale = get_test_train_data(X_train_, X_test_, response_variable_list)

    # # train with whole dataset and test with drug class 2,3 and 4 data
    if(is_train_with_all):
        combined_df = pd.concat([X_test, Y_test], axis=1)
        testdf = combined_df[ 
                             (combined_df['drug_class'] == 0.25) | 
                             (combined_df['drug_class'] == 0.375) ]
        X_test = testdf.drop([response_variable_list], axis = 1)
        Y_test = testdf[response_variable_list]

    X_test_original = X_test.copy()

    if(is_train_with_all):
        sglt_val = 0.375
        dpp_val = 0.25
    else:
        sglt_val = 1
        dpp_val = 0


    X_test_ = pd.DataFrame(X_test)
    X_train_ = pd.DataFrame(X_train)

    X_train = X_train.drop(['init_year'], axis = 1)
    X_test = X_test.drop(['init_year'], axis = 1)

    selected_features = []
    
    random.seed(42) 
    if algo == 'kbest':
        for j in range(Y_train.shape[1]):  # Assuming Y.shape[1] is the number of target features
            feats = get_features_kbest(X_train, Y_train.iloc[:, j],i)
            selected_features.append(feats)
    elif algo == 'relieff':
        selected_features.append(feats_hc)
        #for j in range(Y_train.shape[1]):  # Assuming Y.shape[1] is the number of target features
            #feats = get_features_relieff(X_train, Y_train.iloc[:, j],i)
            #selected_features.append(feats)
    elif algo == 'refMulti':
        selected_list = feats_hc
        #selected_list = get_features_ref_multiout(X_train, Y_train, i)
    elif algo=='ref':
        selected_features.append(feats_hc)
        #for j in range(Y_train.shape[1]):  # Assuming Y.shape[1] is the number of target features
            #feats = get_features_ref(X_train, Y_train.iloc[:, j],i)
            #selected_features.append(feats)

    if algo != 'refMulti':
        selected_list = sum(selected_features, [])
    
    for item in items:
        if item not in selected_list:
            selected_list.extend([item])

    # remove duplicate
    selected_list = np.unique(selected_list)
    number_of_features = len(selected_list)
    print('\n\n')
    print(selected_list.tolist())
    X_train_selected = X_train[selected_list]
    X_test_selected = X_test[selected_list]

    ################# OUTLIER CODE ################
    print('Shape of training data before removing outliers:', np.shape(X_train_selected))
    print('Shape of test data before removing outliers:', np.shape(X_test_selected))
    
    out_train, out_test = outlier_detect(X_train_selected, Y_train, X_test_selected, Y_test)
    
    train_ = X_train_selected.copy()
    train_[response_variable_list] = Y_train.values
    
    test_ = X_test_selected.copy()
    test_[response_variable_list] = Y_test.values
    
    train_ = pd.DataFrame(train_.drop(out_train, axis = 0))
    test_ = pd.DataFrame(test_.drop(out_test, axis = 0))
    
    Y_train = train_[response_variable_list]
    X_train_selected = train_.drop(response_variable_list, axis=1)
    
    Y_test = test_[response_variable_list]
    X_test_selected = test_.drop(response_variable_list, axis=1)
    
    print('Shape of training data after removing outliers:', np.shape(X_train_selected))
    print('Shape of test data after removing outliers:', np.shape(X_test_selected))

    X_test_before_scale = pd.DataFrame(X_test_before_scale.drop(out_test, axis = 0)) 
    X_test_original = pd.DataFrame(X_test_original.drop(out_test, axis = 0)) 

    ################
    
    train = X_train_selected.copy()
    train[response_variable_list] = Y_train.values

    xgb = XGBRegressor(
    #n_estimators=100, 
    #eta=0.01, 
    #subsample=0.5, 
    #colsample_bytree=0.8,
    #alpha=0.1,
    #max_depth = 5,
    #max_leaves = 6,
    #learning_rate =0.01
)

    lr = linear_model.LinearRegression(n_jobs = 10)

    kernel = DotProduct()# + WhiteKernel()

    gpr = GPR(kernel, alpha=1e-10, random_state=123)

    rfr = RandomForestRegressor(n_estimators=150, max_depth=10, random_state=123)

    ridge = Ridge(alpha=0.001)

    mlpr = MLPRegressor(random_state=123, 
                         max_iter=2000,
                    hidden_layer_sizes = (128),
                    learning_rate= 'adaptive'
                        )

    gbr = GradientBoostingRegressor(random_state=0)

    catboost = CatBoostRegressor(iterations=40,
                          learning_rate=0.1,
                          depth=6, verbose = 0)

    ltbr = ltb.LGBMRegressor(max_depth = 6, learning_rate = 0.1, verbose = -1, verbose_eval = False)


#    nn = keras.Sequential([
#     keras.layers.Dense(100, activation='relu', input_shape=(number_of_features,)),  # Adjust input shape
# #     keras.layers.Dense(250, activation='relu'),  # Additional hidden layer with 150 neurons
# #     keras.layers.Dropout(0.5),  # Dropout layer for regularization
# #     keras.layers.Dense(100, activation='relu'),  # Another hidden layer with 100 neurons
#     keras.layers.Dense(50, activation='relu'),  # Yet another hidden layer with 50 neurons
#     keras.layers.Dense(25, activation='relu'),  # Additional hidden layer with 25 neurons
#     keras.layers.Dense(1)  # Output layer with a single neuron for regression
#     ])

    nn = keras.Sequential([
    keras.layers.Dense(64, activation='relu', input_shape=(number_of_features,)),  # Adjust input shape
    keras.layers.Dense(32, activation='relu'),  # Additional hidden layer
#     keras.layers.Dense(64, activation='relu'),  # Another hidden layer
#     keras.layers.Dense(32, activation='relu'),  # Yet another hidden layer
    keras.layers.Dense(4)  # Output layer with a single neuron for regression
])
    random.seed(42)
    #wrapper = MultiOutputRegressor(catboost)
    vr = VotingRegressor([ ('catboost', catboost), ('ltbr', ltbr), ('rfr', rfr), ])
    
# tried combinations for vr 
# rfr + ltbr + cat + xgb
# rfr + ltbr
# rfr + cat
# ltbr + cat
# rfr + ltbr + cat

    wrapper = RegressorChain(vr, order=[0,1,2,3])
    

    models = [wrapper] 
    random.seed(42) 
    model_results = train_models(models, X_test_selected, Y_test, X_train_selected, Y_train, train, scaler, X_test_original)
    return model_results

# %%
feature_size  = [2,3,4,5,6,7,8,9,10]
warnings.filterwarnings('ignore')
for i in feature_size:
    print('\n\n\n===============  ', i ,' features ','   ===================\n',)
    model_results = run('kbest', i)
    table = []
    for model, score in model_results.items():
        table.append([model, score])

    table_str = tabulate(table, headers=['Model', 'Test R2 Score'], tablefmt='grid')
    print(table_str)
        
    print('\n\n\n')
# Out:
# ===============   2  features     ===================
#
# Shape of data after excluding missing response: (1566, 125)
# Shape of full data after selecting date range dates > 21 days (1084, 125)
# Shape of data after excluding missing response: (156, 125)
# Shape of full data after selecting date range dates > 21 days (102, 125)
# X_train shape after imputation:  (1077, 107)
#
#  Shape of the data after oversampling
# {3.0, 4.0}
# [(3.0, 440), (4.0, 637)]
# [(3.0, 637), (4.0, 637)]
#
#
#
# ['bmi', 'drug_class', 'hba1c_bl_18m', 'hba1c_bl_6m', 'hdl', 'ldl', 'obese', 'trigly']
# Shape of training data before removing outliers: (1274, 8)
# Shape of test data before removing outliers: (101, 8)
# Training set outliers: [640, 834, 238, 1060, 448, 640, 834, 923, 952, 966, 1066, 565, 640, 778, 834]
# Testing set outliers: []
# Shape of training data after removing outliers: (1263, 8)
# Shape of test data after removing outliers: (101, 8)
# Cross validation variance 0.0016256645483346528
# Cross validation mean score 0.6156694474031493
# R2 score Training : 0.7950530047135204
# R2 score Testing: 0.4269
# RMSE: 5.818566
#  =========== Total number of samples assigned by the model VS Total number of samples in original test data
# DPP samples  40 49
# SGLT samples  61 52
#
#
# Category    Real value    Predicted value    Count    Percentage of Predicted cases
# ----------  ------------  -----------------  -------  -------------------------------
# Concordant  SGLT          SGLT               33       54.10%
# Discordant  DPP           SGLT               28       47.50%
#
# Concordant  DPP           DPP                21       52.50%
# Discordant  SGLT          DPP                19       45.90%
#
#
#  =========== Total number of samples assigned by the model VS Total number of samples in original test data
# DPP samples  26 49
# SGLT samples  75 52
#
#
# Category    Real value    Predicted value    Count    Percentage of Predicted cases
# ----------  ------------  -----------------  -------  -------------------------------
# Concordant  SGLT          SGLT               40       53.33%
# Discordant  DPP           SGLT               35       46.15%
#
# Concordant  DPP           DPP                14       53.85%
# Discordant  SGLT          DPP                12       46.67%
#
#
#  =========== Total number of samples assigned by the model VS Total number of samples in original test data
# DPP samples  73 49
# SGLT samples  26 52
#
#
# Category    Real value    Predicted value    Count    Percentage of Predicted cases
# ----------  ------------  -----------------  -------  -------------------------------
# Concordant  SGLT          SGLT               11       42.31%
# Discordant  DPP           SGLT               15       54.79%
#
# Concordant  DPP           DPP                33       45.21%
# Discordant  SGLT          DPP                40       57.69%
#
#
#  =========== Total number of samples assigned by the model VS Total number of samples in original test data
# DPP samples  5 49
# SGLT samples  96 52
#
#
# Category    Real value    Predicted value    Count    Percentage of Predicted cases
# ----------  ------------  -----------------  -------  -------------------------------
# Concordant  SGLT          SGLT               48       50.00%
# Discordant  DPP           SGLT               48       80.00%
#
# Concordant  DPP           DPP                1        20.00%
# Discordant  SGLT          DPP                4        50.00%
#
#
#
#  -------- Percentage HBA1C  ---------
# Category    Real value    Predicted value    Mean Change from Baseline    std    treatment difference
# ----------  ------------  -----------------  ---------------------------  -----  ----------------------
# Concordant  SGLT          SGLT               -12.61                       15.10  -8.61
# Discordant  DPP           SGLT               -4.00                        11.76
#
# Concordant  DPP           DPP                -4.24                        16.10  -0.29
# Discordant  SGLT          DPP                -3.95                        13.49
#
#  -------- Percentage LDL  ---------
# Category    Real value    Predicted value    Mean Change from Baseline    std    treatment difference
# ----------  ------------  -----------------  ---------------------------  -----  ----------------------
# Concordant  SGLT          SGLT               -0.32                        0.92   -0.10
# Discordant  DPP           SGLT               -0.22                        0.77
#
# Concordant  DPP           DPP                -0.01                        0.74   0.12
# Discordant  SGLT          DPP                -0.13                        0.66
#
#  -------- Percentage HDL  ---------
# Category    Real value    Predicted value    Mean Change from Baseline    std    treatment difference
# ----------  ------------  -----------------  ---------------------------  -----  ----------------------
# Concordant  SGLT          SGLT               -0.07                        0.32   -0.12
# Discordant  DPP           SGLT               0.05                         0.18
#
# Concordant  DPP           DPP                0.01                         0.26   -0.03
# Discordant  SGLT          DPP                0.03                         0.19
#
#  -------- Percentage BMI  ---------
# Category    Real value    Predicted value    Mean Change from Baseline    std    treatment difference
# ----------  ------------  -----------------  ---------------------------  -----  ----------------------
# Concordant  SGLT          SGLT               -1.20                        2.85   -1.43
# Discordant  DPP           SGLT               0.22                         2.76
#
# Concordant  DPP           DPP                -0.00                        nan    2.05
# Discordant  SGLT          DPP                -2.05                        1.27
# +----------------+-----------------+
# | Model          |   Test R2 Score |
# +================+=================+
# | RegressorChain |        0.426867 |
# +----------------+-----------------+
#
#
#
#
#
#
#
# ===============   3  features     ===================
#
# Shape of data after excluding missing response: (1566, 125)
# Shape of full data after selecting date range dates > 21 days (1084, 125)
# Shape of data after excluding missing response: (156, 125)
# Shape of full data after selecting date range dates > 21 days (102, 125)
# X_train shape after imputation:  (1077, 107)
#
#  Shape of the data after oversampling
# {3.0, 4.0}
# [(3.0, 440), (4.0, 637)]
# [(3.0, 637), (4.0, 637)]
#
#
#
# ['bmi', 'drug_class', 'eGFR', 'hba1c_bl_18m', 'hba1c_bl_6m', 'hdl', 'ldl', 'obese', 'trigly']
# Shape of training data before removing outliers: (1274, 9)
# Shape of test data before removing outliers: (101, 9)
# Training set outliers: [358, 640, 238, 1060, 448, 834, 923, 952, 778, 834]
# Testing set outliers: []
# Shape of training data after removing outliers: (1265, 9)
# Shape of test data after removing outliers: (101, 9)
# KeyboardInterrupt

# %%
feature_size  = [2,3,4,5,7,9]


feats = [
    ['bmi', 'cvd_comp', 'drug_class', 'hba1c_bl_6m', 'hdl', 'insulin', 'ldl', 'obese', 'sp'],
    ['bmi', 'comb_comp_enn', 'cvd_comp', 'drug_class', 'eGFR', 'hba1c_bl_18m', 'hba1c_bl_6m', 'hdl', 'insulin', 'ldl', 'obese', 'sp', 'sum_diab_drugs'],
    ['bmi', 'comb_comp_enn', 'concordant_dis', 'cvd_comp', 'drug_class', 'eGFR', 'hba1c_bl_18m', 'hba1c_bl_6m', 'hdl', 'ika', 'insulin', 'ldl', 'obese', 'sp', 'sum_diab_drugs', 'trigly'],
    ['MD_RCT_mmol_mol', 'bmi', 'comb_comp_enn', 'concordant_dis', 'cvd_comp', 'drug_class', 'eGFR', 'hba1c_bl_18m', 'hba1c_bl_6m', 'hdl', 'ika', 'insulin', 'ldl', 'obese', 'sp', 'sum_diab_drugs', 't2d_dur_y', 'trigly'],
    ['MD_RCT_mmol_mol', 'bmi', 'chd', 'comb_comp_enn', 'concordant_dis', 'cvd_comp', 'drug_class', 'eGFR', 'hba1c_bl_18m', 'hba1c_bl_6m', 'hdl', 'hyperten', 'ika', 'insulin', 'ldl', 'obese', 'sp', 'sum_diab_drugs', 't2d_dur_y', 'trigly'],
    ['MD_RCT_mmol_mol', 'bmi', 'chd', 'comb_comp_enn', 'concordant_dis', 'cvd_comp', 'dg406', 'drug_class', 'eGFR', 'hba1c_bl_18m', 'hba1c_bl_6m', 'hdl', 'hyperten', 'ika', 'insulin', 'ldl', 'obese', 'sp', 'sum_diab_drugs', 't2d_dur_y', 'trigly'],
    
    ]
warnings.filterwarnings('ignore')
for i, val in enumerate(feature_size):
    print('\n\n\n===============  ', val ,' features ','   ===================\n',)
    model_results = run('relieff', val, feats[i])
    table = []
    for model, score in model_results.items():
        table.append([model, score])

    table_str = tabulate(table, headers=['Model', 'Test R2 Score'], tablefmt='grid')
    print(table_str)
        
    print('\n\n\n')
# Out:
# ===============   2  features     ===================
#
# Shape of data after excluding missing response: (1566, 125)
# Shape of full data after selecting date range dates > 21 days (1084, 115)
# Shape of data after excluding missing response: (156, 125)
# Shape of full data after selecting date range dates > 21 days (102, 115)
# X_train shape:  (1077, 107)
# (1077, 107)
# {3.0, 4.0}
# [(3.0, 440), (4.0, 637)]
# [(3.0, 637), (4.0, 637)]
#
#
#
# ['bmi', 'cvd_comp', 'drug_class', 'hba1c_bl_6m', 'hdl', 'insulin', 'ldl', 'obese', 'sp']
# Shape of training data before removing outliers: (1274, 9)
# Shape of test data before removing outliers: (101, 9)
# Training set outliers: [1060, 448, 834, 923, 952, 1066, 565, 670, 778, 834, 1058, 1111]
# Testing set outliers: []
# Shape of training data after removing outliers: (1263, 9)
# Shape of test data after removing outliers: (101, 9)
# Cross validation variance 0.0006533138749707186
# Cross validation mean score 0.6058475391060799
# R2 score Training : 0.7904531788928693
# R2 score Testing: 0.4683
# RMSE: 5.349908
#  =========== Total number of samples assigned by the model VS Total number of samples in original test data
# DPP samples  42 49
# SGLT samples  58 52
#
#
# Category    Real value    Predicted value    Count    Percentage of Predicted cases
# ----------  ------------  -----------------  -------  -------------------------------
# Concordant  SGLT          SGLT               32       55.17%
# Discordant  DPP           SGLT               26       47.62%
#
# Concordant  DPP           DPP                22       52.38%
# Discordant  SGLT          DPP                20       44.83%
#
#
#  =========== Total number of samples assigned by the model VS Total number of samples in original test data
# DPP samples  36 49
# SGLT samples  65 52
#
#
# Category    Real value    Predicted value    Count    Percentage of Predicted cases
# ----------  ------------  -----------------  -------  -------------------------------
# Concordant  SGLT          SGLT               38       58.46%
# Discordant  DPP           SGLT               27       38.89%
#
# Concordant  DPP           DPP                22       61.11%
# Discordant  SGLT          DPP                14       41.54%
#
#
#  =========== Total number of samples assigned by the model VS Total number of samples in original test data
# DPP samples  63 49
# SGLT samples  36 52
#
#
# Category    Real value    Predicted value    Count    Percentage of Predicted cases
# ----------  ------------  -----------------  -------  -------------------------------
# Concordant  SGLT          SGLT               15       41.67%
# Discordant  DPP           SGLT               21       55.56%
#
# Concordant  DPP           DPP                28       44.44%
# Discordant  SGLT          DPP                35       58.33%
#
#
#  =========== Total number of samples assigned by the model VS Total number of samples in original test data
# DPP samples  18 49
# SGLT samples  83 52
#
#
# Category    Real value    Predicted value    Count    Percentage of Predicted cases
# ----------  ------------  -----------------  -------  -------------------------------
# Concordant  SGLT          SGLT               45       54.22%
# Discordant  DPP           SGLT               38       38.89%
#
# Concordant  DPP           DPP                11       61.11%
# Discordant  SGLT          DPP                7        45.78%
#
#
#
#  -------- Percentage HBA1C  ---------
# Category    Real value    Predicted value    Mean % Change from Baseline    std     treatment difference
# ----------  ------------  -----------------  -----------------------------  ------  ----------------------
# Concordant  SGLT          SGLT               -10.69%                        11.63%  -6.88%
# Discordant  DPP           SGLT               -3.81%                         12.25%
#
# Concordant  DPP           DPP                -5.18%                         15.24%  2.27
# Discordant  SGLT          DPP                -7.45%                         19.41%
#
#  -------- Percentage LDL  ---------
# Category    Real value    Predicted value    Mean % Change from Baseline    std    treatment difference
# ----------  ------------  -----------------  -----------------------------  -----  ----------------------
# Concordant  SGLT          SGLT               -0.27%                         0.92%  -0.05%
# Discordant  DPP           SGLT               -0.22%                         0.87%
#
# Concordant  DPP           DPP                -0.09%                         0.62%  0.20
# Discordant  SGLT          DPP                -0.29%                         0.72%
#
#  -------- Percentage HDL  ---------
# Category    Real value    Predicted value    Mean % Change from Baseline    std    treatment difference
# ----------  ------------  -----------------  -----------------------------  -----  ----------------------
# Concordant  SGLT          SGLT               -0.02%                         0.21%  -0.06%
# Discordant  DPP           SGLT               0.04%                          0.22%
#
# Concordant  DPP           DPP                -0.02%                         0.29%  -0.07
# Discordant  SGLT          DPP                0.05%                          0.17%
#
#  -------- Percentage BMI  ---------
# Category    Real value    Predicted value    Mean % Change from Baseline    std    treatment difference
# ----------  ------------  -----------------  -----------------------------  -----  ----------------------
# Concordant  SGLT          SGLT               -1.45%                         2.40%  -1.33%
# Discordant  DPP           SGLT               -0.12%                         2.60%
#
# Concordant  DPP           DPP                1.41%                          2.97%  1.49
# Discordant  SGLT          DPP                -0.09%                         4.54%
# +----------------+-----------------+
# | Model          |   Test R2 Score |
# +================+=================+
# | RegressorChain |        0.468331 |
# +----------------+-----------------+
#
#
#
#
#
#
#
# ===============   3  features     ===================
#
# Shape of data after excluding missing response: (1566, 125)
# Shape of full data after selecting date range dates > 21 days (1084, 115)
# Shape of data after excluding missing response: (156, 125)
# Shape of full data after selecting date range dates > 21 days (102, 115)
# X_train shape:  (1077, 107)
# (1077, 107)
# {3.0, 4.0}
# [(3.0, 440), (4.0, 637)]
# [(3.0, 637), (4.0, 637)]
#
#
#
# ['bmi', 'comb_comp_enn', 'cvd_comp', 'drug_class', 'eGFR', 'hba1c_bl_18m', 'hba1c_bl_6m', 'hdl', 'insulin', 'ldl', 'obese', 'sp', 'sum_diab_drugs']
# Shape of training data before removing outliers: (1274, 13)
# Shape of test data before removing outliers: (101, 13)
# Training set outliers: [358, 238, 1060, 448, 826, 834, 923, 952, 1066, 565, 778, 834, 1058, 1111]
# Testing set outliers: []
# Shape of training data after removing outliers: (1261, 13)
# Shape of test data after removing outliers: (101, 13)
# Cross validation variance 0.0007934238886585859
# Cross validation mean score 0.6199373902379722
# R2 score Training : 0.8181011532075322
# R2 score Testing: 0.4656
# RMSE: 5.445907
#  =========== Total number of samples assigned by the model VS Total number of samples in original test data
# DPP samples  39 49
# SGLT samples  62 52
#
#
# Category    Real value    Predicted value    Count    Percentage of Predicted cases
# ----------  ------------  -----------------  -------  -------------------------------
# Concordant  SGLT          SGLT               32       51.61%
# Discordant  DPP           SGLT               30       51.28%
#
# Concordant  DPP           DPP                19       48.72%
# Discordant  SGLT          DPP                20       48.39%
#
#
#  =========== Total number of samples assigned by the model VS Total number of samples in original test data
# DPP samples  24 49
# SGLT samples  77 52
#
#
# Category    Real value    Predicted value    Count    Percentage of Predicted cases
# ----------  ------------  -----------------  -------  -------------------------------
# Concordant  SGLT          SGLT               36       46.75%
# Discordant  DPP           SGLT               41       66.67%
#
# Concordant  DPP           DPP                8        33.33%
# Discordant  SGLT          DPP                16       53.25%
#
#
#  =========== Total number of samples assigned by the model VS Total number of samples in original test data
# DPP samples  82 49
# SGLT samples  19 52
#
#
# Category    Real value    Predicted value    Count    Percentage of Predicted cases
# ----------  ------------  -----------------  -------  -------------------------------
# Concordant  SGLT          SGLT               9        47.37%
# Discordant  DPP           SGLT               10       52.44%
#
# Concordant  DPP           DPP                39       47.56%
# Discordant  SGLT          DPP                43       52.63%
#
#
#  =========== Total number of samples assigned by the model VS Total number of samples in original test data
# DPP samples  6 49
# SGLT samples  95 52
#
#
# Category    Real value    Predicted value    Count    Percentage of Predicted cases
# ----------  ------------  -----------------  -------  -------------------------------
# Concordant  SGLT          SGLT               50       52.63%
# Discordant  DPP           SGLT               45       33.33%
#
# Concordant  DPP           DPP                4        66.67%
# Discordant  SGLT          DPP                2        47.37%
#
#
#
#  -------- Percentage HBA1C  ---------
# Category    Real value    Predicted value    Mean % Change from Baseline    std     treatment difference
# ----------  ------------  -----------------  -----------------------------  ------  ----------------------
# Concordant  SGLT          SGLT               -11.25%                        15.63%  -9.02%
# Discordant  DPP           SGLT               -2.23%                         10.77%
#
# Concordant  DPP           DPP                -7.05%                         17.13%  -0.50
# Discordant  SGLT          DPP                -6.55%                         13.82%
#
#  -------- Percentage LDL  ---------
# Category    Real value    Predicted value    Mean % Change from Baseline    std    treatment difference
# ----------  ------------  -----------------  -----------------------------  -----  ----------------------
# Concordant  SGLT          SGLT               -0.29%                         0.87%  -0.06%
# Discordant  DPP           SGLT               -0.22%                         0.78%
#
# Concordant  DPP           DPP                0.16%                          0.64%  0.41
# Discordant  SGLT          DPP                -0.25%                         0.86%
#
#  -------- Percentage HDL  ---------
# Category    Real value    Predicted value    Mean % Change from Baseline    std    treatment difference
# ----------  ------------  -----------------  -----------------------------  -----  ----------------------
# Concordant  SGLT          SGLT               0.10%                          0.14%  0.08%
# Discordant  DPP           SGLT               0.02%                          0.16%
#
# Concordant  DPP           DPP                -0.00%                         0.28%  0.01
# Discordant  SGLT          DPP                -0.01%                         0.23%
#
#  -------- Percentage BMI  ---------
# Category    Real value    Predicted value    Mean % Change from Baseline    std    treatment difference
# ----------  ------------  -----------------  -----------------------------  -----  ----------------------
# Concordant  SGLT          SGLT               -1.20%                         2.79%  -1.32%
# Discordant  DPP           SGLT               0.12%                          2.82%
#
# Concordant  DPP           DPP                1.34%                          0.99%  4.34
# Discordant  SGLT          DPP                -3.00%                         0.65%
# +----------------+-----------------+
# | Model          |   Test R2 Score |
# +================+=================+
# | RegressorChain |        0.465618 |
# +----------------+-----------------+
#
#
#
#
#
#
#
# ===============   4  features     ===================
#
# Shape of data after excluding missing response: (1566, 125)
# Shape of full data after selecting date range dates > 21 days (1084, 115)
# Shape of data after excluding missing response: (156, 125)
# Shape of full data after selecting date range dates > 21 days (102, 115)
# X_train shape:  (1077, 107)
# (1077, 107)
# {3.0, 4.0}
# [(3.0, 440), (4.0, 637)]
# [(3.0, 637), (4.0, 637)]
#
#
#
# ['bmi', 'comb_comp_enn', 'concordant_dis', 'cvd_comp', 'drug_class', 'eGFR', 'hba1c_bl_18m', 'hba1c_bl_6m', 'hdl', 'ika', 'insulin', 'ldl', 'obese', 'sp', 'sum_diab_drugs', 'trigly']
# Shape of training data before removing outliers: (1274, 16)
# Shape of test data before removing outliers: (101, 16)
# Training set outliers: [340, 521, 640, 762, 972, 238, 252, 1060, 69, 826, 923, 952, 1066, 145, 363, 565, 1058, 1111]
# Testing set outliers: []
# Shape of training data after removing outliers: (1256, 16)
# Shape of test data after removing outliers: (101, 16)
# Cross validation variance 0.0002939518635962457
# Cross validation mean score 0.6298473176744157
# R2 score Training : 0.8320642739037185
# R2 score Testing: 0.4651
# RMSE: 5.499023
#  =========== Total number of samples assigned by the model VS Total number of samples in original test data
# DPP samples  40 49
# SGLT samples  61 52
#
#
# Category    Real value    Predicted value    Count    Percentage of Predicted cases
# ----------  ------------  -----------------  -------  -------------------------------
# Concordant  SGLT          SGLT               32       52.46%
# Discordant  DPP           SGLT               29       50.00%
#
# Concordant  DPP           DPP                20       50.00%
# Discordant  SGLT          DPP                20       47.54%
#
#
#  =========== Total number of samples assigned by the model VS Total number of samples in original test data
# DPP samples  25 49
# SGLT samples  76 52
#
#
# Category    Real value    Predicted value    Count    Percentage of Predicted cases
# ----------  ------------  -----------------  -------  -------------------------------
# Concordant  SGLT          SGLT               37       48.68%
# Discordant  DPP           SGLT               39       60.00%
#
# Concordant  DPP           DPP                10       40.00%
# Discordant  SGLT          DPP                15       51.32%
#
#
#  =========== Total number of samples assigned by the model VS Total number of samples in original test data
# DPP samples  66 49
# SGLT samples  34 52
#
#
# Category    Real value    Predicted value    Count    Percentage of Predicted cases
# ----------  ------------  -----------------  -------  -------------------------------
# Concordant  SGLT          SGLT               15       44.12%
# Discordant  DPP           SGLT               19       54.55%
#
# Concordant  DPP           DPP                30       45.45%
# Discordant  SGLT          DPP                36       55.88%
#
#
#  =========== Total number of samples assigned by the model VS Total number of samples in original test data
# DPP samples  6 49
# SGLT samples  95 52
#
#
# Category    Real value    Predicted value    Count    Percentage of Predicted cases
# ----------  ------------  -----------------  -------  -------------------------------
# Concordant  SGLT          SGLT               49       51.58%
# Discordant  DPP           SGLT               46       50.00%
#
# Concordant  DPP           DPP                3        50.00%
# Discordant  SGLT          DPP                3        48.42%
#
#
#
#  -------- Percentage HBA1C  ---------
# Category    Real value    Predicted value    Mean % Change from Baseline    std     treatment difference
# ----------  ------------  -----------------  -----------------------------  ------  ----------------------
# Concordant  SGLT          SGLT               -9.59%                         12.34%  -6.42%
# Discordant  DPP           SGLT               -3.17%                         12.27%
#
# Concordant  DPP           DPP                -5.45%                         15.63%  3.75
# Discordant  SGLT          DPP                -9.20%                         18.85%
#
#  -------- Percentage LDL  ---------
# Category    Real value    Predicted value    Mean % Change from Baseline    std    treatment difference
# ----------  ------------  -----------------  -----------------------------  -----  ----------------------
# Concordant  SGLT          SGLT               -0.42%                         0.88%  -0.21%
# Discordant  DPP           SGLT               -0.21%                         0.82%
#
# Concordant  DPP           DPP                0.03%                          0.48%  -0.04
# Discordant  SGLT          DPP                0.07%                          0.72%
#
#  -------- Percentage HDL  ---------
# Category    Real value    Predicted value    Mean % Change from Baseline    std    treatment difference
# ----------  ------------  -----------------  -----------------------------  -----  ----------------------
# Concordant  SGLT          SGLT               0.07%                          0.13%  0.06%
# Discordant  DPP           SGLT               0.01%                          0.21%
#
# Concordant  DPP           DPP                -0.00%                         0.29%  0.01
# Discordant  SGLT          DPP                -0.01%                         0.25%
#
#  -------- Percentage BMI  ---------
# Category    Real value    Predicted value    Mean % Change from Baseline    std    treatment difference
# ----------  ------------  -----------------  -----------------------------  -----  ----------------------
# Concordant  SGLT          SGLT               -1.41%                         2.30%  -1.54%
# Discordant  DPP           SGLT               0.13%                          2.79%
#
# Concordant  DPP           DPP                1.60%                          1.04%  0.51
# Discordant  SGLT          DPP                1.10%                          7.64%
# +----------------+-----------------+
# | Model          |   Test R2 Score |
# +================+=================+
# | RegressorChain |        0.465109 |
# +----------------+-----------------+
#
#
#
#
#
#
#
# ===============   5  features     ===================
#
# Shape of data after excluding missing response: (1566, 125)
# Shape of full data after selecting date range dates > 21 days (1084, 115)
# Shape of data after excluding missing response: (156, 125)
# Shape of full data after selecting date range dates > 21 days (102, 115)
# X_train shape:  (1077, 107)
# (1077, 107)
# {3.0, 4.0}
# [(3.0, 440), (4.0, 637)]
# [(3.0, 637), (4.0, 637)]
#
#
#
# ['MD_RCT_mmol_mol', 'bmi', 'comb_comp_enn', 'concordant_dis', 'cvd_comp', 'drug_class', 'eGFR', 'hba1c_bl_18m', 'hba1c_bl_6m', 'hdl', 'ika', 'insulin', 'ldl', 'obese', 'sp', 'sum_diab_drugs', 't2d_dur_y', 'trigly']
# Shape of training data before removing outliers: (1274, 18)
# Shape of test data before removing outliers: (101, 18)
# Training set outliers: [340, 521, 640, 762, 972, 252, 1060, 69, 315, 826, 923, 952, 1066, 145, 363, 565, 1058, 1111]
# Testing set outliers: []
# Shape of training data after removing outliers: (1256, 18)
# Shape of test data after removing outliers: (101, 18)
# Cross validation variance 0.0005477739099167746
# Cross validation mean score 0.633489776752894
# R2 score Training : 0.8365950377794913
# R2 score Testing: 0.4604
# RMSE: 5.481415
#  =========== Total number of samples assigned by the model VS Total number of samples in original test data
# DPP samples  45 49
# SGLT samples  55 52
#
#
# Category    Real value    Predicted value    Count    Percentage of Predicted cases
# ----------  ------------  -----------------  -------  -------------------------------
# Concordant  SGLT          SGLT               29       52.73%
# Discordant  DPP           SGLT               26       48.89%
#
# Concordant  DPP           DPP                23       51.11%
# Discordant  SGLT          DPP                22       47.27%
#
#
#  =========== Total number of samples assigned by the model VS Total number of samples in original test data
# DPP samples  26 49
# SGLT samples  75 52
#
#
# Category    Real value    Predicted value    Count    Percentage of Predicted cases
# ----------  ------------  -----------------  -------  -------------------------------
# Concordant  SGLT          SGLT               38       50.67%
# Discordant  DPP           SGLT               37       53.85%
#
# Concordant  DPP           DPP                12       46.15%
# Discordant  SGLT          DPP                14       49.33%
#
#
#  =========== Total number of samples assigned by the model VS Total number of samples in original test data
# DPP samples  78 49
# SGLT samples  21 52
#
#
# Category    Real value    Predicted value    Count    Percentage of Predicted cases
# ----------  ------------  -----------------  -------  -------------------------------
# Concordant  SGLT          SGLT               11       52.38%
# Discordant  DPP           SGLT               10       51.28%
#
# Concordant  DPP           DPP                38       48.72%
# Discordant  SGLT          DPP                40       47.62%
#
#
#  =========== Total number of samples assigned by the model VS Total number of samples in original test data
# DPP samples  9 49
# SGLT samples  92 52
#
#
# Category    Real value    Predicted value    Count    Percentage of Predicted cases
# ----------  ------------  -----------------  -------  -------------------------------
# Concordant  SGLT          SGLT               45       48.91%
# Discordant  DPP           SGLT               47       77.78%
#
# Concordant  DPP           DPP                2        22.22%
# Discordant  SGLT          DPP                7        51.09%
#
#
#
#  -------- Percentage HBA1C  ---------
# Category    Real value    Predicted value    Mean % Change from Baseline    std     treatment difference
# ----------  ------------  -----------------  -----------------------------  ------  ----------------------
# Concordant  SGLT          SGLT               -13.59%                        14.45%  -11.93%
# Discordant  DPP           SGLT               -1.65%                         11.84%
#
# Concordant  DPP           DPP                -6.87%                         15.20%  -4.14
# Discordant  SGLT          DPP                -2.73%                         12.69%
#
#  -------- Percentage LDL  ---------
# Category    Real value    Predicted value    Mean % Change from Baseline    std    treatment difference
# ----------  ------------  -----------------  -----------------------------  -----  ----------------------
# Concordant  SGLT          SGLT               -0.36%                         0.96%  -0.16%
# Discordant  DPP           SGLT               -0.20%                         0.70%
#
# Concordant  DPP           DPP                -0.03%                         0.97%  0.01
# Discordant  SGLT          DPP                -0.04%                         0.49%
#
#  -------- Percentage HDL  ---------
# Category    Real value    Predicted value    Mean % Change from Baseline    std    treatment difference
# ----------  ------------  -----------------  -----------------------------  -----  ----------------------
# Concordant  SGLT          SGLT               -0.09%                         0.31%  -0.14%
# Discordant  DPP           SGLT               0.04%                          0.27%
#
# Concordant  DPP           DPP                0.01%                          0.23%  -0.03
# Discordant  SGLT          DPP                0.04%                          0.19%
#
#  -------- Percentage BMI  ---------
# Category    Real value    Predicted value    Mean % Change from Baseline    std    treatment difference
# ----------  ------------  -----------------  -----------------------------  -----  ----------------------
# Concordant  SGLT          SGLT               -1.06%                         2.77%  -1.45%
# Discordant  DPP           SGLT               0.39%                          2.53%
#
# Concordant  DPP           DPP                -3.74%                         5.73%  -1.13
# Discordant  SGLT          DPP                -2.61%                         2.49%
# +----------------+-----------------+
# | Model          |   Test R2 Score |
# +================+=================+
# | RegressorChain |        0.460427 |
# +----------------+-----------------+
#
#
#
#
#
#
#
# ===============   7  features     ===================
#
# Shape of data after excluding missing response: (1566, 125)
# Shape of full data after selecting date range dates > 21 days (1084, 115)
# Shape of data after excluding missing response: (156, 125)
# Shape of full data after selecting date range dates > 21 days (102, 115)
# X_train shape:  (1077, 107)
# (1077, 107)
# {3.0, 4.0}
# [(3.0, 440), (4.0, 637)]
# [(3.0, 637), (4.0, 637)]
#
#
#
# ['MD_RCT_mmol_mol', 'bmi', 'chd', 'comb_comp_enn', 'concordant_dis', 'cvd_comp', 'drug_class', 'eGFR', 'hba1c_bl_18m', 'hba1c_bl_6m', 'hdl', 'hyperten', 'ika', 'insulin', 'ldl', 'obese', 'sp', 'sum_diab_drugs', 't2d_dur_y', 'trigly']
# Shape of training data before removing outliers: (1274, 20)
# Shape of test data before removing outliers: (101, 20)
# Training set outliers: [340, 521, 640, 762, 972, 238, 1060, 69, 315, 826, 923, 952, 1066, 145, 363, 565, 1058, 1111]
# Testing set outliers: []
# Shape of training data after removing outliers: (1256, 20)
# Shape of test data after removing outliers: (101, 20)
# Cross validation variance 0.0006281834843839548
# Cross validation mean score 0.6358413812737341
# R2 score Training : 0.8403686063177956
# R2 score Testing: 0.4704
# RMSE: 5.430112
#  =========== Total number of samples assigned by the model VS Total number of samples in original test data
# DPP samples  44 49
# SGLT samples  56 52
#
#
# Category    Real value    Predicted value    Count    Percentage of Predicted cases
# ----------  ------------  -----------------  -------  -------------------------------
# Concordant  SGLT          SGLT               29       51.79%
# Discordant  DPP           SGLT               27       52.27%
#
# Concordant  DPP           DPP                21       47.73%
# Discordant  SGLT          DPP                23       48.21%
#
#
#  =========== Total number of samples assigned by the model VS Total number of samples in original test data
# DPP samples  32 49
# SGLT samples  69 52
#
#
# Category    Real value    Predicted value    Count    Percentage of Predicted cases
# ----------  ------------  -----------------  -------  -------------------------------
# Concordant  SGLT          SGLT               31       44.93%
# Discordant  DPP           SGLT               38       65.62%
#
# Concordant  DPP           DPP                11       34.38%
# Discordant  SGLT          DPP                21       55.07%
#
#
#  =========== Total number of samples assigned by the model VS Total number of samples in original test data
# DPP samples  71 49
# SGLT samples  28 52
#
#
# Category    Real value    Predicted value    Count    Percentage of Predicted cases
# ----------  ------------  -----------------  -------  -------------------------------
# Concordant  SGLT          SGLT               14       50.00%
# Discordant  DPP           SGLT               14       50.70%
#
# Concordant  DPP           DPP                35       49.30%
# Discordant  SGLT          DPP                36       50.00%
#
#
#  =========== Total number of samples assigned by the model VS Total number of samples in original test data
# DPP samples  3 49
# SGLT samples  98 52
#
#
# Category    Real value    Predicted value    Count    Percentage of Predicted cases
# ----------  ------------  -----------------  -------  -------------------------------
# Concordant  SGLT          SGLT               50       51.02%
# Discordant  DPP           SGLT               48       66.67%
#
# Concordant  DPP           DPP                1        33.33%
# Discordant  SGLT          DPP                2        48.98%
#
#
#
#  -------- Percentage HBA1C  ---------
# Category    Real value    Predicted value    Mean % Change from Baseline    std     treatment difference
# ----------  ------------  -----------------  -----------------------------  ------  ----------------------
# Concordant  SGLT          SGLT               -13.86%                        14.79%  -10.49%
# Discordant  DPP           SGLT               -3.37%                         12.19%
#
# Concordant  DPP           DPP                -5.81%                         15.35%  -1.94
# Discordant  SGLT          DPP                -3.87%                         13.61%
#
#  -------- Percentage LDL  ---------
# Category    Real value    Predicted value    Mean % Change from Baseline    std    treatment difference
# ----------  ------------  -----------------  -----------------------------  -----  ----------------------
# Concordant  SGLT          SGLT               -0.41%                         0.99%  -0.33%
# Discordant  DPP           SGLT               -0.08%                         0.72%
#
# Concordant  DPP           DPP                -0.44%                         0.89%  -0.36
# Discordant  SGLT          DPP                -0.08%                         0.58%
#
#  -------- Percentage HDL  ---------
# Category    Real value    Predicted value    Mean % Change from Baseline    std    treatment difference
# ----------  ------------  -----------------  -----------------------------  -----  ----------------------
# Concordant  SGLT          SGLT               0.02%                          0.17%  -0.11%
# Discordant  DPP           SGLT               0.13%                          0.16%
#
# Concordant  DPP           DPP                -0.05%                         0.28%  -0.08
# Discordant  SGLT          DPP                0.03%                          0.19%
#
#  -------- Percentage BMI  ---------
# Category    Real value    Predicted value    Mean % Change from Baseline    std    treatment difference
# ----------  ------------  -----------------  -----------------------------  -----  ----------------------
# Concordant  SGLT          SGLT               -1.09%                         2.63%  -1.28%
# Discordant  DPP           SGLT               0.19%                          2.76%
#
# Concordant  DPP           DPP                1.56%                          nan%   7.25
# Discordant  SGLT          DPP                -5.69%                         3.15%
# +----------------+-----------------+
# | Model          |   Test R2 Score |
# +================+=================+
# | RegressorChain |        0.470447 |
# +----------------+-----------------+
#
#
#
#
#
#
#
# ===============   9  features     ===================
#
# Shape of data after excluding missing response: (1566, 125)
# Shape of full data after selecting date range dates > 21 days (1084, 115)
# Shape of data after excluding missing response: (156, 125)
# Shape of full data after selecting date range dates > 21 days (102, 115)
# X_train shape:  (1077, 107)
# (1077, 107)
# {3.0, 4.0}
# [(3.0, 440), (4.0, 637)]
# [(3.0, 637), (4.0, 637)]
#
#
#
# ['MD_RCT_mmol_mol', 'bmi', 'chd', 'comb_comp_enn', 'concordant_dis', 'cvd_comp', 'dg406', 'drug_class', 'eGFR', 'hba1c_bl_18m', 'hba1c_bl_6m', 'hdl', 'hyperten', 'ika', 'insulin', 'ldl', 'obese', 'sp', 'sum_diab_drugs', 't2d_dur_y', 'trigly']
# Shape of training data before removing outliers: (1274, 21)
# Shape of test data before removing outliers: (101, 21)
# Training set outliers: [340, 521, 640, 762, 972, 238, 1060, 69, 315, 826, 923, 952, 1066, 145, 363, 565, 1058, 1111]
# Testing set outliers: []
# Shape of training data after removing outliers: (1256, 21)
# Shape of test data after removing outliers: (101, 21)
# Cross validation variance 0.0007025918025992792
# Cross validation mean score 0.6344628147771646
# R2 score Training : 0.8398522340014666
# R2 score Testing: 0.4649
# RMSE: 5.442018
#  =========== Total number of samples assigned by the model VS Total number of samples in original test data
# DPP samples  45 49
# SGLT samples  55 52
#
#
# Category    Real value    Predicted value    Count    Percentage of Predicted cases
# ----------  ------------  -----------------  -------  -------------------------------
# Concordant  SGLT          SGLT               27       49.09%
# Discordant  DPP           SGLT               28       55.56%
#
# Concordant  DPP           DPP                20       44.44%
# Discordant  SGLT          DPP                25       50.91%
#
#
#  =========== Total number of samples assigned by the model VS Total number of samples in original test data
# DPP samples  14 49
# SGLT samples  87 52
#
#
# Category    Real value    Predicted value    Count    Percentage of Predicted cases
# ----------  ------------  -----------------  -------  -------------------------------
# Concordant  SGLT          SGLT               45       51.72%
# Discordant  DPP           SGLT               42       50.00%
#
# Concordant  DPP           DPP                7        50.00%
# Discordant  SGLT          DPP                7        48.28%
#
#
#  =========== Total number of samples assigned by the model VS Total number of samples in original test data
# DPP samples  72 49
# SGLT samples  29 52
#
#
# Category    Real value    Predicted value    Count    Percentage of Predicted cases
# ----------  ------------  -----------------  -------  -------------------------------
# Concordant  SGLT          SGLT               16       55.17%
# Discordant  DPP           SGLT               13       50.00%
#
# Concordant  DPP           DPP                36       50.00%
# Discordant  SGLT          DPP                36       44.83%
#
#
#  =========== Total number of samples assigned by the model VS Total number of samples in original test data
# DPP samples  8 49
# SGLT samples  93 52
#
#
# Category    Real value    Predicted value    Count    Percentage of Predicted cases
# ----------  ------------  -----------------  -------  -------------------------------
# Concordant  SGLT          SGLT               47       50.54%
# Discordant  DPP           SGLT               46       62.50%
#
# Concordant  DPP           DPP                3        37.50%
# Discordant  SGLT          DPP                5        49.46%
#
#
#
#  -------- Percentage HBA1C  ---------
# Category    Real value    Predicted value    Mean % Change from Baseline    std     treatment difference
# ----------  ------------  -----------------  -----------------------------  ------  ----------------------
# Concordant  SGLT          SGLT               -11.26%                        11.76%  -8.19%
# Discordant  DPP           SGLT               -3.07%                         12.20%
#
# Concordant  DPP           DPP                -2.70%                         9.15%   4.78
# Discordant  SGLT          DPP                -7.48%                         17.91%
#
#  -------- Percentage LDL  ---------
# Category    Real value    Predicted value    Mean % Change from Baseline    std    treatment difference
# ----------  ------------  -----------------  -----------------------------  -----  ----------------------
# Concordant  SGLT          SGLT               -0.30%                         0.88%  -0.14%
# Discordant  DPP           SGLT               -0.16%                         0.71%
#
# Concordant  DPP           DPP                -0.17%                         1.10%  -0.06
# Discordant  SGLT          DPP                -0.11%                         0.76%
#
#  -------- Percentage HDL  ---------
# Category    Real value    Predicted value    Mean % Change from Baseline    std    treatment difference
# ----------  ------------  -----------------  -----------------------------  -----  ----------------------
# Concordant  SGLT          SGLT               -0.05%                         0.30%  -0.00%
# Discordant  DPP           SGLT               -0.05%                         0.30%
#
# Concordant  DPP           DPP                0.02%                          0.25%  -0.01
# Discordant  SGLT          DPP                0.03%                          0.18%
#
#  -------- Percentage BMI  ---------
# Category    Real value    Predicted value    Mean % Change from Baseline    std    treatment difference
# ----------  ------------  -----------------  -----------------------------  -----  ----------------------
# Concordant  SGLT          SGLT               -1.34%                         2.19%  -1.53%
# Discordant  DPP           SGLT               0.20%                          2.82%
#
# Concordant  DPP           DPP                0.57%                          0.99%  1.19
# Discordant  SGLT          DPP                -0.62%                         6.46%
# +----------------+-----------------+
# | Model          |   Test R2 Score |
# +================+=================+
# | RegressorChain |        0.464862 |
# +----------------+-----------------+

# %%
feats = [
    ['bmi', 'drug_class', 'eGFR', 'hba1c_bl_6m', 'hdl', 'ldl'],
    ['bmi', 'drug_class', 'eGFR', 'gluk', 'hba1c_bl_18m', 'hba1c_bl_6m', 'hdl', 'ika', 'ldl'],
    ['bmi', 'drug_class', 'eGFR', 'gluk', 'hba1c_bl_18m', 'hba1c_bl_6m', 'hdl', 'ika', 'ldl', 'trigly'],
    ['P_Krea', 'bmi', 'drug_class', 'eGFR', 'gluk', 'hba1c_bl_18m', 'hba1c_bl_6m', 'hdl', 'ika', 'ldl', 'trigly'],
    ['P_Krea', 'bmi', 'drug_class', 'eGFR', 'gluk', 'hba1c_bl_18m', 'hba1c_bl_6m', 'hdl', 'ika', 'ldl', 't2d_dur_y', 'trigly'],
    

]

feature_size  = [2,3,4,5,6]
warnings.filterwarnings('ignore')
for i, val in enumerate(feature_size):
    print('\n\n\n===============  ', val ,' features ','   ===================\n',)
    model_results = run('ref', val, feats[i])
    table = []
    for model, score in model_results.items():
        table.append([model, score])

    table_str = tabulate(table, headers=['Model', 'Test R2 Score'], tablefmt='grid')
    print(table_str)
        
    print('\n\n\n')
# Out:
# ===============   2  features     ===================
#
# Shape of data after excluding missing response: (1566, 125)
# Shape of full data after selecting date range dates > 21 days (1084, 115)
# Shape of data after excluding missing response: (156, 125)
# Shape of full data after selecting date range dates > 21 days (102, 115)
# X_train shape:  (1077, 107)
# (1077, 107)
# {3.0, 4.0}
# [(3.0, 440), (4.0, 637)]
# [(3.0, 637), (4.0, 637)]
#
#
#
# ['bmi', 'drug_class', 'eGFR', 'hba1c_bl_6m', 'hdl', 'ldl']
# Shape of training data before removing outliers: (1274, 6)
# Shape of test data before removing outliers: (101, 6)
# Training set outliers: [238, 1060, 448, 834, 923, 834]
# Testing set outliers: []
# Shape of training data after removing outliers: (1269, 6)
# Shape of test data after removing outliers: (101, 6)
# Cross validation variance 8.912255373153239e-05
# Cross validation mean score 0.5967027247551456
# R2 score Training : 0.7908526086243748
# R2 score Testing: 0.4490
# RMSE: 5.591692
#  =========== Total number of samples assigned by the model VS Total number of samples in original test data
# DPP samples  57 49
# SGLT samples  44 52
#
#
# Category    Real value    Predicted value    Count    Percentage of Predicted cases
# ----------  ------------  -----------------  -------  -------------------------------
# Concordant  SGLT          SGLT               24       54.55%
# Discordant  DPP           SGLT               20       49.12%
#
# Concordant  DPP           DPP                29       50.88%
# Discordant  SGLT          DPP                28       45.45%
#
#
#  =========== Total number of samples assigned by the model VS Total number of samples in original test data
# DPP samples  19 49
# SGLT samples  82 52
#
#
# Category    Real value    Predicted value    Count    Percentage of Predicted cases
# ----------  ------------  -----------------  -------  -------------------------------
# Concordant  SGLT          SGLT               43       52.44%
# Discordant  DPP           SGLT               39       47.37%
#
# Concordant  DPP           DPP                10       52.63%
# Discordant  SGLT          DPP                9        47.56%
#
#
#  =========== Total number of samples assigned by the model VS Total number of samples in original test data
# DPP samples  67 49
# SGLT samples  31 52
#
#
# Category    Real value    Predicted value    Count    Percentage of Predicted cases
# ----------  ------------  -----------------  -------  -------------------------------
# Concordant  SGLT          SGLT               16       51.61%
# Discordant  DPP           SGLT               15       50.75%
#
# Concordant  DPP           DPP                33       49.25%
# Discordant  SGLT          DPP                34       48.39%
#
#
#  =========== Total number of samples assigned by the model VS Total number of samples in original test data
# DPP samples  12 49
# SGLT samples  89 52
#
#
# Category    Real value    Predicted value    Count    Percentage of Predicted cases
# ----------  ------------  -----------------  -------  -------------------------------
# Concordant  SGLT          SGLT               46       51.69%
# Discordant  DPP           SGLT               43       50.00%
#
# Concordant  DPP           DPP                6        50.00%
# Discordant  SGLT          DPP                6        48.31%
#
#
#
#  -------- Percentage HBA1C  ---------
# Category    Real value    Predicted value    Mean % Change from Baseline    std     treatment difference
# ----------  ------------  -----------------  -----------------------------  ------  ----------------------
# Concordant  SGLT          SGLT               -10.46%                        14.50%  -7.76%
# Discordant  DPP           SGLT               -2.70%                         12.81%
#
# Concordant  DPP           DPP                -5.07%                         14.31%  3.50
# Discordant  SGLT          DPP                -8.57%                         15.63%
#
#  -------- Percentage LDL  ---------
# Category    Real value    Predicted value    Mean % Change from Baseline    std    treatment difference
# ----------  ------------  -----------------  -----------------------------  -----  ----------------------
# Concordant  SGLT          SGLT               -0.33%                         0.90%  -0.25%
# Discordant  DPP           SGLT               -0.09%                         0.80%
#
# Concordant  DPP           DPP                -0.45%                         0.52%  -0.45
# Discordant  SGLT          DPP                -0.00%                         0.58%
#
#  -------- Percentage HDL  ---------
# Category    Real value    Predicted value    Mean % Change from Baseline    std    treatment difference
# ----------  ------------  -----------------  -----------------------------  -----  ----------------------
# Concordant  SGLT          SGLT               0.05%                          0.20%  -0.01%
# Discordant  DPP           SGLT               0.06%                          0.25%
#
# Concordant  DPP           DPP                0.00%                          0.23%  -0.02
# Discordant  SGLT          DPP                0.02%                          0.18%
#
#  -------- Percentage BMI  ---------
# Category    Real value    Predicted value    Mean % Change from Baseline    std    treatment difference
# ----------  ------------  -----------------  -----------------------------  -----  ----------------------
# Concordant  SGLT          SGLT               -1.62%                         2.15%  -1.81%
# Discordant  DPP           SGLT               0.19%                          2.90%
#
# Concordant  DPP           DPP                0.43%                          0.98%  -0.97
# Discordant  SGLT          DPP                1.41%                          5.16%
# +----------------+-----------------+
# | Model          |   Test R2 Score |
# +================+=================+
# | RegressorChain |        0.448954 |
# +----------------+-----------------+
#
#
#
#
#
#
#
# ===============   3  features     ===================
#
# Shape of data after excluding missing response: (1566, 125)
# Shape of full data after selecting date range dates > 21 days (1084, 115)
# Shape of data after excluding missing response: (156, 125)
# Shape of full data after selecting date range dates > 21 days (102, 115)
# X_train shape:  (1077, 107)
# (1077, 107)
# {3.0, 4.0}
# [(3.0, 440), (4.0, 637)]
# [(3.0, 637), (4.0, 637)]
#
#
#
# ['bmi', 'drug_class', 'eGFR', 'gluk', 'hba1c_bl_18m', 'hba1c_bl_6m', 'hdl', 'ika', 'ldl']
# Shape of training data before removing outliers: (1274, 9)
# Shape of test data before removing outliers: (101, 9)
# Training set outliers: [340, 521, 972, 238, 252, 1060, 69, 315, 640, 826, 923, 952, 1066, 145, 363, 565, 749, 1058, 1111]
# Testing set outliers: []
# Shape of training data after removing outliers: (1255, 9)
# Shape of test data after removing outliers: (101, 9)
# Cross validation variance 9.438471116562621e-05
# Cross validation mean score 0.6212781345850604
# R2 score Training : 0.8237529464909481
# R2 score Testing: 0.4472
# RMSE: 5.512352
#  =========== Total number of samples assigned by the model VS Total number of samples in original test data
# DPP samples  49 49
# SGLT samples  51 52
#
#
# Category    Real value    Predicted value    Count    Percentage of Predicted cases
# ----------  ------------  -----------------  -------  -------------------------------
# Concordant  SGLT          SGLT               26       50.98%
# Discordant  DPP           SGLT               25       53.06%
#
# Concordant  DPP           DPP                23       46.94%
# Discordant  SGLT          DPP                26       49.02%
#
#
#  =========== Total number of samples assigned by the model VS Total number of samples in original test data
# DPP samples  15 49
# SGLT samples  85 52
#
#
# Category    Real value    Predicted value    Count    Percentage of Predicted cases
# ----------  ------------  -----------------  -------  -------------------------------
# Concordant  SGLT          SGLT               44       51.76%
# Discordant  DPP           SGLT               41       46.67%
#
# Concordant  DPP           DPP                8        53.33%
# Discordant  SGLT          DPP                7        48.24%
#
#
#  =========== Total number of samples assigned by the model VS Total number of samples in original test data
# DPP samples  79 49
# SGLT samples  22 52
#
#
# Category    Real value    Predicted value    Count    Percentage of Predicted cases
# ----------  ------------  -----------------  -------  -------------------------------
# Concordant  SGLT          SGLT               14       63.64%
# Discordant  DPP           SGLT               8        48.10%
#
# Concordant  DPP           DPP                41       51.90%
# Discordant  SGLT          DPP                38       36.36%
#
#
#  =========== Total number of samples assigned by the model VS Total number of samples in original test data
# DPP samples  11 49
# SGLT samples  90 52
#
#
# Category    Real value    Predicted value    Count    Percentage of Predicted cases
# ----------  ------------  -----------------  -------  -------------------------------
# Concordant  SGLT          SGLT               48       53.33%
# Discordant  DPP           SGLT               42       36.36%
#
# Concordant  DPP           DPP                7        63.64%
# Discordant  SGLT          DPP                4        46.67%
#
#
#
#  -------- Percentage HBA1C  ---------
# Category    Real value    Predicted value    Mean % Change from Baseline    std     treatment difference
# ----------  ------------  -----------------  -----------------------------  ------  ----------------------
# Concordant  SGLT          SGLT               -15.19%                        18.37%  -11.47%
# Discordant  DPP           SGLT               -3.72%                         12.84%
#
# Concordant  DPP           DPP                -5.00%                         14.79%  -1.31
# Discordant  SGLT          DPP                -3.69%                         7.28%
#
#  -------- Percentage LDL  ---------
# Category    Real value    Predicted value    Mean % Change from Baseline    std    treatment difference
# ----------  ------------  -----------------  -----------------------------  -----  ----------------------
# Concordant  SGLT          SGLT               -0.35%                         0.89%  -0.08%
# Discordant  DPP           SGLT               -0.27%                         0.75%
#
# Concordant  DPP           DPP                0.38%                          0.62%  0.19
# Discordant  SGLT          DPP                0.19%                          0.59%
#
#  -------- Percentage HDL  ---------
# Category    Real value    Predicted value    Mean % Change from Baseline    std    treatment difference
# ----------  ------------  -----------------  -----------------------------  -----  ----------------------
# Concordant  SGLT          SGLT               0.08%                          0.18%  0.02%
# Discordant  DPP           SGLT               0.06%                          0.13%
#
# Concordant  DPP           DPP                -0.01%                         0.28%  0.01
# Discordant  SGLT          DPP                -0.02%                         0.23%
#
#  -------- Percentage BMI  ---------
# Category    Real value    Predicted value    Mean % Change from Baseline    std    treatment difference
# ----------  ------------  -----------------  -----------------------------  -----  ----------------------
# Concordant  SGLT          SGLT               -1.16%                         2.85%  -1.18%
# Discordant  DPP           SGLT               0.02%                          2.32%
#
# Concordant  DPP           DPP                1.44%                          4.58%  3.95
# Discordant  SGLT          DPP                -2.52%                         0.72%
# +----------------+-----------------+
# | Model          |   Test R2 Score |
# +================+=================+
# | RegressorChain |        0.447186 |
# +----------------+-----------------+
#
#
#
#
#
#
#
# ===============   4  features     ===================
#
# Shape of data after excluding missing response: (1566, 125)
# Shape of full data after selecting date range dates > 21 days (1084, 115)
# Shape of data after excluding missing response: (156, 125)
# Shape of full data after selecting date range dates > 21 days (102, 115)
# X_train shape:  (1077, 107)
# (1077, 107)
# {3.0, 4.0}
# [(3.0, 440), (4.0, 637)]
# [(3.0, 637), (4.0, 637)]
#
#
#
# ['bmi', 'drug_class', 'eGFR', 'gluk', 'hba1c_bl_18m', 'hba1c_bl_6m', 'hdl', 'ika', 'ldl', 'trigly']
# Shape of training data before removing outliers: (1274, 10)
# Shape of test data before removing outliers: (101, 10)
# Training set outliers: [340, 521, 640, 972, 238, 252, 1060, 69, 315, 826, 923, 952, 1066, 145, 363, 565, 749, 1058, 1111]
# Testing set outliers: []
# Shape of training data after removing outliers: (1255, 10)
# Shape of test data after removing outliers: (101, 10)
# Cross validation variance 6.819618142091637e-05
# Cross validation mean score 0.6229774527605346
# R2 score Training : 0.8287653751617574
# R2 score Testing: 0.4447
# RMSE: 5.635239
#  =========== Total number of samples assigned by the model VS Total number of samples in original test data
# DPP samples  51 49
# SGLT samples  50 52
#
#
# Category    Real value    Predicted value    Count    Percentage of Predicted cases
# ----------  ------------  -----------------  -------  -------------------------------
# Concordant  SGLT          SGLT               25       50.00%
# Discordant  DPP           SGLT               25       52.94%
#
# Concordant  DPP           DPP                24       47.06%
# Discordant  SGLT          DPP                27       50.00%
#
#
#  =========== Total number of samples assigned by the model VS Total number of samples in original test data
# DPP samples  16 49
# SGLT samples  85 52
#
#
# Category    Real value    Predicted value    Count    Percentage of Predicted cases
# ----------  ------------  -----------------  -------  -------------------------------
# Concordant  SGLT          SGLT               42       49.41%
# Discordant  DPP           SGLT               43       62.50%
#
# Concordant  DPP           DPP                6        37.50%
# Discordant  SGLT          DPP                10       50.59%
#
#
#  =========== Total number of samples assigned by the model VS Total number of samples in original test data
# DPP samples  70 49
# SGLT samples  29 52
#
#
# Category    Real value    Predicted value    Count    Percentage of Predicted cases
# ----------  ------------  -----------------  -------  -------------------------------
# Concordant  SGLT          SGLT               18       62.07%
# Discordant  DPP           SGLT               11       47.14%
#
# Concordant  DPP           DPP                37       52.86%
# Discordant  SGLT          DPP                33       37.93%
#
#
#  =========== Total number of samples assigned by the model VS Total number of samples in original test data
# DPP samples  5 49
# SGLT samples  96 52
#
#
# Category    Real value    Predicted value    Count    Percentage of Predicted cases
# ----------  ------------  -----------------  -------  -------------------------------
# Concordant  SGLT          SGLT               48       50.00%
# Discordant  DPP           SGLT               48       80.00%
#
# Concordant  DPP           DPP                1        20.00%
# Discordant  SGLT          DPP                4        50.00%
#
#
#
#  -------- Percentage HBA1C  ---------
# Category    Real value    Predicted value    Mean % Change from Baseline    std     treatment difference
# ----------  ------------  -----------------  -----------------------------  ------  ----------------------
# Concordant  SGLT          SGLT               -13.60%                        17.31%  -9.20%
# Discordant  DPP           SGLT               -4.40%                         12.58%
#
# Concordant  DPP           DPP                -3.79%                         14.91%  1.80
# Discordant  SGLT          DPP                -5.59%                         11.52%
#
#  -------- Percentage LDL  ---------
# Category    Real value    Predicted value    Mean % Change from Baseline    std    treatment difference
# ----------  ------------  -----------------  -----------------------------  -----  ----------------------
# Concordant  SGLT          SGLT               -0.30%                         0.88%  -0.17%
# Discordant  DPP           SGLT               -0.13%                         0.71%
#
# Concordant  DPP           DPP                -0.35%                         1.14%  -0.20
# Discordant  SGLT          DPP                -0.15%                         0.80%
#
#  -------- Percentage HDL  ---------
# Category    Real value    Predicted value    Mean % Change from Baseline    std    treatment difference
# ----------  ------------  -----------------  -----------------------------  -----  ----------------------
# Concordant  SGLT          SGLT               0.02%                          0.27%  -0.00%
# Discordant  DPP           SGLT               0.02%                          0.17%
#
# Concordant  DPP           DPP                0.02%                          0.25%  0.01
# Discordant  SGLT          DPP                0.01%                          0.20%
#
#  -------- Percentage BMI  ---------
# Category    Real value    Predicted value    Mean % Change from Baseline    std    treatment difference
# ----------  ------------  -----------------  -----------------------------  -----  ----------------------
# Concordant  SGLT          SGLT               -1.26%                         2.56%  -1.50%
# Discordant  DPP           SGLT               0.24%                          2.76%
#
# Concordant  DPP           DPP                -0.67%                         nan%   0.73
# Discordant  SGLT          DPP                -1.40%                         5.18%
# +----------------+-----------------+
# | Model          |   Test R2 Score |
# +================+=================+
# | RegressorChain |        0.444671 |
# +----------------+-----------------+
#
#
#
#
#
#
#
# ===============   5  features     ===================
#
# Shape of data after excluding missing response: (1566, 125)
# Shape of full data after selecting date range dates > 21 days (1084, 115)
# Shape of data after excluding missing response: (156, 125)
# Shape of full data after selecting date range dates > 21 days (102, 115)
# X_train shape:  (1077, 107)
# (1077, 107)
# {3.0, 4.0}
# [(3.0, 440), (4.0, 637)]
# [(3.0, 637), (4.0, 637)]
#
#
#
# ['P_Krea', 'bmi', 'drug_class', 'eGFR', 'gluk', 'hba1c_bl_18m', 'hba1c_bl_6m', 'hdl', 'ika', 'ldl', 'trigly']
# Shape of training data before removing outliers: (1274, 11)
# Shape of test data before removing outliers: (101, 11)
# Training set outliers: [62, 340, 358, 521, 762, 972, 252, 1060, 315, 468, 826, 923, 938, 952, 1066, 145, 363, 565, 749, 1058, 1111]
# Testing set outliers: []
# Shape of training data after removing outliers: (1253, 11)
# Shape of test data after removing outliers: (101, 11)
# Cross validation variance 3.787340757381092e-05
# Cross validation mean score 0.627270961805816
# R2 score Training : 0.8323742933077192
# R2 score Testing: 0.4506
# RMSE: 5.528138
#  =========== Total number of samples assigned by the model VS Total number of samples in original test data
# DPP samples  42 49
# SGLT samples  59 52
#
#
# Category    Real value    Predicted value    Count    Percentage of Predicted cases
# ----------  ------------  -----------------  -------  -------------------------------
# Concordant  SGLT          SGLT               27       45.76%
# Discordant  DPP           SGLT               32       59.52%
#
# Concordant  DPP           DPP                17       40.48%
# Discordant  SGLT          DPP                25       54.24%
#
#
#  =========== Total number of samples assigned by the model VS Total number of samples in original test data
# DPP samples  12 49
# SGLT samples  89 52
#
#
# Category    Real value    Predicted value    Count    Percentage of Predicted cases
# ----------  ------------  -----------------  -------  -------------------------------
# Concordant  SGLT          SGLT               45       50.56%
# Discordant  DPP           SGLT               44       58.33%
#
# Concordant  DPP           DPP                5        41.67%
# Discordant  SGLT          DPP                7        49.44%
#
#
#  =========== Total number of samples assigned by the model VS Total number of samples in original test data
# DPP samples  72 49
# SGLT samples  27 52
#
#
# Category    Real value    Predicted value    Count    Percentage of Predicted cases
# ----------  ------------  -----------------  -------  -------------------------------
# Concordant  SGLT          SGLT               16       59.26%
# Discordant  DPP           SGLT               11       47.22%
#
# Concordant  DPP           DPP                38       52.78%
# Discordant  SGLT          DPP                34       40.74%
#
#
#  =========== Total number of samples assigned by the model VS Total number of samples in original test data
# DPP samples  8 49
# SGLT samples  93 52
#
#
# Category    Real value    Predicted value    Count    Percentage of Predicted cases
# ----------  ------------  -----------------  -------  -------------------------------
# Concordant  SGLT          SGLT               48       51.61%
# Discordant  DPP           SGLT               45       50.00%
#
# Concordant  DPP           DPP                4        50.00%
# Discordant  SGLT          DPP                4        48.39%
#
#
#
#  -------- Percentage HBA1C  ---------
# Category    Real value    Predicted value    Mean % Change from Baseline    std     treatment difference
# ----------  ------------  -----------------  -----------------------------  ------  ----------------------
# Concordant  SGLT          SGLT               -10.26%                        13.68%  -8.01%
# Discordant  DPP           SGLT               -2.25%                         11.53%
#
# Concordant  DPP           DPP                -7.59%                         16.73%  0.97
# Discordant  SGLT          DPP                -8.56%                         16.55%
#
#  -------- Percentage LDL  ---------
# Category    Real value    Predicted value    Mean % Change from Baseline    std    treatment difference
# ----------  ------------  -----------------  -----------------------------  -----  ----------------------
# Concordant  SGLT          SGLT               -0.30%                         0.90%  -0.10%
# Discordant  DPP           SGLT               -0.20%                         0.78%
#
# Concordant  DPP           DPP                0.18%                          0.61%  0.31
# Discordant  SGLT          DPP                -0.13%                         0.62%
#
#  -------- Percentage HDL  ---------
# Category    Real value    Predicted value    Mean % Change from Baseline    std    treatment difference
# ----------  ------------  -----------------  -----------------------------  -----  ----------------------
# Concordant  SGLT          SGLT               0.04%                          0.14%  -0.05%
# Discordant  DPP           SGLT               0.09%                          0.19%
#
# Concordant  DPP           DPP                -0.02%                         0.28%  -0.05
# Discordant  SGLT          DPP                0.02%                          0.20%
#
#  -------- Percentage BMI  ---------
# Category    Real value    Predicted value    Mean % Change from Baseline    std    treatment difference
# ----------  ------------  -----------------  -----------------------------  -----  ----------------------
# Concordant  SGLT          SGLT               -1.45%                         2.33%  -1.62%
# Discordant  DPP           SGLT               0.17%                          2.85%
#
# Concordant  DPP           DPP                0.77%                          0.70%  -0.14
# Discordant  SGLT          DPP                0.91%                          6.13%
# +----------------+-----------------+
# | Model          |   Test R2 Score |
# +================+=================+
# | RegressorChain |        0.450642 |
# +----------------+-----------------+
#
#
#
#
#
#
#
# ===============   6  features     ===================
#
# Shape of data after excluding missing response: (1566, 125)
# Shape of full data after selecting date range dates > 21 days (1084, 115)
# Shape of data after excluding missing response: (156, 125)
# Shape of full data after selecting date range dates > 21 days (102, 115)
# X_train shape:  (1077, 107)
# (1077, 107)
# {3.0, 4.0}
# [(3.0, 440), (4.0, 637)]
# [(3.0, 637), (4.0, 637)]
#
#
#
# ['P_Krea', 'bmi', 'drug_class', 'eGFR', 'gluk', 'hba1c_bl_18m', 'hba1c_bl_6m', 'hdl', 'ika', 'ldl', 't2d_dur_y', 'trigly']
# Shape of training data before removing outliers: (1274, 12)
# Shape of test data before removing outliers: (101, 12)
# Training set outliers: [62, 340, 521, 762, 972, 252, 1060, 315, 468, 826, 923, 938, 952, 1066, 145, 363, 565, 749, 1058, 1111]
# Testing set outliers: []
# Shape of training data after removing outliers: (1254, 12)
# Shape of test data after removing outliers: (101, 12)
# Cross validation variance 3.9228766755695196e-05
# Cross validation mean score 0.6342659494377912
# R2 score Training : 0.836688349987735
# R2 score Testing: 0.4603
# RMSE: 5.454550
#  =========== Total number of samples assigned by the model VS Total number of samples in original test data
# DPP samples  47 49
# SGLT samples  54 52
#
#
# Category    Real value    Predicted value    Count    Percentage of Predicted cases
# ----------  ------------  -----------------  -------  -------------------------------
# Concordant  SGLT          SGLT               26       48.15%
# Discordant  DPP           SGLT               28       55.32%
#
# Concordant  DPP           DPP                21       44.68%
# Discordant  SGLT          DPP                26       51.85%
#
#
#  =========== Total number of samples assigned by the model VS Total number of samples in original test data
# DPP samples  18 49
# SGLT samples  83 52
#
#
# Category    Real value    Predicted value    Count    Percentage of Predicted cases
# ----------  ------------  -----------------  -------  -------------------------------
# Concordant  SGLT          SGLT               41       49.40%
# Discordant  DPP           SGLT               42       61.11%
#
# Concordant  DPP           DPP                7        38.89%
# Discordant  SGLT          DPP                11       50.60%
#
#
#  =========== Total number of samples assigned by the model VS Total number of samples in original test data
# DPP samples  78 49
# SGLT samples  22 52
#
#
# Category    Real value    Predicted value    Count    Percentage of Predicted cases
# ----------  ------------  -----------------  -------  -------------------------------
# Concordant  SGLT          SGLT               14       63.64%
# Discordant  DPP           SGLT               8        47.44%
#
# Concordant  DPP           DPP                41       52.56%
# Discordant  SGLT          DPP                37       36.36%
#
#
#  =========== Total number of samples assigned by the model VS Total number of samples in original test data
# DPP samples  13 49
# SGLT samples  88 52
#
#
# Category    Real value    Predicted value    Count    Percentage of Predicted cases
# ----------  ------------  -----------------  -------  -------------------------------
# Concordant  SGLT          SGLT               44       50.00%
# Discordant  DPP           SGLT               44       61.54%
#
# Concordant  DPP           DPP                5        38.46%
# Discordant  SGLT          DPP                8        50.00%
#
#
#
#  -------- Percentage HBA1C  ---------
# Category    Real value    Predicted value    Mean % Change from Baseline    std     treatment difference
# ----------  ------------  -----------------  -----------------------------  ------  ----------------------
# Concordant  SGLT          SGLT               -13.54%                        16.43%  -11.75%
# Discordant  DPP           SGLT               -1.79%                         11.59%
#
# Concordant  DPP           DPP                -7.19%                         15.71%  -1.84
# Discordant  SGLT          DPP                -5.35%                         12.41%
#
#  -------- Percentage LDL  ---------
# Category    Real value    Predicted value    Mean % Change from Baseline    std    treatment difference
# ----------  ------------  -----------------  -----------------------------  -----  ----------------------
# Concordant  SGLT          SGLT               -0.34%                         0.95%  -0.15%
# Discordant  DPP           SGLT               -0.19%                         0.77%
#
# Concordant  DPP           DPP                0.03%                          0.76%  0.06
# Discordant  SGLT          DPP                -0.04%                         0.33%
#
#  -------- Percentage HDL  ---------
# Category    Real value    Predicted value    Mean % Change from Baseline    std    treatment difference
# ----------  ------------  -----------------  -----------------------------  -----  ----------------------
# Concordant  SGLT          SGLT               0.05%                          0.14%  0.03%
# Discordant  DPP           SGLT               0.02%                          0.16%
#
# Concordant  DPP           DPP                -0.00%                         0.28%  0.00
# Discordant  SGLT          DPP                -0.00%                         0.25%
#
#  -------- Percentage BMI  ---------
# Category    Real value    Predicted value    Mean % Change from Baseline    std    treatment difference
# ----------  ------------  -----------------  -----------------------------  -----  ----------------------
# Concordant  SGLT          SGLT               -1.50%                         2.40%  -1.69%
# Discordant  DPP           SGLT               0.19%                          2.85%
#
# Concordant  DPP           DPP                0.49%                          1.45%  0.47
# Discordant  SGLT          DPP                0.02%                          4.23%
# +----------------+-----------------+
# | Model          |   Test R2 Score |
# +================+=================+
# | RegressorChain |        0.460277 |
# +----------------+-----------------+

# %%
feats = [
    ['P_Krea', 'bmi', 'drug_class', 'eGFR', 'gluk', 'hba1c_bl_18m', 'hba1c_bl_6m', 'ika', 'ldl', 't2d_dur_y', 'trigly'],
    ['P_Krea', 'bmi', 'drug_class', 'eGFR', 'gluk', 'hba1c_bl_18m', 'hba1c_bl_6m', 'hdl', 'ika', 'ldl', 'n_of_dis', 't2d_dur_y', 'trigly'],
    ['MD_RCT_mmol_mol', 'P_Krea', 'bmi', 'drug_class', 'eGFR', 'gluk', 'hba1c_bl_18m', 'hba1c_bl_6m', 'hdl', 'ika', 'ldl', 'n_of_dis', 'smoking', 'sum_diab_drugs', 't2d_dur_y', 'trigly'],
    ['C10A', 'MD_RCT_mmol_mol', 'P_Krea', 'bmi', 'comb_comp_enn', 'drug_class', 'eGFR', 'gluk', 'hba1c_bl_18m', 'hba1c_bl_6m', 'hdl', 'ika', 'insulin', 'ldl', 'met_oad0', 'n_of_dis', 'smoking', 'sum_diab_drugs', 't2d_dur_y', 'trigly'],
    ['C10A', 'MD_RCT_mmol_mol', 'P_Krea', 'T2D_nocomp', 'bmi', 'comb_comp_enn', 'drug_class', 'eGFR', 'gluk', 'hba1c_bl_18m', 'hba1c_bl_6m', 'hdl', 'ika', 'insulin', 'ldl', 'met_oad0', 'n_of_dis', 'renal_insuf', 'smoking', 'sum_diab_drugs', 't2d_dur_y', 'trigly'],
    
   ]

feature_size  = [10,12,15,20,22]
warnings.filterwarnings('ignore')
for i, val in enumerate(feature_size):
    print('\n\n\n===============  ', val ,' features ','   ===================\n',)
    model_results = run('refMulti', val, feats[i])
    table = []
    for model, score in model_results.items():
        table.append([model, score])

    table_str = tabulate(table, headers=['Model', 'Test R2 Score'], tablefmt='grid')
    print(table_str)
        
    print('\n\n\n')
# Out:
# ===============   10  features     ===================
#
# Shape of data after excluding missing response: (1566, 125)
# Shape of full data after selecting date range dates > 21 days (1084, 115)
# Shape of data after excluding missing response: (156, 125)
# Shape of full data after selecting date range dates > 21 days (102, 115)
# X_train shape:  (1077, 107)
# (1077, 107)
# {3.0, 4.0}
# [(3.0, 440), (4.0, 637)]
# [(3.0, 637), (4.0, 637)]
#
#
#
# ['P_Krea', 'bmi', 'drug_class', 'eGFR', 'gluk', 'hba1c_bl_18m', 'hba1c_bl_6m', 'ika', 'ldl', 't2d_dur_y', 'trigly']
# Shape of training data before removing outliers: (1274, 11)
# Shape of test data before removing outliers: (101, 11)
# Training set outliers: [62, 340, 521, 762, 972, 252, 1060, 219, 278, 288, 875, 924, 1063, 145, 363, 565, 749, 1058, 1111]
# Testing set outliers: []
# Shape of training data after removing outliers: (1255, 11)
# Shape of test data after removing outliers: (101, 11)
# Cross validation variance 0.00014121884891293474
# Cross validation mean score 0.5087618743882788
# R2 score Training : 0.770731919892667
# R2 score Testing: 0.3846
# RMSE: 5.436061
#  =========== Total number of samples assigned by the model VS Total number of samples in original test data
# DPP samples  45 49
# SGLT samples  55 52
#
#
# Category    Real value    Predicted value    Count    Percentage of Predicted cases
# ----------  ------------  -----------------  -------  -------------------------------
# Concordant  SGLT          SGLT               24       43.64%
# Discordant  DPP           SGLT               31       62.22%
#
# Concordant  DPP           DPP                17       37.78%
# Discordant  SGLT          DPP                28       56.36%
#
#
#  =========== Total number of samples assigned by the model VS Total number of samples in original test data
# DPP samples  10 49
# SGLT samples  91 52
#
#
# Category    Real value    Predicted value    Count    Percentage of Predicted cases
# ----------  ------------  -----------------  -------  -------------------------------
# Concordant  SGLT          SGLT               45       49.45%
# Discordant  DPP           SGLT               46       70.00%
#
# Concordant  DPP           DPP                3        30.00%
# Discordant  SGLT          DPP                7        50.55%
#
#
#  =========== Total number of samples assigned by the model VS Total number of samples in original test data
# DPP samples  48 49
# SGLT samples  53 52
#
#
# Category    Real value    Predicted value    Count    Percentage of Predicted cases
# ----------  ------------  -----------------  -------  -------------------------------
# Concordant  SGLT          SGLT               27       50.94%
# Discordant  DPP           SGLT               26       52.08%
#
# Concordant  DPP           DPP                23       47.92%
# Discordant  SGLT          DPP                25       49.06%
#
#
#  =========== Total number of samples assigned by the model VS Total number of samples in original test data
# DPP samples  5 49
# SGLT samples  96 52
#
#
# Category    Real value    Predicted value    Count    Percentage of Predicted cases
# ----------  ------------  -----------------  -------  -------------------------------
# Concordant  SGLT          SGLT               47       48.96%
# Discordant  DPP           SGLT               49       100.00%
#
# Concordant  DPP           DPP                0        0.00%
# Discordant  SGLT          DPP                5        51.04%
#
#
#
#  -------- Percentage HBA1C  ---------
# Category    Real value    Predicted value    Mean % Change from Baseline    std     treatment difference
# ----------  ------------  -----------------  -----------------------------  ------  ----------------------
# Concordant  SGLT          SGLT               -15.17%                        16.17%  -11.04%
# Discordant  DPP           SGLT               -4.13%                         15.61%
#
# Concordant  DPP           DPP                -3.18%                         9.25%   1.36
# Discordant  SGLT          DPP                -4.54%                         12.18%
#
#  -------- Percentage LDL  ---------
# Category    Real value    Predicted value    Mean % Change from Baseline    std    treatment difference
# ----------  ------------  -----------------  -----------------------------  -----  ----------------------
# Concordant  SGLT          SGLT               -0.30%                         0.91%  -0.17%
# Discordant  DPP           SGLT               -0.13%                         0.70%
#
# Concordant  DPP           DPP                -0.63%                         1.57%  -0.52
# Discordant  SGLT          DPP                -0.11%                         0.44%
#
#  -------- Percentage HDL  ---------
# Category    Real value    Predicted value    Mean % Change from Baseline    std    treatment difference
# ----------  ------------  -----------------  -----------------------------  -----  ----------------------
# Concordant  SGLT          SGLT               -0.00%                         0.16%  0.01%
# Discordant  DPP           SGLT               -0.02%                         0.24%
#
# Concordant  DPP           DPP                0.03%                          0.29%  0.00
# Discordant  SGLT          DPP                0.02%                          0.28%
#
#  -------- Percentage BMI  ---------
# Category    Real value    Predicted value    Mean % Change from Baseline    std    treatment difference
# ----------  ------------  -----------------  -----------------------------  -----  ----------------------
# Concordant  SGLT          SGLT               -1.19%                         2.88%  -1.41%
# Discordant  DPP           SGLT               0.22%                          2.74%
#
# Concordant  DPP           DPP                nan%                           nan%   nan
# Discordant  SGLT          DPP                -1.99%                         1.15%
# +----------------+-----------------+
# | Model          |   Test R2 Score |
# +================+=================+
# | RegressorChain |        0.384607 |
# +----------------+-----------------+
#
#
#
#
#
#
#
# ===============   12  features     ===================
#
# Shape of data after excluding missing response: (1566, 125)
# Shape of full data after selecting date range dates > 21 days (1084, 115)
# Shape of data after excluding missing response: (156, 125)
# Shape of full data after selecting date range dates > 21 days (102, 115)
# X_train shape:  (1077, 107)
# (1077, 107)
# {3.0, 4.0}
# [(3.0, 440), (4.0, 637)]
# [(3.0, 637), (4.0, 637)]
#
#
#
# ['P_Krea', 'bmi', 'drug_class', 'eGFR', 'gluk', 'hba1c_bl_18m', 'hba1c_bl_6m', 'hdl', 'ika', 'ldl', 'n_of_dis', 't2d_dur_y', 'trigly']
# Shape of training data before removing outliers: (1274, 13)
# Shape of test data before removing outliers: (101, 13)
# Training set outliers: [62, 340, 521, 762, 972, 252, 1060, 315, 826, 923, 938, 952, 1066, 145, 363, 565, 749, 1058, 1111]
# Testing set outliers: []
# Shape of training data after removing outliers: (1255, 13)
# Shape of test data after removing outliers: (101, 13)
# Cross validation variance 0.0003849303002765354
# Cross validation mean score 0.6315206374569836
# R2 score Training : 0.8394511015578552
# R2 score Testing: 0.4649
# RMSE: 5.340302
#  =========== Total number of samples assigned by the model VS Total number of samples in original test data
# DPP samples  42 49
# SGLT samples  59 52
#
#
# Category    Real value    Predicted value    Count    Percentage of Predicted cases
# ----------  ------------  -----------------  -------  -------------------------------
# Concordant  SGLT          SGLT               29       49.15%
# Discordant  DPP           SGLT               30       54.76%
#
# Concordant  DPP           DPP                19       45.24%
# Discordant  SGLT          DPP                23       50.85%
#
#
#  =========== Total number of samples assigned by the model VS Total number of samples in original test data
# DPP samples  12 49
# SGLT samples  89 52
#
#
# Category    Real value    Predicted value    Count    Percentage of Predicted cases
# ----------  ------------  -----------------  -------  -------------------------------
# Concordant  SGLT          SGLT               47       52.81%
# Discordant  DPP           SGLT               42       41.67%
#
# Concordant  DPP           DPP                7        58.33%
# Discordant  SGLT          DPP                5        47.19%
#
#
#  =========== Total number of samples assigned by the model VS Total number of samples in original test data
# DPP samples  85 49
# SGLT samples  14 52
#
#
# Category    Real value    Predicted value    Count    Percentage of Predicted cases
# ----------  ------------  -----------------  -------  -------------------------------
# Concordant  SGLT          SGLT               9        64.29%
# Discordant  DPP           SGLT               5        49.41%
#
# Concordant  DPP           DPP                43       50.59%
# Discordant  SGLT          DPP                42       35.71%
#
#
#  =========== Total number of samples assigned by the model VS Total number of samples in original test data
# DPP samples  6 49
# SGLT samples  95 52
#
#
# Category    Real value    Predicted value    Count    Percentage of Predicted cases
# ----------  ------------  -----------------  -------  -------------------------------
# Concordant  SGLT          SGLT               49       51.58%
# Discordant  DPP           SGLT               46       50.00%
#
# Concordant  DPP           DPP                3        50.00%
# Discordant  SGLT          DPP                3        48.42%
#
#
#
#  -------- Percentage HBA1C  ---------
# Category    Real value    Predicted value    Mean % Change from Baseline    std     treatment difference
# ----------  ------------  -----------------  -----------------------------  ------  ----------------------
# Concordant  SGLT          SGLT               -13.00%                        17.66%  -10.83%
# Discordant  DPP           SGLT               -2.17%                         11.71%
#
# Concordant  DPP           DPP                -7.16%                         16.07%  -2.20
# Discordant  SGLT          DPP                -4.96%                         9.33%
#
#  -------- Percentage LDL  ---------
# Category    Real value    Predicted value    Mean % Change from Baseline    std    treatment difference
# ----------  ------------  -----------------  -----------------------------  -----  ----------------------
# Concordant  SGLT          SGLT               -0.30%                         0.90%  -0.07%
# Discordant  DPP           SGLT               -0.23%                         0.78%
#
# Concordant  DPP           DPP                0.24%                          0.56%  0.30
# Discordant  SGLT          DPP                -0.06%                         0.25%
#
#  -------- Percentage HDL  ---------
# Category    Real value    Predicted value    Mean % Change from Baseline    std    treatment difference
# ----------  ------------  -----------------  -----------------------------  -----  ----------------------
# Concordant  SGLT          SGLT               0.07%                          0.15%  -0.10%
# Discordant  DPP           SGLT               0.17%                          0.27%
#
# Concordant  DPP           DPP                -0.01%                         0.26%  -0.01
# Discordant  SGLT          DPP                -0.00%                         0.24%
#
#  -------- Percentage BMI  ---------
# Category    Real value    Predicted value    Mean % Change from Baseline    std    treatment difference
# ----------  ------------  -----------------  -----------------------------  -----  ----------------------
# Concordant  SGLT          SGLT               -1.07%                         2.69%  -1.22%
# Discordant  DPP           SGLT               0.16%                          2.79%
#
# Concordant  DPP           DPP                1.15%                          1.71%  5.73
# Discordant  SGLT          DPP                -4.58%                         2.05%
# +----------------+-----------------+
# | Model          |   Test R2 Score |
# +================+=================+
# | RegressorChain |        0.464933 |
# +----------------+-----------------+
#
#
#
#
#
#
#
# ===============   15  features     ===================
#
# Shape of data after excluding missing response: (1566, 125)
# Shape of full data after selecting date range dates > 21 days (1084, 115)
# Shape of data after excluding missing response: (156, 125)
# Shape of full data after selecting date range dates > 21 days (102, 115)
# X_train shape:  (1077, 107)
# (1077, 107)
# {3.0, 4.0}
# [(3.0, 440), (4.0, 637)]
# [(3.0, 637), (4.0, 637)]
#
#
#
# ['MD_RCT_mmol_mol', 'P_Krea', 'bmi', 'drug_class', 'eGFR', 'gluk', 'hba1c_bl_18m', 'hba1c_bl_6m', 'hdl', 'ika', 'ldl', 'n_of_dis', 'smoking', 'sum_diab_drugs', 't2d_dur_y', 'trigly']
# Shape of training data before removing outliers: (1274, 16)
# Shape of test data before removing outliers: (101, 16)
# Training set outliers: [62, 340, 521, 762, 972, 1060, 315, 826, 923, 938, 952, 1066, 145, 363, 565, 749, 1058, 1111]
# Testing set outliers: []
# Shape of training data after removing outliers: (1256, 16)
# Shape of test data after removing outliers: (101, 16)
# Cross validation variance 7.919007549090501e-05
# Cross validation mean score 0.6370364246978598
# R2 score Training : 0.8437217837311796
# R2 score Testing: 0.4640
# RMSE: 5.399471
#  =========== Total number of samples assigned by the model VS Total number of samples in original test data
# DPP samples  27 49
# SGLT samples  73 52
#
#
# Category    Real value    Predicted value    Count    Percentage of Predicted cases
# ----------  ------------  -----------------  -------  -------------------------------
# Concordant  SGLT          SGLT               40       54.79%
# Discordant  DPP           SGLT               33       44.44%
#
# Concordant  DPP           DPP                15       55.56%
# Discordant  SGLT          DPP                12       45.21%
#
#
#  =========== Total number of samples assigned by the model VS Total number of samples in original test data
# DPP samples  15 49
# SGLT samples  86 52
#
#
# Category    Real value    Predicted value    Count    Percentage of Predicted cases
# ----------  ------------  -----------------  -------  -------------------------------
# Concordant  SGLT          SGLT               43       50.00%
# Discordant  DPP           SGLT               43       60.00%
#
# Concordant  DPP           DPP                6        40.00%
# Discordant  SGLT          DPP                9        50.00%
#
#
#  =========== Total number of samples assigned by the model VS Total number of samples in original test data
# DPP samples  68 49
# SGLT samples  31 52
#
#
# Category    Real value    Predicted value    Count    Percentage of Predicted cases
# ----------  ------------  -----------------  -------  -------------------------------
# Concordant  SGLT          SGLT               15       48.39%
# Discordant  DPP           SGLT               16       52.94%
#
# Concordant  DPP           DPP                32       47.06%
# Discordant  SGLT          DPP                36       51.61%
#
#
#  =========== Total number of samples assigned by the model VS Total number of samples in original test data
# DPP samples  8 49
# SGLT samples  93 52
#
#
# Category    Real value    Predicted value    Count    Percentage of Predicted cases
# ----------  ------------  -----------------  -------  -------------------------------
# Concordant  SGLT          SGLT               45       48.39%
# Discordant  DPP           SGLT               48       87.50%
#
# Concordant  DPP           DPP                1        12.50%
# Discordant  SGLT          DPP                7        51.61%
#
#
#
#  -------- Percentage HBA1C  ---------
# Category    Real value    Predicted value    Mean % Change from Baseline    std     treatment difference
# ----------  ------------  -----------------  -----------------------------  ------  ----------------------
# Concordant  SGLT          SGLT               -11.53%                        16.03%  -8.80%
# Discordant  DPP           SGLT               -2.73%                         11.85%
#
# Concordant  DPP           DPP                -3.33%                         8.93%   -0.83
# Discordant  SGLT          DPP                -2.50%                         8.01%
#
#  -------- Percentage LDL  ---------
# Category    Real value    Predicted value    Mean % Change from Baseline    std    treatment difference
# ----------  ------------  -----------------  -----------------------------  -----  ----------------------
# Concordant  SGLT          SGLT               -0.31%                         0.91%  -0.22%
# Discordant  DPP           SGLT               -0.09%                         0.69%
#
# Concordant  DPP           DPP                -0.67%                         1.14%  -0.57
# Discordant  SGLT          DPP                -0.10%                         0.60%
#
#  -------- Percentage HDL  ---------
# Category    Real value    Predicted value    Mean % Change from Baseline    std    treatment difference
# ----------  ------------  -----------------  -----------------------------  -----  ----------------------
# Concordant  SGLT          SGLT               0.06%                          0.12%  0.06%
# Discordant  DPP           SGLT               0.00%                          0.22%
#
# Concordant  DPP           DPP                0.01%                          0.28%  0.02
# Discordant  SGLT          DPP                -0.01%                         0.26%
#
#  -------- Percentage BMI  ---------
# Category    Real value    Predicted value    Mean % Change from Baseline    std    treatment difference
# ----------  ------------  -----------------  -----------------------------  -----  ----------------------
# Concordant  SGLT          SGLT               -1.42%                         2.40%  -1.64%
# Discordant  DPP           SGLT               0.22%                          2.76%
#
# Concordant  DPP           DPP                0.35%                          nan%   0.63
# Discordant  SGLT          DPP                -0.28%                         4.62%
# +----------------+-----------------+
# | Model          |   Test R2 Score |
# +================+=================+
# | RegressorChain |        0.464002 |
# +----------------+-----------------+
#
#
#
#
#
#
#
# ===============   20  features     ===================
#
# Shape of data after excluding missing response: (1566, 125)
# Shape of full data after selecting date range dates > 21 days (1084, 115)
# Shape of data after excluding missing response: (156, 125)
# Shape of full data after selecting date range dates > 21 days (102, 115)
# X_train shape:  (1077, 107)
# (1077, 107)
# {3.0, 4.0}
# [(3.0, 440), (4.0, 637)]
# [(3.0, 637), (4.0, 637)]
#
#
#
# ['C10A', 'MD_RCT_mmol_mol', 'P_Krea', 'bmi', 'comb_comp_enn', 'drug_class', 'eGFR', 'gluk', 'hba1c_bl_18m', 'hba1c_bl_6m', 'hdl', 'ika', 'insulin', 'ldl', 'met_oad0', 'n_of_dis', 'smoking', 'sum_diab_drugs', 't2d_dur_y', 'trigly']
# Shape of training data before removing outliers: (1274, 20)
# Shape of test data before removing outliers: (101, 20)
# Training set outliers: [62, 340, 521, 762, 972, 1060, 315, 468, 826, 923, 938, 952, 1066, 145, 363, 565, 749, 1058, 1111]
# Testing set outliers: []
# Shape of training data after removing outliers: (1255, 20)
# Shape of test data after removing outliers: (101, 20)
# Cross validation variance 0.0002216009076338734
# Cross validation mean score 0.6358937111085919
# R2 score Training : 0.8452505367192149
# R2 score Testing: 0.4734
# RMSE: 5.274348
#  =========== Total number of samples assigned by the model VS Total number of samples in original test data
# DPP samples  35 49
# SGLT samples  65 52
#
#
# Category    Real value    Predicted value    Count    Percentage of Predicted cases
# ----------  ------------  -----------------  -------  -------------------------------
# Concordant  SGLT          SGLT               33       50.77%
# Discordant  DPP           SGLT               32       54.29%
#
# Concordant  DPP           DPP                16       45.71%
# Discordant  SGLT          DPP                19       49.23%
#
#
#  =========== Total number of samples assigned by the model VS Total number of samples in original test data
# DPP samples  25 49
# SGLT samples  76 52
#
#
# Category    Real value    Predicted value    Count    Percentage of Predicted cases
# ----------  ------------  -----------------  -------  -------------------------------
# Concordant  SGLT          SGLT               36       47.37%
# Discordant  DPP           SGLT               40       64.00%
#
# Concordant  DPP           DPP                9        36.00%
# Discordant  SGLT          DPP                16       52.63%
#
#
#  =========== Total number of samples assigned by the model VS Total number of samples in original test data
# DPP samples  68 49
# SGLT samples  31 52
#
#
# Category    Real value    Predicted value    Count    Percentage of Predicted cases
# ----------  ------------  -----------------  -------  -------------------------------
# Concordant  SGLT          SGLT               15       48.39%
# Discordant  DPP           SGLT               16       52.94%
#
# Concordant  DPP           DPP                32       47.06%
# Discordant  SGLT          DPP                36       51.61%
#
#
#  =========== Total number of samples assigned by the model VS Total number of samples in original test data
# DPP samples  5 49
# SGLT samples  96 52
#
#
# Category    Real value    Predicted value    Count    Percentage of Predicted cases
# ----------  ------------  -----------------  -------  -------------------------------
# Concordant  SGLT          SGLT               48       50.00%
# Discordant  DPP           SGLT               48       80.00%
#
# Concordant  DPP           DPP                1        20.00%
# Discordant  SGLT          DPP                4        50.00%
#
#
#
#  -------- Percentage HBA1C  ---------
# Category    Real value    Predicted value    Mean % Change from Baseline    std     treatment difference
# ----------  ------------  -----------------  -----------------------------  ------  ----------------------
# Concordant  SGLT          SGLT               -12.30%                        16.80%  -9.58%
# Discordant  DPP           SGLT               -2.72%                         11.55%
#
# Concordant  DPP           DPP                -3.31%                         9.90%   1.16
# Discordant  SGLT          DPP                -4.47%                         9.74%
#
#  -------- Percentage LDL  ---------
# Category    Real value    Predicted value    Mean % Change from Baseline    std    treatment difference
# ----------  ------------  -----------------  -----------------------------  -----  ----------------------
# Concordant  SGLT          SGLT               -0.41%                         0.95%  -0.23%
# Discordant  DPP           SGLT               -0.18%                         0.82%
#
# Concordant  DPP           DPP                -0.09%                         0.49%  -0.11
# Discordant  SGLT          DPP                0.02%                          0.52%
#
#  -------- Percentage HDL  ---------
# Category    Real value    Predicted value    Mean % Change from Baseline    std    treatment difference
# ----------  ------------  -----------------  -----------------------------  -----  ----------------------
# Concordant  SGLT          SGLT               0.07%                          0.16%  0.08%
# Discordant  DPP           SGLT               -0.01%                         0.22%
#
# Concordant  DPP           DPP                0.01%                          0.29%  0.03
# Discordant  SGLT          DPP                -0.01%                         0.24%
#
#  -------- Percentage BMI  ---------
# Category    Real value    Predicted value    Mean % Change from Baseline    std    treatment difference
# ----------  ------------  -----------------  -----------------------------  -----  ----------------------
# Concordant  SGLT          SGLT               -1.15%                         2.72%  -1.36%
# Discordant  DPP           SGLT               0.22%                          2.76%
#
# Concordant  DPP           DPP                0.36%                          nan%   3.11
# Discordant  SGLT          DPP                -2.75%                         3.34%
# +----------------+-----------------+
# | Model          |   Test R2 Score |
# +================+=================+
# | RegressorChain |        0.473448 |
# +----------------+-----------------+
#
#
#
#
#
#
#
# ===============   22  features     ===================
#
# Shape of data after excluding missing response: (1566, 125)
# Shape of full data after selecting date range dates > 21 days (1084, 115)
# Shape of data after excluding missing response: (156, 125)
# Shape of full data after selecting date range dates > 21 days (102, 115)
# X_train shape:  (1077, 107)
# (1077, 107)
# {3.0, 4.0}
# [(3.0, 440), (4.0, 637)]
# [(3.0, 637), (4.0, 637)]
#
#
#
# ['C10A', 'MD_RCT_mmol_mol', 'P_Krea', 'T2D_nocomp', 'bmi', 'comb_comp_enn', 'drug_class', 'eGFR', 'gluk', 'hba1c_bl_18m', 'hba1c_bl_6m', 'hdl', 'ika', 'insulin', 'ldl', 'met_oad0', 'n_of_dis', 'renal_insuf', 'smoking', 'sum_diab_drugs', 't2d_dur_y', 'trigly']
# Shape of training data before removing outliers: (1274, 22)
# Shape of test data before removing outliers: (101, 22)
# Training set outliers: [62, 340, 521, 762, 972, 1060, 315, 468, 826, 923, 938, 952, 1066, 145, 363, 565, 749, 1058, 1111]
# Testing set outliers: []
# Shape of training data after removing outliers: (1255, 22)
# Shape of test data after removing outliers: (101, 22)
# Cross validation variance 0.00021744955810470902
# Cross validation mean score 0.6363598615833382
# R2 score Training : 0.846418069490694
# R2 score Testing: 0.4764
# RMSE: 5.286809
#  =========== Total number of samples assigned by the model VS Total number of samples in original test data
# DPP samples  39 49
# SGLT samples  61 52
#
#
# Category    Real value    Predicted value    Count    Percentage of Predicted cases
# ----------  ------------  -----------------  -------  -------------------------------
# Concordant  SGLT          SGLT               33       54.10%
# Discordant  DPP           SGLT               28       48.72%
#
# Concordant  DPP           DPP                20       51.28%
# Discordant  SGLT          DPP                19       45.90%
#
#
#  =========== Total number of samples assigned by the model VS Total number of samples in original test data
# DPP samples  30 49
# SGLT samples  71 52
#
#
# Category    Real value    Predicted value    Count    Percentage of Predicted cases
# ----------  ------------  -----------------  -------  -------------------------------
# Concordant  SGLT          SGLT               38       53.52%
# Discordant  DPP           SGLT               33       46.67%
#
# Concordant  DPP           DPP                16       53.33%
# Discordant  SGLT          DPP                14       46.48%
#
#
#  =========== Total number of samples assigned by the model VS Total number of samples in original test data
# DPP samples  67 49
# SGLT samples  33 52
#
#
# Category    Real value    Predicted value    Count    Percentage of Predicted cases
# ----------  ------------  -----------------  -------  -------------------------------
# Concordant  SGLT          SGLT               15       45.45%
# Discordant  DPP           SGLT               18       53.73%
#
# Concordant  DPP           DPP                31       46.27%
# Discordant  SGLT          DPP                36       54.55%
#
#
#  =========== Total number of samples assigned by the model VS Total number of samples in original test data
# DPP samples  5 49
# SGLT samples  96 52
#
#
# Category    Real value    Predicted value    Count    Percentage of Predicted cases
# ----------  ------------  -----------------  -------  -------------------------------
# Concordant  SGLT          SGLT               49       51.04%
# Discordant  DPP           SGLT               47       60.00%
#
# Concordant  DPP           DPP                2        40.00%
# Discordant  SGLT          DPP                3        48.96%
#
#
#
#  -------- Percentage HBA1C  ---------
# Category    Real value    Predicted value    Mean % Change from Baseline    std     treatment difference
# ----------  ------------  -----------------  -----------------------------  ------  ----------------------
# Concordant  SGLT          SGLT               -13.76%                        16.11%  -10.65%
# Discordant  DPP           SGLT               -3.11%                         12.15%
#
# Concordant  DPP           DPP                -2.65%                         9.25%   -0.70
# Discordant  SGLT          DPP                -1.95%                         9.10%
#
#  -------- Percentage LDL  ---------
# Category    Real value    Predicted value    Mean % Change from Baseline    std    treatment difference
# ----------  ------------  -----------------  -----------------------------  -----  ----------------------
# Concordant  SGLT          SGLT               -0.33%                         0.94%  -0.30%
# Discordant  DPP           SGLT               -0.02%                         0.75%
#
# Concordant  DPP           DPP                -0.44%                         0.73%  -0.32
# Discordant  SGLT          DPP                -0.13%                         0.63%
#
#  -------- Percentage HDL  ---------
# Category    Real value    Predicted value    Mean % Change from Baseline    std    treatment difference
# ----------  ------------  -----------------  -----------------------------  -----  ----------------------
# Concordant  SGLT          SGLT               0.03%                          0.23%  0.05%
# Discordant  DPP           SGLT               -0.02%                         0.23%
#
# Concordant  DPP           DPP                0.02%                          0.28%  0.01
# Discordant  SGLT          DPP                0.00%                          0.23%
#
#  -------- Percentage BMI  ---------
# Category    Real value    Predicted value    Mean % Change from Baseline    std    treatment difference
# ----------  ------------  -----------------  -----------------------------  -----  ----------------------
# Concordant  SGLT          SGLT               -1.19%                         2.82%  -1.38%
# Discordant  DPP           SGLT               0.18%                          2.77%
#
# Concordant  DPP           DPP                1.03%                          2.41%  3.54
# Discordant  SGLT          DPP                -2.51%                         0.89%
# +----------------+-----------------+
# | Model          |   Test R2 Score |
# +================+=================+
# | RegressorChain |        0.476435 |
# +----------------+-----------------+
