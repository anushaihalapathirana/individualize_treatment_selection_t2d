# %%
import os
import nbformat
from nbconvert.preprocessors import ExecutePreprocessor

# Set environment variable to disable file validation
os.environ['PYDEVD_DISABLE_FILE_VALIDATION'] = '1'

# Paths to the directories containing the .ipynb files
dir1 = '../best_models'
ensemble_notebook = 'ensemble_predictions_Majority.ipynb'

def run_notebook(notebook_path, notebook_dir=None):
    """
    Execute a Jupyter notebook (.ipynb file) and capture its output.

    Args:
    - notebook_path (str): Path to the .ipynb file to execute.
    - notebook_dir (str, optional): Directory path where the notebook should be executed.
                                    Defaults to None.

    Returns:
    - list: List of outputs generated by the notebook.
    """
    if notebook_dir is None:
        notebook_dir = os.path.dirname(notebook_path)

    try:
        with open(notebook_path) as f:
            nb = nbformat.read(f, as_version=4)
    except FileNotFoundError:
        print(f'Error: Notebook file not found at {notebook_path}')
        return None
    except Exception as e:
        print(f'Error reading the notebook {notebook_path}: {e}')
        return None
    
    ep = ExecutePreprocessor(timeout=600, kernel_name='python3')
    try:
        # Execute the notebook
        ep.preprocess(nb, {'metadata': {'path': notebook_dir}})
    except Exception as e:
        print(f'Error executing the notebook {notebook_path}: {e}')
        return None
    
    # Save the executed notebook back to file
    try:
        with open(notebook_path, 'w') as f:
            nbformat.write(nb, f)
    except Exception as e:
        print(f'Error saving executed notebook {notebook_path}: {e}')
    
    # Collecting the output of the notebook
    output_cells = [cell for cell in nb.cells if cell.cell_type == 'code']
    outputs = []
    for cell in output_cells:
        for output in cell.get('outputs', []):
            if output.output_type == 'stream':
                outputs.append(output.text.strip())
            elif output.output_type == 'execute_result':
                outputs.append(output['data']['text/plain'].strip())
            elif output.output_type == 'error':
                outputs.append(f"Error: {output['evalue']}")
    
    return outputs



# Function to find notebook paths in a directory
def find_notebooks(directory):
    return [os.path.join(directory, file) for file in os.listdir(directory) if file.endswith('.ipynb')]

# Get notebook paths in dir1
notebooks_dir1 = find_notebooks(dir1)


def print_outputs(output, search_val_1):

    for line in output:
        if search_val_1 in line:  # Replace "desired_value_prefix" with actual text to identify your value
            print(f'{line}')

# Execute the notebook in dir1 and then ensemble notebook
for notebook_path in notebooks_dir1:
    print(f'Running {notebook_path} \n')
    output1 = run_notebook(notebook_path, dir1)
    print_outputs(output1, 'R2')
    print_outputs(output1, 'treatment')

    # Execute the ensemble_notebook 
    print(f'\nRunning {ensemble_notebook} \n')
    output2 = run_notebook(ensemble_notebook)
    print_outputs(output2, 'Accuracy')
    print_outputs(output2, 'treatment')
    print('--------------------------------------------------------- \n\n')
# Out:
# Running ../best_models/Model 2-Copy5.ipynb
#
# R2 score Training : 0.8437217837311796
# R2 score Testing: 0.4640
# RMSE: 5.399471
# +----------------+-----------------+
# | Model          |   Test R2 Score |
# +================+=================+
# | RegressorChain |        0.464002 |
# +----------------+-----------------+
# ====== Percentage =========
# Category    Real value    Predicted value    Mean % Change from Baseline    std     treatment difference
# ----------  ------------  -----------------  -----------------------------  ------  ----------------------
# Concordant  SGLT          SGLT               -11.53%                        16.03%  -8.80%
# Discordant  DPP           SGLT               -2.73%                         11.85%
#
# Concordant  DPP           DPP                -3.33%                         8.93%   -0.83
# Discordant  SGLT          DPP                -2.50%                         8.01%
#
#
# ====== Percentage =========
# Category    Real value    Predicted value    Mean % Change from Baseline    std    treatment difference
# ----------  ------------  -----------------  -----------------------------  -----  ----------------------
# Concordant  SGLT          SGLT               -0.31%                         0.91%  -0.22%
# Discordant  DPP           SGLT               -0.09%                         0.69%
#
# Concordant  DPP           DPP                -0.67%                         1.14%  -0.57
# Discordant  SGLT          DPP                -0.10%                         0.60%
#
#
# ====== Percentage =========
# Category    Real value    Predicted value    Mean % Change from Baseline    std    treatment difference
# ----------  ------------  -----------------  -----------------------------  -----  ----------------------
# Concordant  SGLT          SGLT               0.06%                          0.12%  0.06%
# Discordant  DPP           SGLT               0.00%                          0.22%
#
# Concordant  DPP           DPP                0.01%                          0.28%  0.02
# Discordant  SGLT          DPP                -0.01%                         0.26%
#
#
# ====== Percentage =========
# Category    Real value    Predicted value    Mean % Change from Baseline    std    treatment difference
# ----------  ------------  -----------------  -----------------------------  -----  ----------------------
# Concordant  SGLT          SGLT               -1.42%                         2.40%  -1.64%
# Discordant  DPP           SGLT               0.22%                          2.76%
#
# Concordant  DPP           DPP                0.35%                          nan%   0.63
# Discordant  SGLT          DPP                -0.28%                         4.62%
#
# Running ensemble_predictions_Majority.ipynb
#
# ======= Majority vote model results =======
# Accuracy: 0.53
# F1 score: 0.505438008367766
# Precision: 0.5333333333333333
# Recall: 0.7692307692307693
# Confusion Matrix:
# [[14 35]
#  [12 40]]
# ======= Model based on regression model weights =======
# Optimal Threshold: 1.1425921330882347
# Accuracy: 0.50
# F1 score: 0.49306371315097614
# Precision: 0.5151515151515151
# Recall: 0.6538461538461539
# Confusion Matrix:
# [[17 32]
#  [18 34]]
# =========== Total number of samples assigned by the model VS Total number of samples in original test data
# DPP samples  26 49
# SGLT samples  75 52
#
#
# Category    Real value    Predicted value    Count    Percentage of Predicted cases
# ----------  ------------  -----------------  -------  -------------------------------
# Concordant  SGLT          SGLT               40       53.33%
# Discordant  DPP           SGLT               35       46.15%
#
# Concordant  DPP           DPP                14       53.85%
# Discordant  SGLT          DPP                12       46.67%
#
#
#
# ============= HBA1C ===================
# Category    Real value    Predicted value    Mean Change from Baseline    std     treatment difference
# ----------  ------------  -----------------  ---------------------------  ------  ----------------------
# Concordant  SGLT          SGLT               -11.525                      16.029  -8.554
# Discordant  DPP           SGLT               -2.971                       11.549
#
# Concordant  DPP           DPP                -6.929                       18.028  -4.429
# Discordant  SGLT          DPP                -2.500                       8.006
#
# ============= LDL ===================
# Category    Real value    Predicted value    Mean Change from Baseline    std    treatment difference
# ----------  ------------  -----------------  ---------------------------  -----  ----------------------
# Concordant  SGLT          SGLT               -0.220                       0.872  -0.149
# Discordant  DPP           SGLT               -0.071                       0.819
#
# Concordant  DPP           DPP                -0.386                       0.567  0.073
# Discordant  SGLT          DPP                -0.458                       0.839
#
# ============= HDL ===================
# Category    Real value    Predicted value    Mean Change from Baseline    std    treatment difference
# ----------  ------------  -----------------  ---------------------------  -----  ----------------------
# Concordant  SGLT          SGLT               0.026                        0.191  0.027
# Discordant  DPP           SGLT               -0.001                       0.274
#
# Concordant  DPP           DPP                0.011                        0.236  0.060
# Discordant  SGLT          DPP                -0.048                       0.310
#
# ============= BMI ===================
# Category    Real value    Predicted value    Mean Change from Baseline    std    treatment difference
# ----------  ------------  -----------------  ---------------------------  -----  ----------------------
# Concordant  SGLT          SGLT               -1.844                       2.354  -1.903
# Discordant  DPP           SGLT               0.059                        3.145
#
# Concordant  DPP           DPP                0.621                        1.229  -0.029
# Discordant  SGLT          DPP                0.650                        3.247
# =========== Total number of samples assigned by the model VS Total number of samples in original test data
# DPP samples  35 49
# SGLT samples  66 52
#
#
# Category    Real value    Predicted value    Count    Percentage of Predicted cases
# ----------  ------------  -----------------  -------  -------------------------------
# Concordant  SGLT          SGLT               34       51.52%
# Discordant  DPP           SGLT               32       51.43%
#
# Concordant  DPP           DPP                17       48.57%
# Discordant  SGLT          DPP                18       48.48%
#
#
#
# ============= HBA1C ===================
# Category    Real value    Predicted value    Mean Change from Baseline    std     treatment difference
# ----------  ------------  -----------------  ---------------------------  ------  ----------------------
# Concordant  SGLT          SGLT               -11.735                      16.939  -8.735
# Discordant  DPP           SGLT               -3.000                       10.940
#
# Concordant  DPP           DPP                -6.176                       17.844  -1.065
# Discordant  SGLT          DPP                -5.111                       9.368
#
# ============= LDL ===================
# Category    Real value    Predicted value    Mean Change from Baseline    std    treatment difference
# ----------  ------------  -----------------  ---------------------------  -----  ----------------------
# Concordant  SGLT          SGLT               -0.221                       0.930  -0.124
# Discordant  DPP           SGLT               -0.097                       0.849
#
# Concordant  DPP           DPP                -0.282                       0.575  0.095
# Discordant  SGLT          DPP                -0.378                       0.730
#
# ============= HDL ===================
# Category    Real value    Predicted value    Mean Change from Baseline    std    treatment difference
# ----------  ------------  -----------------  ---------------------------  -----  ----------------------
# Concordant  SGLT          SGLT               0.043                        0.178  0.051
# Discordant  DPP           SGLT               -0.008                       0.276
#
# Concordant  DPP           DPP                0.022                        0.237  0.078
# Discordant  SGLT          DPP                -0.056                       0.285
#
# ============= BMI ===================
# Category    Real value    Predicted value    Mean Change from Baseline    std    treatment difference
# ----------  ------------  -----------------  ---------------------------  -----  ----------------------
# Concordant  SGLT          SGLT               -1.827                       2.511  -1.859
# Discordant  DPP           SGLT               0.032                        3.284
#
# Concordant  DPP           DPP                0.571                        1.164  0.785
# Discordant  SGLT          DPP                -0.214                       2.978
# ---------------------------------------------------------
#
#
# Running ../best_models/Model 2-Copy7.ipynb
# R2 score Training : 0.8119853858072292
# R2 score Testing: 0.4666
# RMSE: 5.329325
# +----------------+-----------------+
# | Model          |   Test R2 Score |
# +================+=================+
# | RegressorChain |        0.466637 |
# +----------------+-----------------+
# ====== Percentage =========
# Category    Real value    Predicted value    Mean % Change from Baseline    std     treatment difference
# ----------  ------------  -----------------  -----------------------------  ------  ----------------------
# Concordant  SGLT          SGLT               -11.76%                        15.67%  -8.12%
# Discordant  DPP           SGLT               -3.64%                         11.75%
#
# Concordant  DPP           DPP                -1.33%                         9.01%   -0.52
# Discordant  SGLT          DPP                -0.82%                         7.86%
#
#
# ====== Percentage =========
# Category    Real value    Predicted value    Mean % Change from Baseline    std    treatment difference
# ----------  ------------  -----------------  -----------------------------  -----  ----------------------
# Concordant  SGLT          SGLT               -0.32%                         0.91%  -0.22%
# Discordant  DPP           SGLT               -0.10%                         0.66%
#
# Concordant  DPP           DPP                -0.68%                         1.38%  -0.61
# Discordant  SGLT          DPP                -0.07%                         0.59%
#
#
# ====== Percentage =========
# Category    Real value    Predicted value    Mean % Change from Baseline    std    treatment difference
# ----------  ------------  -----------------  -----------------------------  -----  ----------------------
# Concordant  SGLT          SGLT               0.07%                          0.11%  0.04%
# Discordant  DPP           SGLT               0.04%                          0.17%
#
# Concordant  DPP           DPP                -0.01%                         0.28%  0.01
# Discordant  SGLT          DPP                -0.01%                         0.26%
#
#
# ====== Percentage =========
# Category    Real value    Predicted value    Mean % Change from Baseline    std    treatment difference
# ----------  ------------  -----------------  -----------------------------  -----  ----------------------
# Concordant  SGLT          SGLT               -1.44%                         2.43%  -1.67%
# Discordant  DPP           SGLT               0.23%                          2.82%
#
# Concordant  DPP           DPP                0.13%                          0.71%  0.44
# Discordant  SGLT          DPP                -0.31%                         4.27%
#
# Running ensemble_predictions_Majority.ipynb
#
# ======= Majority vote model results =======
# Accuracy: 0.56
# F1 score: 0.5345531174739097
# Precision: 0.5526315789473685
# Recall: 0.8076923076923077
# Confusion Matrix:
# [[15 34]
#  [10 42]]
# ======= Model based on regression model weights =======
# Optimal Threshold: 1.265009949306025
# Accuracy: 0.50
# F1 score: 0.48727715350245665
# Precision: 0.5079365079365079
# Recall: 0.6153846153846154
# Confusion Matrix:
# [[18 31]
#  [20 32]]
# =========== Total number of samples assigned by the model VS Total number of samples in original test data
# DPP samples  25 49
# SGLT samples  76 52
#
#
# Category    Real value    Predicted value    Count    Percentage of Predicted cases
# ----------  ------------  -----------------  -------  -------------------------------
# Concordant  SGLT          SGLT               42       55.26%
# Discordant  DPP           SGLT               34       40.00%
#
# Concordant  DPP           DPP                15       60.00%
# Discordant  SGLT          DPP                10       44.74%
#
#
#
# ============= HBA1C ===================
# Category    Real value    Predicted value    Mean Change from Baseline    std     treatment difference
# ----------  ------------  -----------------  ---------------------------  ------  ----------------------
# Concordant  SGLT          SGLT               -11.571                      15.524  -8.189
# Discordant  DPP           SGLT               -3.382                       11.670
#
# Concordant  DPP           DPP                -5.733                       17.657  -5.233
# Discordant  SGLT          DPP                -0.500                       8.209
#
# ============= LDL ===================
# Category    Real value    Predicted value    Mean Change from Baseline    std    treatment difference
# ----------  ------------  -----------------  ---------------------------  -----  ----------------------
# Concordant  SGLT          SGLT               -0.252                       0.914  -0.161
# Discordant  DPP           SGLT               -0.091                       0.836
#
# Concordant  DPP           DPP                -0.320                       0.560  0.050
# Discordant  SGLT          DPP                -0.370                       0.631
#
# ============= HDL ===================
# Category    Real value    Predicted value    Mean Change from Baseline    std    treatment difference
# ----------  ------------  -----------------  ---------------------------  -----  ----------------------
# Concordant  SGLT          SGLT               0.003                        0.238  0.005
# Discordant  DPP           SGLT               -0.003                       0.276
#
# Concordant  DPP           DPP                0.014                        0.232  -0.021
# Discordant  SGLT          DPP                0.035                        0.152
#
# ============= BMI ===================
# Category    Real value    Predicted value    Mean Change from Baseline    std    treatment difference
# ----------  ------------  -----------------  ---------------------------  -----  ----------------------
# Concordant  SGLT          SGLT               -1.483                       2.958  -1.594
# Discordant  DPP           SGLT               0.110                        3.183
#
# Concordant  DPP           DPP                0.466                        1.295  0.833
# Discordant  SGLT          DPP                -0.367                       1.513
# =========== Total number of samples assigned by the model VS Total number of samples in original test data
# DPP samples  38 49
# SGLT samples  63 52
#
#
# Category    Real value    Predicted value    Count    Percentage of Predicted cases
# ----------  ------------  -----------------  -------  -------------------------------
# Concordant  SGLT          SGLT               32       50.79%
# Discordant  DPP           SGLT               31       52.63%
#
# Concordant  DPP           DPP                18       47.37%
# Discordant  SGLT          DPP                20       49.21%
#
#
#
# ============= HBA1C ===================
# Category    Real value    Predicted value    Mean Change from Baseline    std     treatment difference
# ----------  ------------  -----------------  ---------------------------  ------  ----------------------
# Concordant  SGLT          SGLT               -11.594                      17.042  -8.723
# Discordant  DPP           SGLT               -2.871                       11.451
#
# Concordant  DPP           DPP                -6.222                       16.900  -0.222
# Discordant  SGLT          DPP                -6.000                       10.483
#
# ============= LDL ===================
# Category    Real value    Predicted value    Mean Change from Baseline    std    treatment difference
# ----------  ------------  -----------------  ---------------------------  -----  ----------------------
# Concordant  SGLT          SGLT               -0.203                       0.932  -0.164
# Discordant  DPP           SGLT               -0.039                       0.823
#
# Concordant  DPP           DPP                -0.372                       0.614  0.018
# Discordant  SGLT          DPP                -0.390                       0.746
#
# ============= HDL ===================
# Category    Real value    Predicted value    Mean Change from Baseline    std    treatment difference
# ----------  ------------  -----------------  ---------------------------  -----  ----------------------
# Concordant  SGLT          SGLT               0.046                        0.180  0.062
# Discordant  DPP           SGLT               -0.016                       0.278
#
# Concordant  DPP           DPP                0.034                        0.234  0.085
# Discordant  SGLT          DPP                -0.051                       0.273
#
# ============= BMI ===================
# Category    Real value    Predicted value    Mean Change from Baseline    std    treatment difference
# ----------  ------------  -----------------  ---------------------------  -----  ----------------------
# Concordant  SGLT          SGLT               -1.710                       2.644  -1.937
# Discordant  DPP           SGLT               0.227                        3.284
#
# Concordant  DPP           DPP                0.206                        1.446  0.768
# Discordant  SGLT          DPP                -0.562                       2.870
# ---------------------------------------------------------
#
#
# Running ../best_models/Model 2-Copy3.ipynb
# R2 score Training : 0.9039086656104696
# R2 score Testing: 0.4681
# RMSE: 5.354380
# +----------------+-----------------+
# | Model          |   Test R2 Score |
# +================+=================+
# | RegressorChain |        0.468082 |
# +----------------+-----------------+
# ====== Percentage =========
# Category    Real value    Predicted value    Mean % Change from Baseline    std     treatment difference
# ----------  ------------  -----------------  -----------------------------  ------  ----------------------
# Concordant  SGLT          SGLT               -13.15%                        16.60%  -10.68%
# Discordant  DPP           SGLT               -2.47%                         12.12%
#
# Concordant  DPP           DPP                -7.22%                         16.00%  -4.22
# Discordant  SGLT          DPP                -3.00%                         8.86%
#
#
# ====== Percentage =========
# Category    Real value    Predicted value    Mean % Change from Baseline    std    treatment difference
# ----------  ------------  -----------------  -----------------------------  -----  ----------------------
# Concordant  SGLT          SGLT               -0.41%                         0.91%  -0.22%
# Discordant  DPP           SGLT               -0.19%                         0.82%
#
# Concordant  DPP           DPP                -0.04%                         0.46%  -0.21
# Discordant  SGLT          DPP                0.17%                          0.45%
#
#
# ====== Percentage =========
# Category    Real value    Predicted value    Mean % Change from Baseline    std    treatment difference
# ----------  ------------  -----------------  -----------------------------  -----  ----------------------
# Concordant  SGLT          SGLT               0.10%                          0.15%  0.07%
# Discordant  DPP           SGLT               0.03%                          0.17%
#
# Concordant  DPP           DPP                -0.00%                         0.30%  0.02
# Discordant  SGLT          DPP                -0.02%                         0.24%
#
#
# ====== Percentage =========
# Category    Real value    Predicted value    Mean % Change from Baseline    std    treatment difference
# ----------  ------------  -----------------  -----------------------------  -----  ----------------------
# Concordant  SGLT          SGLT               -1.08%                         2.71%  -1.43%
# Discordant  DPP           SGLT               0.35%                          2.80%
#
# Concordant  DPP           DPP                -0.90%                         1.92%  2.12
# Discordant  SGLT          DPP                -3.02%                         2.90%
#
# Running ensemble_predictions_Majority.ipynb
#
# ======= Majority vote model results =======
# Accuracy: 0.49
# F1 score: 0.4727862616770151
# Precision: 0.5
# Recall: 0.6346153846153846
# Confusion Matrix:
# [[16 33]
#  [19 33]]
# ======= Model based on regression model weights =======
# Optimal Threshold: 0.9943447692312207
# Accuracy: 0.46
# F1 score: 0.4532967650123994
# Precision: 0.47368421052631576
# Recall: 0.5192307692307693
# Confusion Matrix:
# [[19 30]
#  [25 27]]
# =========== Total number of samples assigned by the model VS Total number of samples in original test data
# DPP samples  35 49
# SGLT samples  66 52
#
#
# Category    Real value    Predicted value    Count    Percentage of Predicted cases
# ----------  ------------  -----------------  -------  -------------------------------
# Concordant  SGLT          SGLT               33       50.00%
# Discordant  DPP           SGLT               33       54.29%
#
# Concordant  DPP           DPP                16       45.71%
# Discordant  SGLT          DPP                19       50.00%
#
#
#
# ============= HBA1C ===================
# Category    Real value    Predicted value    Mean Change from Baseline    std     treatment difference
# ----------  ------------  -----------------  ---------------------------  ------  ----------------------
# Concordant  SGLT          SGLT               -12.788                      16.399  -9.697
# Discordant  DPP           SGLT               -3.091                       12.019
#
# Concordant  DPP           DPP                -6.188                       16.714  -2.556
# Discordant  SGLT          DPP                -3.632                       10.166
#
# ============= LDL ===================
# Category    Real value    Predicted value    Mean Change from Baseline    std    treatment difference
# ----------  ------------  -----------------  ---------------------------  -----  ----------------------
# Concordant  SGLT          SGLT               -0.191                       0.928  -0.161
# Discordant  DPP           SGLT               -0.030                       0.816
#
# Concordant  DPP           DPP                -0.431                       0.574  -0.010
# Discordant  SGLT          DPP                -0.421                       0.734
#
# ============= HDL ===================
# Category    Real value    Predicted value    Mean Change from Baseline    std    treatment difference
# ----------  ------------  -----------------  ---------------------------  -----  ----------------------
# Concordant  SGLT          SGLT               0.011                        0.246  0.005
# Discordant  DPP           SGLT               0.005                        0.276
#
# Concordant  DPP           DPP                -0.004                       0.236  -0.009
# Discordant  SGLT          DPP                0.005                        0.182
#
# ============= BMI ===================
# Category    Real value    Predicted value    Mean Change from Baseline    std    treatment difference
# ----------  ------------  -----------------  ---------------------------  -----  ----------------------
# Concordant  SGLT          SGLT               -1.705                       2.929  -1.840
# Discordant  DPP           SGLT               0.136                        3.248
#
# Concordant  DPP           DPP                0.392                        1.177  0.903
# Discordant  SGLT          DPP                -0.511                       2.330
# =========== Total number of samples assigned by the model VS Total number of samples in original test data
# DPP samples  44 49
# SGLT samples  57 52
#
#
# Category    Real value    Predicted value    Count    Percentage of Predicted cases
# ----------  ------------  -----------------  -------  -------------------------------
# Concordant  SGLT          SGLT               27       47.37%
# Discordant  DPP           SGLT               30       56.82%
#
# Concordant  DPP           DPP                19       43.18%
# Discordant  SGLT          DPP                25       52.63%
#
#
#
# ============= HBA1C ===================
# Category    Real value    Predicted value    Mean Change from Baseline    std     treatment difference
# ----------  ------------  -----------------  ---------------------------  ------  ----------------------
# Concordant  SGLT          SGLT               -12.852                      17.459  -9.252
# Discordant  DPP           SGLT               -3.600                       12.331
#
# Concordant  DPP           DPP                -4.895                       15.790  0.865
# Discordant  SGLT          DPP                -5.760                       10.990
#
# ============= LDL ===================
# Category    Real value    Predicted value    Mean Change from Baseline    std    treatment difference
# ----------  ------------  -----------------  ---------------------------  -----  ----------------------
# Concordant  SGLT          SGLT               -0.289                       0.976  -0.266
# Discordant  DPP           SGLT               -0.023                       0.856
#
# Concordant  DPP           DPP                -0.379                       0.541  -0.119
# Discordant  SGLT          DPP                -0.260                       0.740
#
# ============= HDL ===================
# Category    Real value    Predicted value    Mean Change from Baseline    std    treatment difference
# ----------  ------------  -----------------  ---------------------------  -----  ----------------------
# Concordant  SGLT          SGLT               0.057                        0.186  0.019
# Discordant  DPP           SGLT               0.038                        0.235
#
# Concordant  DPP           DPP                -0.054                       0.296  -0.011
# Discordant  SGLT          DPP                -0.043                       0.251
#
# ============= BMI ===================
# Category    Real value    Predicted value    Mean Change from Baseline    std    treatment difference
# ----------  ------------  -----------------  ---------------------------  -----  ----------------------
# Concordant  SGLT          SGLT               -1.967                       2.019  -2.187
# Discordant  DPP           SGLT               0.220                        3.328
#
# Concordant  DPP           DPP                0.219                        1.451  0.733
# Discordant  SGLT          DPP                -0.514                       3.266
# ---------------------------------------------------------
#
#
# Running ../best_models/Model 1.ipynb
# R2 score Training : 0.8846418700008112
# R2 score Testing: 0.4411
# RMSE: 5.586394
# +----------------+-----------------+
# | Model          |   Test R2 Score |
# +================+=================+
# | RegressorChain |        0.441075 |
# +----------------+-----------------+
# ====== Percentage =========
# Category    Real value    Predicted value    Mean % Change from Baseline    std     treatment difference
# ----------  ------------  -----------------  -----------------------------  ------  ----------------------
# Concordant  SGLT          SGLT               -13.45%                        17.27%  -10.92%
# Discordant  DPP           SGLT               -2.53%                         11.63%
#
# Concordant  DPP           DPP                -3.86%                         9.34%   -0.33
# Discordant  SGLT          DPP                -3.52%                         8.04%
#
#
# ====== Percentage =========
# Category    Real value    Predicted value    Mean % Change from Baseline    std    treatment difference
# ----------  ------------  -----------------  -----------------------------  -----  ----------------------
# Concordant  SGLT          SGLT               -0.60%                         0.97%  -0.46%
# Discordant  DPP           SGLT               -0.14%                         0.77%
#
# Concordant  DPP           DPP                -0.21%                         0.78%  -0.28
# Discordant  SGLT          DPP                0.08%                          0.56%
#
#
# ====== Percentage =========
# Category    Real value    Predicted value    Mean % Change from Baseline    std    treatment difference
# ----------  ------------  -----------------  -----------------------------  -----  ----------------------
# Concordant  SGLT          SGLT               0.04%                          0.11%  0.07%
# Discordant  DPP           SGLT               -0.02%                         0.23%
#
# Concordant  DPP           DPP                0.02%                          0.28%  0.02
# Discordant  SGLT          DPP                0.00%                          0.24%
#
#
# ====== Percentage =========
# Category    Real value    Predicted value    Mean % Change from Baseline    std    treatment difference
# ----------  ------------  -----------------  -----------------------------  -----  ----------------------
# Concordant  SGLT          SGLT               -1.65%                         2.37%  -1.98%
# Discordant  DPP           SGLT               0.33%                          3.11%
#
# Concordant  DPP           DPP                -0.12%                         0.92%  -0.67
# Discordant  SGLT          DPP                0.55%                          3.82%
#
# Running ensemble_predictions_Majority.ipynb
#
# ======= Majority vote model results =======
# Accuracy: 0.47
# F1 score: 0.45250881020305417
# Precision: 0.48484848484848486
# Recall: 0.6153846153846154
# Confusion Matrix:
# [[15 34]
#  [20 32]]
# ======= Model based on regression model weights =======
# Optimal Threshold: 1.628104318926101
# Accuracy: 0.43
# F1 score: 0.4196141353265762
# Precision: 0.425
# Recall: 0.3269230769230769
# Confusion Matrix:
# [[26 23]
#  [35 17]]
# =========== Total number of samples assigned by the model VS Total number of samples in original test data
# DPP samples  35 49
# SGLT samples  66 52
#
#
# Category    Real value    Predicted value    Count    Percentage of Predicted cases
# ----------  ------------  -----------------  -------  -------------------------------
# Concordant  SGLT          SGLT               32       48.48%
# Discordant  DPP           SGLT               34       57.14%
#
# Concordant  DPP           DPP                15       42.86%
# Discordant  SGLT          DPP                20       51.52%
#
#
#
# ============= HBA1C ===================
# Category    Real value    Predicted value    Mean Change from Baseline    std     treatment difference
# ----------  ------------  -----------------  ---------------------------  ------  ----------------------
# Concordant  SGLT          SGLT               -13.375                      17.404  -11.551
# Discordant  DPP           SGLT               -1.824                       10.861
#
# Concordant  DPP           DPP                -9.267                       17.822  -6.117
# Discordant  SGLT          DPP                -3.150                       6.491
#
# ============= LDL ===================
# Category    Real value    Predicted value    Mean Change from Baseline    std    treatment difference
# ----------  ------------  -----------------  ---------------------------  -----  ----------------------
# Concordant  SGLT          SGLT               -0.250                       0.822  -0.253
# Discordant  DPP           SGLT               0.003                        0.750
#
# Concordant  DPP           DPP                -0.533                       0.678  -0.218
# Discordant  SGLT          DPP                -0.315                       0.944
#
# ============= HDL ===================
# Category    Real value    Predicted value    Mean Change from Baseline    std    treatment difference
# ----------  ------------  -----------------  ---------------------------  -----  ----------------------
# Concordant  SGLT          SGLT               0.011                        0.205  0.025
# Discordant  DPP           SGLT               -0.014                       0.258
#
# Concordant  DPP           DPP                0.039                        0.275  0.034
# Discordant  SGLT          DPP                0.005                        0.255
#
# ============= BMI ===================
# Category    Real value    Predicted value    Mean Change from Baseline    std    treatment difference
# ----------  ------------  -----------------  ---------------------------  -----  ----------------------
# Concordant  SGLT          SGLT               -2.105                       2.227  -1.888
# Discordant  DPP           SGLT               -0.217                       2.578
#
# Concordant  DPP           DPP                1.209                        2.911  1.138
# Discordant  SGLT          DPP                0.070                        3.056
# =========== Total number of samples assigned by the model VS Total number of samples in original test data
# DPP samples  61 49
# SGLT samples  40 52
#
#
# Category    Real value    Predicted value    Count    Percentage of Predicted cases
# ----------  ------------  -----------------  -------  -------------------------------
# Concordant  SGLT          SGLT               17       42.50%
# Discordant  DPP           SGLT               23       57.38%
#
# Concordant  DPP           DPP                26       42.62%
# Discordant  SGLT          DPP                35       57.50%
#
#
#
# ============= HBA1C ===================
# Category    Real value    Predicted value    Mean Change from Baseline    std     treatment difference
# ----------  ------------  -----------------  ---------------------------  ------  ----------------------
# Concordant  SGLT          SGLT               -12.824                      18.736  -10.258
# Discordant  DPP           SGLT               -2.565                       12.310
#
# Concordant  DPP           DPP                -5.462                       14.806  2.338
# Discordant  SGLT          DPP                -7.800                       12.801
#
# ============= LDL ===================
# Category    Real value    Predicted value    Mean Change from Baseline    std    treatment difference
# ----------  ------------  -----------------  ---------------------------  -----  ----------------------
# Concordant  SGLT          SGLT               -0.429                       0.912  -0.455
# Discordant  DPP           SGLT               0.026                        0.699
#
# Concordant  DPP           DPP                -0.327                       0.793  -0.127
# Discordant  SGLT          DPP                -0.200                       0.840
#
# ============= HDL ===================
# Category    Real value    Predicted value    Mean Change from Baseline    std    treatment difference
# ----------  ------------  -----------------  ---------------------------  -----  ----------------------
# Concordant  SGLT          SGLT               0.025                        0.178  0.029
# Discordant  DPP           SGLT               -0.003                       0.210
#
# Concordant  DPP           DPP                0.008                        0.303  0.007
# Discordant  SGLT          DPP                0.001                        0.244
#
# ============= BMI ===================
# Category    Real value    Predicted value    Mean Change from Baseline    std    treatment difference
# ----------  ------------  -----------------  ---------------------------  -----  ----------------------
# Concordant  SGLT          SGLT               -1.732                       1.713  -1.536
# Discordant  DPP           SGLT               -0.196                       3.073
#
# Concordant  DPP           DPP                0.587                        2.399  1.630
# Discordant  SGLT          DPP                -1.043                       3.149
# ---------------------------------------------------------
#
#
# Running ../best_models/Model 2-Copy1.ipynb
# R2 score Training : 0.9055862865629846
# R2 score Testing: 0.4752
# RMSE: 5.383567
# +----------------+-----------------+
# | Model          |   Test R2 Score |
# +================+=================+
# | RegressorChain |        0.475191 |
# +----------------+-----------------+
# ====== Percentage =========
# Category    Real value    Predicted value    Mean % Change from Baseline    std     treatment difference
# ----------  ------------  -----------------  -----------------------------  ------  ----------------------
# Concordant  SGLT          SGLT               -14.39%                        15.70%  -10.81%
# Discordant  DPP           SGLT               -3.58%                         13.13%
#
# Concordant  DPP           DPP                -4.70%                         14.45%  -4.30
# Discordant  SGLT          DPP                -0.40%                         6.99%
#
#
# ====== Percentage =========
# Category    Real value    Predicted value    Mean % Change from Baseline    std    treatment difference
# ----------  ------------  -----------------  -----------------------------  -----  ----------------------
# Concordant  SGLT          SGLT               -0.35%                         0.92%  -0.19%
# Discordant  DPP           SGLT               -0.16%                         0.76%
#
# Concordant  DPP           DPP                -0.16%                         0.82%  -0.13
# Discordant  SGLT          DPP                -0.03%                         0.61%
#
#
# ====== Percentage =========
# Category    Real value    Predicted value    Mean % Change from Baseline    std    treatment difference
# ----------  ------------  -----------------  -----------------------------  -----  ----------------------
# Concordant  SGLT          SGLT               0.02%                          0.17%  0.01%
# Discordant  DPP           SGLT               0.01%                          0.14%
#
# Concordant  DPP           DPP                0.00%                          0.29%  0.01
# Discordant  SGLT          DPP                -0.01%                         0.25%
#
#
# ====== Percentage =========
# Category    Real value    Predicted value    Mean % Change from Baseline    std    treatment difference
# ----------  ------------  -----------------  -----------------------------  -----  ----------------------
# Concordant  SGLT          SGLT               -1.35%                         2.74%  -1.23%
# Discordant  DPP           SGLT               -0.12%                         2.38%
#
# Concordant  DPP           DPP                2.67%                          4.02%  3.31
# Discordant  SGLT          DPP                -0.64%                         3.15%
#
# Running ensemble_predictions_Majority.ipynb
#
# ======= Majority vote model results =======
# Accuracy: 0.56
# F1 score: 0.5605531981769605
# Precision: 0.5666666666666667
# Recall: 0.6538461538461539
# Confusion Matrix:
# [[23 26]
#  [18 34]]
# ======= Model based on regression model weights =======
# Optimal Threshold: 1.0069293585797652
# Accuracy: 0.54
# F1 score: 0.5446437584934964
# Precision: 0.56
# Recall: 0.5384615384615384
# Confusion Matrix:
# [[27 22]
#  [24 28]]
# =========== Total number of samples assigned by the model VS Total number of samples in original test data
# DPP samples  41 49
# SGLT samples  60 52
#
#
# Category    Real value    Predicted value    Count    Percentage of Predicted cases
# ----------  ------------  -----------------  -------  -------------------------------
# Concordant  SGLT          SGLT               34       56.67%
# Discordant  DPP           SGLT               26       43.90%
#
# Concordant  DPP           DPP                23       56.10%
# Discordant  SGLT          DPP                18       43.33%
#
#
#
# ============= HBA1C ===================
# Category    Real value    Predicted value    Mean Change from Baseline    std     treatment difference
# ----------  ------------  -----------------  ---------------------------  ------  ----------------------
# Concordant  SGLT          SGLT               -14.529                      15.636  -11.414
# Discordant  DPP           SGLT               -3.115                       13.149
#
# Concordant  DPP           DPP                -5.217                       14.365  -5.384
# Discordant  SGLT          DPP                0.167                        7.139
#
# ============= LDL ===================
# Category    Real value    Predicted value    Mean Change from Baseline    std    treatment difference
# ----------  ------------  -----------------  ---------------------------  -----  ----------------------
# Concordant  SGLT          SGLT               -0.324                       0.960  -0.347
# Discordant  DPP           SGLT               0.023                        0.810
#
# Concordant  DPP           DPP                -0.370                       0.665  -0.186
# Discordant  SGLT          DPP                -0.183                       0.654
#
# ============= HDL ===================
# Category    Real value    Predicted value    Mean Change from Baseline    std    treatment difference
# ----------  ------------  -----------------  ---------------------------  -----  ----------------------
# Concordant  SGLT          SGLT               0.013                        0.206  0.010
# Discordant  DPP           SGLT               0.002                        0.242
#
# Concordant  DPP           DPP                0.003                        0.287  0.001
# Discordant  SGLT          DPP                0.002                        0.258
#
# ============= BMI ===================
# Category    Real value    Predicted value    Mean Change from Baseline    std    treatment difference
# ----------  ------------  -----------------  ---------------------------  -----  ----------------------
# Concordant  SGLT          SGLT               -2.132                       2.228  -1.932
# Discordant  DPP           SGLT               -0.200                       2.871
#
# Concordant  DPP           DPP                0.693                        2.553  0.330
# Discordant  SGLT          DPP                0.363                        2.994
# =========== Total number of samples assigned by the model VS Total number of samples in original test data
# DPP samples  51 49
# SGLT samples  50 52
#
#
# Category    Real value    Predicted value    Count    Percentage of Predicted cases
# ----------  ------------  -----------------  -------  -------------------------------
# Concordant  SGLT          SGLT               28       56.00%
# Discordant  DPP           SGLT               22       47.06%
#
# Concordant  DPP           DPP                27       52.94%
# Discordant  SGLT          DPP                24       44.00%
#
#
#
# ============= HBA1C ===================
# Category    Real value    Predicted value    Mean Change from Baseline    std     treatment difference
# ----------  ------------  -----------------  ---------------------------  ------  ----------------------
# Concordant  SGLT          SGLT               -14.643                      17.069  -12.279
# Discordant  DPP           SGLT               -2.364                       13.340
#
# Concordant  DPP           DPP                -5.519                       13.949  -2.144
# Discordant  SGLT          DPP                -3.375                       9.254
#
# ============= LDL ===================
# Category    Real value    Predicted value    Mean Change from Baseline    std    treatment difference
# ----------  ------------  -----------------  ---------------------------  -----  ----------------------
# Concordant  SGLT          SGLT               -0.414                       0.994  -0.419
# Discordant  DPP           SGLT               0.005                        0.862
#
# Concordant  DPP           DPP                -0.296                       0.660  -0.184
# Discordant  SGLT          DPP                -0.113                       0.662
#
# ============= HDL ===================
# Category    Real value    Predicted value    Mean Change from Baseline    std    treatment difference
# ----------  ------------  -----------------  ---------------------------  -----  ----------------------
# Concordant  SGLT          SGLT               0.037                        0.202  0.035
# Discordant  DPP           SGLT               0.002                        0.259
#
# Concordant  DPP           DPP                0.003                        0.268  0.027
# Discordant  SGLT          DPP                -0.024                       0.246
#
# ============= BMI ===================
# Category    Real value    Predicted value    Mean Change from Baseline    std    treatment difference
# ----------  ------------  -----------------  ---------------------------  -----  ----------------------
# Concordant  SGLT          SGLT               -2.001                       2.147  -1.730
# Discordant  DPP           SGLT               -0.271                       3.089
#
# Concordant  DPP           DPP                0.619                        2.395  1.033
# Discordant  SGLT          DPP                -0.415                       3.179
# ---------------------------------------------------------
#
#
# Running ../best_models/Model 2-Copy6.ipynb
# R2 score Training : 0.8916126295766272
# R2 score Testing: 0.4719
# RMSE: 5.296218
# +----------------+-----------------+
# | Model          |   Test R2 Score |
# +================+=================+
# | RegressorChain |        0.471901 |
# +----------------+-----------------+
# ====== Percentage =========
# Category    Real value    Predicted value    Mean % Change from Baseline    std     treatment difference
# ----------  ------------  -----------------  -----------------------------  ------  ----------------------
# Concordant  SGLT          SGLT               -13.70%                        18.10%  -10.97%
# Discordant  DPP           SGLT               -2.73%                         12.07%
#
# Concordant  DPP           DPP                -6.05%                         15.58%  -1.21
# Discordant  SGLT          DPP                -4.84%                         8.98%
#
#
# ====== Percentage =========
# Category    Real value    Predicted value    Mean % Change from Baseline    std    treatment difference
# ----------  ------------  -----------------  -----------------------------  -----  ----------------------
# Concordant  SGLT          SGLT               -0.38%                         0.86%  -0.21%
# Discordant  DPP           SGLT               -0.17%                         0.79%
#
# Concordant  DPP           DPP                -0.13%                         0.70%  -0.26
# Discordant  SGLT          DPP                0.13%                          0.77%
#
#
# ====== Percentage =========
# Category    Real value    Predicted value    Mean % Change from Baseline    std    treatment difference
# ----------  ------------  -----------------  -----------------------------  -----  ----------------------
# Concordant  SGLT          SGLT               0.08%                          0.18%  0.02%
# Discordant  DPP           SGLT               0.06%                          0.15%
#
# Concordant  DPP           DPP                -0.01%                         0.30%  0.03
# Discordant  SGLT          DPP                -0.04%                         0.24%
#
#
# ====== Percentage =========
# Category    Real value    Predicted value    Mean % Change from Baseline    std    treatment difference
# ----------  ------------  -----------------  -----------------------------  -----  ----------------------
# Concordant  SGLT          SGLT               -1.30%                         2.24%  -1.27%
# Discordant  DPP           SGLT               -0.03%                         2.47%
#
# Concordant  DPP           DPP                1.33%                          3.68%  2.45
# Discordant  SGLT          DPP                -1.11%                         4.72%
#
# Running ensemble_predictions_Majority.ipynb
#
# ======= Majority vote model results =======
# Accuracy: 0.53
# F1 score: 0.5274907100904993
# Precision: 0.5396825396825397
# Recall: 0.6538461538461539
# Confusion Matrix:
# [[20 29]
#  [18 34]]
# ======= Model based on regression model weights =======
# Optimal Threshold: 1.2145268467025994
# Accuracy: 0.56
# F1 score: 0.5643564356435643
# Precision: 0.5769230769230769
# Recall: 0.5769230769230769
# Confusion Matrix:
# [[27 22]
#  [22 30]]
# =========== Total number of samples assigned by the model VS Total number of samples in original test data
# DPP samples  38 49
# ...
# Discordant  SGLT          DPP                -0.02%                         0.23%
#
#
# ====== Percentage =========
# Category    Real value    Predicted value    Mean % Change from Baseline    std    treatment difference
# ----------  ------------  -----------------  -----------------------------  -----  ----------------------
# Concordant  SGLT          SGLT               -1.13%                         2.92%  -1.29%
# Discordant  DPP           SGLT               0.15%                          2.91%
#
# Concordant  DPP           DPP                0.68%                          0.58%  2.84
# Discordant  SGLT          DPP                -2.16%                         1.22%
#
# Running ensemble_predictions_Majority.ipynb
#
# ======= Majority vote model results =======
# Accuracy: 0.55
# F1 score: 0.5513678186945513
# Precision: 0.559322033898305
# Recall: 0.6346153846153846
# Confusion Matrix:
# [[23 26]
#  [19 33]]
# ======= Model based on regression model weights =======
# Optimal Threshold: 0.995763071067458
# Accuracy: 0.54
# F1 score: 0.5446437584934964
# Precision: 0.56
# Recall: 0.5384615384615384
# Confusion Matrix:
# [[27 22]
#  [24 28]]
# =========== Total number of samples assigned by the model VS Total number of samples in original test data
# DPP samples  42 49
# SGLT samples  59 52
#
#
# Category    Real value    Predicted value    Count    Percentage of Predicted cases
# ----------  ------------  -----------------  -------  -------------------------------
# Concordant  SGLT          SGLT               33       55.93%
# Discordant  DPP           SGLT               26       45.24%
#
# Concordant  DPP           DPP                23       54.76%
# Discordant  SGLT          DPP                19       44.07%
#
#
#
# ============= HBA1C ===================
# Category    Real value    Predicted value    Mean Change from Baseline    std     treatment difference
# ----------  ------------  -----------------  ---------------------------  ------  ----------------------
# Concordant  SGLT          SGLT               -10.697                      14.415  -7.159
# Discordant  DPP           SGLT               -3.538                       16.207
#
# Concordant  DPP           DPP                -4.739                       10.297  2.524
# Discordant  SGLT          DPP                -7.263                       16.134
#
# ============= LDL ===================
# Category    Real value    Predicted value    Mean Change from Baseline    std    treatment difference
# ----------  ------------  -----------------  ---------------------------  -----  ----------------------
# Concordant  SGLT          SGLT               -0.227                       0.914  -0.131
# Discordant  DPP           SGLT               -0.096                       0.844
#
# Concordant  DPP           DPP                -0.235                       0.673  0.123
# Discordant  SGLT          DPP                -0.358                       0.782
#
# ============= HDL ===================
# Category    Real value    Predicted value    Mean Change from Baseline    std    treatment difference
# ----------  ------------  -----------------  ---------------------------  -----  ----------------------
# Concordant  SGLT          SGLT               0.042                        0.198  0.046
# Discordant  DPP           SGLT               -0.005                       0.237
#
# Concordant  DPP           DPP                0.010                        0.291  0.058
# Discordant  SGLT          DPP                -0.048                       0.257
#
# ============= BMI ===================
# Category    Real value    Predicted value    Mean Change from Baseline    std    treatment difference
# ----------  ------------  -----------------  ---------------------------  -----  ----------------------
# Concordant  SGLT          SGLT               -1.868                       2.293  -1.805
# Discordant  DPP           SGLT               -0.063                       2.892
#
# Concordant  DPP           DPP                0.539                        2.573  0.766
# Discordant  SGLT          DPP                -0.227                       3.238
# =========== Total number of samples assigned by the model VS Total number of samples in original test data
# DPP samples  51 49
# SGLT samples  50 52
#
#
# Category    Real value    Predicted value    Count    Percentage of Predicted cases
# ----------  ------------  -----------------  -------  -------------------------------
# Concordant  SGLT          SGLT               28       56.00%
# Discordant  DPP           SGLT               22       47.06%
#
# Concordant  DPP           DPP                27       52.94%
# Discordant  SGLT          DPP                24       44.00%
#
#
#
# ============= HBA1C ===================
# Category    Real value    Predicted value    Mean Change from Baseline    std     treatment difference
# ----------  ------------  -----------------  ---------------------------  ------  ----------------------
# Concordant  SGLT          SGLT               -10.964                      15.591  -6.919
# Discordant  DPP           SGLT               -4.045                       17.106
#
# Concordant  DPP           DPP                -4.148                       10.324  3.519
# Discordant  SGLT          DPP                -7.667                       14.406
#
# ============= LDL ===================
# Category    Real value    Predicted value    Mean Change from Baseline    std    treatment difference
# ----------  ------------  -----------------  ---------------------------  -----  ----------------------
# Concordant  SGLT          SGLT               -0.264                       0.984  -0.269
# Discordant  DPP           SGLT               0.005                        0.741
#
# Concordant  DPP           DPP                -0.296                       0.769  -0.009
# Discordant  SGLT          DPP                -0.288                       0.716
#
# ============= HDL ===================
# Category    Real value    Predicted value    Mean Change from Baseline    std    treatment difference
# ----------  ------------  -----------------  ---------------------------  -----  ----------------------
# Concordant  SGLT          SGLT               0.051                        0.201  0.050
# Discordant  DPP           SGLT               0.001                        0.250
#
# Concordant  DPP           DPP                0.003                        0.275  0.044
# Discordant  SGLT          DPP                -0.041                       0.241
#
# ============= BMI ===================
# Category    Real value    Predicted value    Mean Change from Baseline    std    treatment difference
# ----------  ------------  -----------------  ---------------------------  -----  ----------------------
# Concordant  SGLT          SGLT               -1.836                       2.457  -1.632
# Discordant  DPP           SGLT               -0.204                       3.112
#
# Concordant  DPP           DPP                0.564                        2.390  1.170
# Discordant  SGLT          DPP                -0.606                       2.999
# ---------------------------------------------------------
#
#
# Running ../best_models/Model 2.ipynb
# R2 score Training : 0.8432060255977087
# R2 score Testing: 0.4765
# RMSE: 5.262177
# +----------------+-----------------+
# | Model          |   Test R2 Score |
# +================+=================+
# | RegressorChain |        0.476485 |
# +----------------+-----------------+
# ====== Percentage =========
# Category    Real value    Predicted value    Mean % Change from Baseline    std     treatment difference
# ----------  ------------  -----------------  -----------------------------  ------  ----------------------
# Concordant  SGLT          SGLT               -14.93%                        17.01%  -12.62%
# Discordant  DPP           SGLT               -2.31%                         11.84%
#
# Concordant  DPP           DPP                -3.84%                         9.60%   -0.80
# Discordant  SGLT          DPP                -3.04%                         8.95%
#
#
# ====== Percentage =========
# Category    Real value    Predicted value    Mean % Change from Baseline    std    treatment difference
# ----------  ------------  -----------------  -----------------------------  -----  ----------------------
# Concordant  SGLT          SGLT               -0.35%                         0.89%  -0.21%
# Discordant  DPP           SGLT               -0.15%                         0.79%
#
# Concordant  DPP           DPP                -0.22%                         0.68%  -0.20
# Discordant  SGLT          DPP                -0.02%                         0.74%
#
#
# ====== Percentage =========
# Category    Real value    Predicted value    Mean % Change from Baseline    std    treatment difference
# ----------  ------------  -----------------  -----------------------------  -----  ----------------------
# Concordant  SGLT          SGLT               0.05%                          0.21%  0.06%
# Discordant  DPP           SGLT               -0.01%                         0.25%
#
# Concordant  DPP           DPP                0.01%                          0.27%  0.02
# Discordant  SGLT          DPP                -0.01%                         0.23%
#
#
# ====== Percentage =========
# Category    Real value    Predicted value    Mean % Change from Baseline    std    treatment difference
# ----------  ------------  -----------------  -----------------------------  -----  ----------------------
# Concordant  SGLT          SGLT               -1.19%                         2.85%  -1.24%
# Discordant  DPP           SGLT               0.06%                          2.37%
#
# Concordant  DPP           DPP                1.66%                          5.15%  3.93
# Discordant  SGLT          DPP                -2.27%                         1.14%
#
# Running ensemble_predictions_Majority.ipynb
#
# ======= Majority vote model results =======
# Accuracy: 0.50
# F1 score: 0.48448844884488446
# Precision: 0.5076923076923077
# Recall: 0.6346153846153846
# Confusion Matrix:
# [[17 32]
#  [19 33]]
# ======= Model based on regression model weights =======
# Optimal Threshold: 1.1033226884638758
# Accuracy: 0.45
# F1 score: 0.44258599773020774
# Precision: 0.46551724137931033
# Recall: 0.5192307692307693
# Confusion Matrix:
# [[18 31]
#  [25 27]]
# =========== Total number of samples assigned by the model VS Total number of samples in original test data
# DPP samples  36 49
# SGLT samples  65 52
#
#
# Category    Real value    Predicted value    Count    Percentage of Predicted cases
# ----------  ------------  -----------------  -------  -------------------------------
# Concordant  SGLT          SGLT               33       50.77%
# Discordant  DPP           SGLT               32       52.78%
#
# Concordant  DPP           DPP                17       47.22%
# Discordant  SGLT          DPP                19       49.23%
#
#
#
# ============= HBA1C ===================
# Category    Real value    Predicted value    Mean Change from Baseline    std     treatment difference
# ----------  ------------  -----------------  ---------------------------  ------  ----------------------
# Concordant  SGLT          SGLT               -12.697                      16.689  -10.228
# Discordant  DPP           SGLT               -2.469                       11.319
#
# Concordant  DPP           DPP                -7.176                       17.136  -3.387
# Discordant  SGLT          DPP                -3.789                       9.449
#
# ============= LDL ===================
# Category    Real value    Predicted value    Mean Change from Baseline    std    treatment difference
# ----------  ------------  -----------------  ---------------------------  -----  ----------------------
# Concordant  SGLT          SGLT               -0.164                       0.726  -0.173
# Discordant  DPP           SGLT               0.009                        0.806
#
# Concordant  DPP           DPP                -0.482                       0.569  -0.014
# Discordant  SGLT          DPP                -0.468                       1.053
#
# ============= HDL ===================
# Category    Real value    Predicted value    Mean Change from Baseline    std    treatment difference
# ----------  ------------  -----------------  ---------------------------  -----  ----------------------
# Concordant  SGLT          SGLT               0.030                        0.192  0.045
# Discordant  DPP           SGLT               -0.015                       0.297
#
# Concordant  DPP           DPP                0.035                        0.179  0.063
# Discordant  SGLT          DPP                -0.028                       0.271
#
# ============= BMI ===================
# Category    Real value    Predicted value    Mean Change from Baseline    std    treatment difference
# ----------  ------------  -----------------  ---------------------------  -----  ----------------------
# Concordant  SGLT          SGLT               -2.142                       2.051  -2.172
# Discordant  DPP           SGLT               0.030                        2.655
#
# Concordant  DPP           DPP                0.576                        2.929  0.327
# Discordant  SGLT          DPP                0.249                        3.214
# =========== Total number of samples assigned by the model VS Total number of samples in original test data
# DPP samples  43 49
# SGLT samples  58 52
#
#
# Category    Real value    Predicted value    Count    Percentage of Predicted cases
# ----------  ------------  -----------------  -------  -------------------------------
# Concordant  SGLT          SGLT               27       46.55%
# Discordant  DPP           SGLT               31       58.14%
#
# Concordant  DPP           DPP                18       41.86%
# Discordant  SGLT          DPP                25       53.45%
#
#
#
# ============= HBA1C ===================
# Category    Real value    Predicted value    Mean Change from Baseline    std     treatment difference
# ----------  ------------  -----------------  ---------------------------  ------  ----------------------
# Concordant  SGLT          SGLT               -12.111                      17.343  -9.176
# Discordant  DPP           SGLT               -2.935                       11.189
#
# Concordant  DPP           DPP                -6.111                       17.228  0.449
# Discordant  SGLT          DPP                -6.560                       11.648
#
# ============= LDL ===================
# Category    Real value    Predicted value    Mean Change from Baseline    std    treatment difference
# ----------  ------------  -----------------  ---------------------------  -----  ----------------------
# Concordant  SGLT          SGLT               -0.256                       0.717  -0.246
# Discordant  DPP           SGLT               -0.010                       0.812
#
# Concordant  DPP           DPP                -0.422                       0.608  -0.126
# Discordant  SGLT          DPP                -0.296                       1.011
#
# ============= HDL ===================
# Category    Real value    Predicted value    Mean Change from Baseline    std    treatment difference
# ----------  ------------  -----------------  ---------------------------  -----  ----------------------
# Concordant  SGLT          SGLT               0.035                        0.208  0.069
# Discordant  DPP           SGLT               -0.034                       0.281
#
# Concordant  DPP           DPP                0.065                        0.216  0.084
# Discordant  SGLT          DPP                -0.019                       0.239
#
# ============= BMI ===================
# Category    Real value    Predicted value    Mean Change from Baseline    std    treatment difference
# ----------  ------------  -----------------  ---------------------------  -----  ----------------------
# Concordant  SGLT          SGLT               -1.941                       1.971  -1.991
# Discordant  DPP           SGLT               0.050                        2.696
#
# Concordant  DPP           DPP                0.511                        2.855  1.053
# Discordant  SGLT          DPP                -0.542                       3.311
# ---------------------------------------------------------
