# %%
import os
import sys
import nbformat
from nbconvert.preprocessors import ExecutePreprocessor

sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '../../')))  

from constants import BEST_MODELS_NOTEBOOKS_DIRECTORY, ENSEMBLE_PYTHON_NOTEBOOK_PATH

# Set environment variable to disable file validation
os.environ['PYDEVD_DISABLE_FILE_VALIDATION'] = '1'

# Paths to the directories containing the .ipynb files
dir1 = '../../'+BEST_MODELS_NOTEBOOKS_DIRECTORY
ensemble_notebook = ENSEMBLE_PYTHON_NOTEBOOK_PATH

def run_notebook(notebook_path, notebook_dir=None):
    """
    Execute a Jupyter notebook (.ipynb file) and capture its output.

    Args:
    - notebook_path (str): Path to the .ipynb file to execute.
    - notebook_dir (str, optional): Directory path where the notebook should be executed.
                                    Defaults to None.

    Returns:
    - list: List of outputs generated by the notebook.
    """
    if notebook_dir is None:
        notebook_dir = os.path.dirname(notebook_path)

    try:
        with open(notebook_path) as f:
            nb = nbformat.read(f, as_version=4)
    except FileNotFoundError:
        print(f'Error: Notebook file not found at {notebook_path}')
        return None
    except Exception as e:
        print(f'Error reading the notebook {notebook_path}: {e}')
        return None
    
    ep = ExecutePreprocessor(timeout=600, kernel_name='python3')
    try:
        # Execute the notebook
        ep.preprocess(nb, {'metadata': {'path': notebook_dir}})
    except Exception as e:
        print(f'Error executing the notebook {notebook_path}: {e}')
        return None
    
    # Save the executed notebook back to file
    try:
        with open(notebook_path, 'w') as f:
            nbformat.write(nb, f)
    except Exception as e:
        print(f'Error saving executed notebook {notebook_path}: {e}')
    
    # Collecting the output of the notebook
    output_cells = [cell for cell in nb.cells if cell.cell_type == 'code']
    outputs = []
    for cell in output_cells:
        for output in cell.get('outputs', []):
            if output.output_type == 'stream':
                outputs.append(output.text.strip())
            elif output.output_type == 'execute_result':
                outputs.append(output['data']['text/plain'].strip())
            elif output.output_type == 'error':
                outputs.append(f"Error: {output['evalue']}")
    
    return outputs



# Function to find notebook paths in a directory
def find_notebooks(directory):
    return [os.path.join(directory, file) for file in os.listdir(directory) if file.endswith('.ipynb')]

# Get notebook paths in dir1
notebooks_dir1 = find_notebooks(dir1)

def print_outputs(output, search_val_1):

    for line in output:
        if search_val_1 in line:  # Replace "desired_value_prefix" with actual text to identify your value
            print(f'{line}')

# Execute the notebook in dir1 and then ensemble notebook
for notebook_path in notebooks_dir1:
    print(f'Running {notebook_path} \n')
    output1 = run_notebook(notebook_path, dir1)
    print_outputs(output1, 'R2')
    print_outputs(output1, 'treatment')

    # Execute the ensemble_notebook 
    print(f'\nRunning {ensemble_notebook} \n')
    output2 = run_notebook(ensemble_notebook)
    print_outputs(output2, 'Accuracy')
    print_outputs(output2, 'treatment')
    print('--------------------------------------------------------- \n\n')
# Out:
# Running ../../src/models/notebooks/Model 5.ipynb
#
# R2 score Training : 0.8985111644010326
# R2 score Testing: 0.4569
# RMSE: 5.521445
# +----------------+-----------------+
# | Model          |   Test R2 Score |
# +================+=================+
# | RegressorChain |        0.456898 |
# +----------------+-----------------+
# ====== Percentage =========
# Category    Real value    Predicted value    Mean Change from Baseline    std    treatment difference
# ----------  ------------  -----------------  ---------------------------  -----  ----------------------
# Concordant  SGLT          SGLT               -13.48                       14.41  -11.57
# Discordant  DPP           SGLT               -1.92                        12.64
#
# Concordant  DPP           DPP                -5.83                        14.65  -1.49
# Discordant  SGLT          DPP                -4.35                        14.45
#
#
# ====== Percentage =========
# Category    Real value    Predicted value    Mean Change from Baseline    std    treatment difference
# ----------  ------------  -----------------  ---------------------------  -----  ----------------------
# Concordant  SGLT          SGLT               -0.37                        0.91   -0.25
# Discordant  DPP           SGLT               -0.12                        0.75
#
# Concordant  DPP           DPP                -0.33                        0.84   -0.47
# Discordant  SGLT          DPP                0.14                         0.42
#
#
# ====== Percentage =========
# Category    Real value    Predicted value    Mean Change from Baseline    std    treatment difference
# ----------  ------------  -----------------  ---------------------------  -----  ----------------------
# Concordant  SGLT          SGLT               0.07                         0.21   0.09
# Discordant  DPP           SGLT               -0.02                        0.17
#
# Concordant  DPP           DPP                0.01                         0.28   0.03
# Discordant  SGLT          DPP                -0.02                        0.23
#
#
# ====== Percentage =========
# Category    Real value    Predicted value    Mean Change from Baseline    std    treatment difference
# ----------  ------------  -----------------  ---------------------------  -----  ----------------------
# Concordant  SGLT          SGLT               -1.13                        2.92   -1.29
# Discordant  DPP           SGLT               0.15                         2.91
#
# Concordant  DPP           DPP                0.68                         0.58   2.84
# Discordant  SGLT          DPP                -2.16                        1.22
#
# Running ensemble_models.ipynb
#
# ======= Majority vote model results =======
# Accuracy: 0.55
# F1 score: 0.5513678186945513
# Precision: 0.559322033898305
# Recall: 0.6346153846153846
# Confusion Matrix:
# [[23 26]
#  [19 33]]
# ======= Model based on regression model weights =======
# Optimal Threshold: 0.995763071067458
# Accuracy: 0.54
# F1 score: 0.5446437584934964
# Precision: 0.56
# Recall: 0.5384615384615384
# Confusion Matrix:
# [[27 22]
#  [24 28]]
# =========== Total number of samples assigned by the model VS Total number of samples in original test data
# DPP samples  42 49
# SGLT samples  59 52
#
#
# Category    Real value    Predicted value    Count    Percentage of Predicted cases
# ----------  ------------  -----------------  -------  -------------------------------
# Concordant  SGLT          SGLT               33       55.93%
# Discordant  DPP           SGLT               26       45.24%
#
# Concordant  DPP           DPP                23       54.76%
# Discordant  SGLT          DPP                19       44.07%
#
#
#
# ============= HBA1C ===================
# Category    Real value    Predicted value    Mean Change from Baseline    std    treatment difference
# ----------  ------------  -----------------  ---------------------------  -----  ----------------------
# Concordant  SGLT          SGLT               -10.70                       14.41  -7.16
# Discordant  DPP           SGLT               -3.54                        16.21
#
# Concordant  DPP           DPP                -4.74                        10.30  2.52
# Discordant  SGLT          DPP                -7.26                        16.13
#
# ============= LDL ===================
# Category    Real value    Predicted value    Mean Change from Baseline    std    treatment difference
# ----------  ------------  -----------------  ---------------------------  -----  ----------------------
# Concordant  SGLT          SGLT               -0.23                        0.91   -0.13
# Discordant  DPP           SGLT               -0.10                        0.84
#
# Concordant  DPP           DPP                -0.23                        0.67   0.12
# Discordant  SGLT          DPP                -0.36                        0.78
#
# ============= HDL ===================
# Category    Real value    Predicted value    Mean Change from Baseline    std    treatment difference
# ----------  ------------  -----------------  ---------------------------  -----  ----------------------
# Concordant  SGLT          SGLT               0.04                         0.20   0.05
# Discordant  DPP           SGLT               -0.00                        0.24
#
# Concordant  DPP           DPP                0.01                         0.29   0.06
# Discordant  SGLT          DPP                -0.05                        0.26
#
# ============= BMI ===================
# Category    Real value    Predicted value    Mean Change from Baseline    std    treatment difference
# ----------  ------------  -----------------  ---------------------------  -----  ----------------------
# Concordant  SGLT          SGLT               -1.87                        2.29   -1.80
# Discordant  DPP           SGLT               -0.06                        2.89
#
# Concordant  DPP           DPP                0.54                         2.57   0.77
# Discordant  SGLT          DPP                -0.23                        3.24
# =========== Total number of samples assigned by the model VS Total number of samples in original test data
# DPP samples  51 49
# SGLT samples  50 52
#
#
# Category    Real value    Predicted value    Count    Percentage of Predicted cases
# ----------  ------------  -----------------  -------  -------------------------------
# Concordant  SGLT          SGLT               28       56.00%
# Discordant  DPP           SGLT               22       47.06%
#
# Concordant  DPP           DPP                27       52.94%
# Discordant  SGLT          DPP                24       44.00%
#
#
#
# ============= HBA1C ===================
# Category    Real value    Predicted value    Mean Change from Baseline    std    treatment difference
# ----------  ------------  -----------------  ---------------------------  -----  ----------------------
# Concordant  SGLT          SGLT               -10.96                       15.59  -6.92
# Discordant  DPP           SGLT               -4.05                        17.11
#
# Concordant  DPP           DPP                -4.15                        10.32  3.52
# Discordant  SGLT          DPP                -7.67                        14.41
#
# ============= LDL ===================
# Category    Real value    Predicted value    Mean Change from Baseline    std    treatment difference
# ----------  ------------  -----------------  ---------------------------  -----  ----------------------
# Concordant  SGLT          SGLT               -0.26                        0.98   -0.27
# Discordant  DPP           SGLT               0.00                         0.74
#
# Concordant  DPP           DPP                -0.30                        0.77   -0.01
# Discordant  SGLT          DPP                -0.29                        0.72
#
# ============= HDL ===================
# Category    Real value    Predicted value    Mean Change from Baseline    std    treatment difference
# ----------  ------------  -----------------  ---------------------------  -----  ----------------------
# Concordant  SGLT          SGLT               0.05                         0.20   0.05
# Discordant  DPP           SGLT               0.00                         0.25
#
# Concordant  DPP           DPP                0.00                         0.28   0.04
# Discordant  SGLT          DPP                -0.04                        0.24
#
# ============= BMI ===================
# Category    Real value    Predicted value    Mean Change from Baseline    std    treatment difference
# ----------  ------------  -----------------  ---------------------------  -----  ----------------------
# Concordant  SGLT          SGLT               -1.84                        2.46   -1.63
# Discordant  DPP           SGLT               -0.20                        3.11
#
# Concordant  DPP           DPP                0.56                         2.39   1.17
# Discordant  SGLT          DPP                -0.61                        3.00
# ---------------------------------------------------------
#
#
# Running ../../src/models/notebooks/Model 7.ipynb
# R2 score Training : 0.8437217837311796
# R2 score Testing: 0.4640
# RMSE: 5.399471
# +----------------+-----------------+
# | Model          |   Test R2 Score |
# +================+=================+
# | RegressorChain |        0.464002 |
# +----------------+-----------------+
# ====== Percentage =========
# Category    Real value    Predicted value    Mean Change from Baseline    std    treatment difference
# ----------  ------------  -----------------  ---------------------------  -----  ----------------------
# Concordant  SGLT          SGLT               -11.53                       16.03  -8.80
# Discordant  DPP           SGLT               -2.73                        11.85
#
# Concordant  DPP           DPP                -3.33                        8.93   -0.83
# Discordant  SGLT          DPP                -2.50                        8.01
#
#
# ====== Percentage =========
# Category    Real value    Predicted value    Mean Change from Baseline    std    treatment difference
# ----------  ------------  -----------------  ---------------------------  -----  ----------------------
# Concordant  SGLT          SGLT               -0.31                        0.91   -0.22
# Discordant  DPP           SGLT               -0.09                        0.69
#
# Concordant  DPP           DPP                -0.67                        1.14   -0.57
# Discordant  SGLT          DPP                -0.10                        0.60
#
#
# ====== Percentage =========
# Category    Real value    Predicted value    Mean Change from Baseline    std    treatment difference
# ----------  ------------  -----------------  ---------------------------  -----  ----------------------
# Concordant  SGLT          SGLT               0.06                         0.12   0.06
# Discordant  DPP           SGLT               0.00                         0.22
#
# Concordant  DPP           DPP                0.01                         0.28   0.02
# Discordant  SGLT          DPP                -0.01                        0.26
#
#
# ====== Percentage =========
# Category    Real value    Predicted value    Mean Change from Baseline    std    treatment difference
# ----------  ------------  -----------------  ---------------------------  -----  ----------------------
# Concordant  SGLT          SGLT               -1.42                        2.40   -1.64
# Discordant  DPP           SGLT               0.22                         2.76
#
# Concordant  DPP           DPP                0.35                         nan    0.63
# Discordant  SGLT          DPP                -0.28                        4.62
#
# Running ensemble_models.ipynb
#
# ======= Majority vote model results =======
# Accuracy: 0.53
# F1 score: 0.505438008367766
# Precision: 0.5333333333333333
# Recall: 0.7692307692307693
# Confusion Matrix:
# [[14 35]
#  [12 40]]
# ======= Model based on regression model weights =======
# Optimal Threshold: 1.1425921330882347
# Accuracy: 0.50
# F1 score: 0.49306371315097614
# Precision: 0.5151515151515151
# Recall: 0.6538461538461539
# Confusion Matrix:
# [[17 32]
#  [18 34]]
# =========== Total number of samples assigned by the model VS Total number of samples in original test data
# DPP samples  26 49
# SGLT samples  75 52
#
#
# Category    Real value    Predicted value    Count    Percentage of Predicted cases
# ----------  ------------  -----------------  -------  -------------------------------
# Concordant  SGLT          SGLT               40       53.33%
# Discordant  DPP           SGLT               35       46.15%
#
# Concordant  DPP           DPP                14       53.85%
# Discordant  SGLT          DPP                12       46.67%
#
#
#
# ============= HBA1C ===================
# Category    Real value    Predicted value    Mean Change from Baseline    std    treatment difference
# ----------  ------------  -----------------  ---------------------------  -----  ----------------------
# Concordant  SGLT          SGLT               -11.53                       16.03  -8.55
# Discordant  DPP           SGLT               -2.97                        11.55
#
# Concordant  DPP           DPP                -6.93                        18.03  -4.43
# Discordant  SGLT          DPP                -2.50                        8.01
#
# ============= LDL ===================
# Category    Real value    Predicted value    Mean Change from Baseline    std    treatment difference
# ----------  ------------  -----------------  ---------------------------  -----  ----------------------
# Concordant  SGLT          SGLT               -0.22                        0.87   -0.15
# Discordant  DPP           SGLT               -0.07                        0.82
#
# Concordant  DPP           DPP                -0.39                        0.57   0.07
# Discordant  SGLT          DPP                -0.46                        0.84
#
# ============= HDL ===================
# Category    Real value    Predicted value    Mean Change from Baseline    std    treatment difference
# ----------  ------------  -----------------  ---------------------------  -----  ----------------------
# Concordant  SGLT          SGLT               0.03                         0.19   0.03
# Discordant  DPP           SGLT               -0.00                        0.27
#
# Concordant  DPP           DPP                0.01                         0.24   0.06
# Discordant  SGLT          DPP                -0.05                        0.31
#
# ============= BMI ===================
# Category    Real value    Predicted value    Mean Change from Baseline    std    treatment difference
# ----------  ------------  -----------------  ---------------------------  -----  ----------------------
# Concordant  SGLT          SGLT               -1.84                        2.35   -1.90
# Discordant  DPP           SGLT               0.06                         3.15
#
# Concordant  DPP           DPP                0.62                         1.23   -0.03
# Discordant  SGLT          DPP                0.65                         3.25
# =========== Total number of samples assigned by the model VS Total number of samples in original test data
# DPP samples  35 49
# SGLT samples  66 52
#
#
# Category    Real value    Predicted value    Count    Percentage of Predicted cases
# ----------  ------------  -----------------  -------  -------------------------------
# Concordant  SGLT          SGLT               34       51.52%
# Discordant  DPP           SGLT               32       51.43%
#
# Concordant  DPP           DPP                17       48.57%
# Discordant  SGLT          DPP                18       48.48%
#
#
#
# ============= HBA1C ===================
# Category    Real value    Predicted value    Mean Change from Baseline    std    treatment difference
# ----------  ------------  -----------------  ---------------------------  -----  ----------------------
# Concordant  SGLT          SGLT               -11.74                       16.94  -8.74
# Discordant  DPP           SGLT               -3.00                        10.94
#
# Concordant  DPP           DPP                -6.18                        17.84  -1.07
# Discordant  SGLT          DPP                -5.11                        9.37
#
# ============= LDL ===================
# Category    Real value    Predicted value    Mean Change from Baseline    std    treatment difference
# ----------  ------------  -----------------  ---------------------------  -----  ----------------------
# Concordant  SGLT          SGLT               -0.22                        0.93   -0.12
# Discordant  DPP           SGLT               -0.10                        0.85
#
# Concordant  DPP           DPP                -0.28                        0.57   0.10
# Discordant  SGLT          DPP                -0.38                        0.73
#
# ============= HDL ===================
# Category    Real value    Predicted value    Mean Change from Baseline    std    treatment difference
# ----------  ------------  -----------------  ---------------------------  -----  ----------------------
# Concordant  SGLT          SGLT               0.04                         0.18   0.05
# Discordant  DPP           SGLT               -0.01                        0.28
#
# Concordant  DPP           DPP                0.02                         0.24   0.08
# Discordant  SGLT          DPP                -0.06                        0.29
#
# ============= BMI ===================
# Category    Real value    Predicted value    Mean Change from Baseline    std    treatment difference
# ----------  ------------  -----------------  ---------------------------  -----  ----------------------
# Concordant  SGLT          SGLT               -1.83                        2.51   -1.86
# Discordant  DPP           SGLT               0.03                         3.28
#
# Concordant  DPP           DPP                0.57                         1.16   0.79
# Discordant  SGLT          DPP                -0.21                        2.98
# ---------------------------------------------------------
#
#
# Running ../../src/models/notebooks/Model 3.ipynb
# R2 score Training : 0.8432060255977087
# R2 score Testing: 0.4765
# RMSE: 5.262177
# +----------------+-----------------+
# | Model          |   Test R2 Score |
# +================+=================+
# | RegressorChain |        0.476485 |
# +----------------+-----------------+
# ====== Percentage =========
# Category    Real value    Predicted value    Mean Change from Baseline    std    treatment difference
# ----------  ------------  -----------------  ---------------------------  -----  ----------------------
# Concordant  SGLT          SGLT               -14.93                       17.01  -12.62
# Discordant  DPP           SGLT               -2.31                        11.84
#
# Concordant  DPP           DPP                -3.84                        9.60   -0.80
# Discordant  SGLT          DPP                -3.04                        8.95
#
#
# ====== Percentage =========
# Category    Real value    Predicted value    Mean Change from Baseline    std    treatment difference
# ----------  ------------  -----------------  ---------------------------  -----  ----------------------
# Concordant  SGLT          SGLT               -0.35                        0.89   -0.21
# Discordant  DPP           SGLT               -0.15                        0.79
#
# Concordant  DPP           DPP                -0.22                        0.68   -0.20
# Discordant  SGLT          DPP                -0.02                        0.74
#
#
# ====== Percentage =========
# Category    Real value    Predicted value    Mean Change from Baseline    std    treatment difference
# ----------  ------------  -----------------  ---------------------------  -----  ----------------------
# Concordant  SGLT          SGLT               0.05                         0.21   0.06
# Discordant  DPP           SGLT               -0.01                        0.25
#
# Concordant  DPP           DPP                0.01                         0.27   0.02
# Discordant  SGLT          DPP                -0.01                        0.23
#
#
# ====== Percentage =========
# Category    Real value    Predicted value    Mean Change from Baseline    std    treatment difference
# ----------  ------------  -----------------  ---------------------------  -----  ----------------------
# Concordant  SGLT          SGLT               -1.19                        2.85   -1.24
# Discordant  DPP           SGLT               0.06                         2.37
#
# Concordant  DPP           DPP                1.66                         5.15   3.93
# Discordant  SGLT          DPP                -2.27                        1.14
#
# Running ensemble_models.ipynb
#
# ======= Majority vote model results =======
# Accuracy: 0.50
# F1 score: 0.48448844884488446
# Precision: 0.5076923076923077
# Recall: 0.6346153846153846
# Confusion Matrix:
# [[17 32]
#  [19 33]]
# ======= Model based on regression model weights =======
# Optimal Threshold: 1.1033226884638758
# Accuracy: 0.45
# F1 score: 0.44258599773020774
# Precision: 0.46551724137931033
# Recall: 0.5192307692307693
# Confusion Matrix:
# [[18 31]
#  [25 27]]
# =========== Total number of samples assigned by the model VS Total number of samples in original test data
# DPP samples  36 49
# SGLT samples  65 52
#
#
# Category    Real value    Predicted value    Count    Percentage of Predicted cases
# ----------  ------------  -----------------  -------  -------------------------------
# Concordant  SGLT          SGLT               33       50.77%
# Discordant  DPP           SGLT               32       52.78%
#
# Concordant  DPP           DPP                17       47.22%
# Discordant  SGLT          DPP                19       49.23%
#
#
#
# ============= HBA1C ===================
# Category    Real value    Predicted value    Mean Change from Baseline    std    treatment difference
# ----------  ------------  -----------------  ---------------------------  -----  ----------------------
# Concordant  SGLT          SGLT               -12.70                       16.69  -10.23
# Discordant  DPP           SGLT               -2.47                        11.32
#
# Concordant  DPP           DPP                -7.18                        17.14  -3.39
# Discordant  SGLT          DPP                -3.79                        9.45
#
# ============= LDL ===================
# Category    Real value    Predicted value    Mean Change from Baseline    std    treatment difference
# ----------  ------------  -----------------  ---------------------------  -----  ----------------------
# Concordant  SGLT          SGLT               -0.16                        0.73   -0.17
# Discordant  DPP           SGLT               0.01                         0.81
#
# Concordant  DPP           DPP                -0.48                        0.57   -0.01
# Discordant  SGLT          DPP                -0.47                        1.05
#
# ============= HDL ===================
# Category    Real value    Predicted value    Mean Change from Baseline    std    treatment difference
# ----------  ------------  -----------------  ---------------------------  -----  ----------------------
# Concordant  SGLT          SGLT               0.03                         0.19   0.04
# Discordant  DPP           SGLT               -0.01                        0.30
#
# Concordant  DPP           DPP                0.03                         0.18   0.06
# Discordant  SGLT          DPP                -0.03                        0.27
#
# ============= BMI ===================
# Category    Real value    Predicted value    Mean Change from Baseline    std    treatment difference
# ----------  ------------  -----------------  ---------------------------  -----  ----------------------
# Concordant  SGLT          SGLT               -2.14                        2.05   -2.17
# Discordant  DPP           SGLT               0.03                         2.65
#
# Concordant  DPP           DPP                0.58                         2.93   0.33
# Discordant  SGLT          DPP                0.25                         3.21
# =========== Total number of samples assigned by the model VS Total number of samples in original test data
# DPP samples  43 49
# SGLT samples  58 52
#
#
# Category    Real value    Predicted value    Count    Percentage of Predicted cases
# ----------  ------------  -----------------  -------  -------------------------------
# Concordant  SGLT          SGLT               27       46.55%
# Discordant  DPP           SGLT               31       58.14%
#
# Concordant  DPP           DPP                18       41.86%
# Discordant  SGLT          DPP                25       53.45%
#
#
#
# ============= HBA1C ===================
# Category    Real value    Predicted value    Mean Change from Baseline    std    treatment difference
# ----------  ------------  -----------------  ---------------------------  -----  ----------------------
# Concordant  SGLT          SGLT               -12.11                       17.34  -9.18
# Discordant  DPP           SGLT               -2.94                        11.19
#
# Concordant  DPP           DPP                -6.11                        17.23  0.45
# Discordant  SGLT          DPP                -6.56                        11.65
#
# ============= LDL ===================
# Category    Real value    Predicted value    Mean Change from Baseline    std    treatment difference
# ----------  ------------  -----------------  ---------------------------  -----  ----------------------
# Concordant  SGLT          SGLT               -0.26                        0.72   -0.25
# Discordant  DPP           SGLT               -0.01                        0.81
#
# Concordant  DPP           DPP                -0.42                        0.61   -0.13
# Discordant  SGLT          DPP                -0.30                        1.01
#
# ============= HDL ===================
# Category    Real value    Predicted value    Mean Change from Baseline    std    treatment difference
# ----------  ------------  -----------------  ---------------------------  -----  ----------------------
# Concordant  SGLT          SGLT               0.03                         0.21   0.07
# Discordant  DPP           SGLT               -0.03                        0.28
#
# Concordant  DPP           DPP                0.07                         0.22   0.08
# Discordant  SGLT          DPP                -0.02                        0.24
#
# ============= BMI ===================
# Category    Real value    Predicted value    Mean Change from Baseline    std    treatment difference
# ----------  ------------  -----------------  ---------------------------  -----  ----------------------
# Concordant  SGLT          SGLT               -1.94                        1.97   -1.99
# Discordant  DPP           SGLT               0.05                         2.70
#
# Concordant  DPP           DPP                0.51                         2.86   1.05
# Discordant  SGLT          DPP                -0.54                        3.31
# ---------------------------------------------------------
#
#
# Running ../../src/models/notebooks/Model 1.ipynb
# R2 score Training : 0.8846418700008112
# R2 score Testing: 0.4411
# RMSE: 5.586394
# +----------------+-----------------+
# | Model          |   Test R2 Score |
# +================+=================+
# | RegressorChain |        0.441075 |
# +----------------+-----------------+
# ====== Percentage =========
# Category    Real value    Predicted value    Mean Change from Baseline    std    treatment difference
# ----------  ------------  -----------------  ---------------------------  -----  ----------------------
# Concordant  SGLT          SGLT               -13.45                       17.27  -10.92
# Discordant  DPP           SGLT               -2.53                        11.63
#
# Concordant  DPP           DPP                -3.86                        9.34   -0.33
# Discordant  SGLT          DPP                -3.52                        8.04
#
#
# ====== Percentage =========
# Category    Real value    Predicted value    Mean Change from Baseline    std    treatment difference
# ----------  ------------  -----------------  ---------------------------  -----  ----------------------
# Concordant  SGLT          SGLT               -0.60                        0.97   -0.46
# Discordant  DPP           SGLT               -0.14                        0.77
#
# Concordant  DPP           DPP                -0.21                        0.78   -0.28
# Discordant  SGLT          DPP                0.08                         0.56
#
#
# ====== Percentage =========
# Category    Real value    Predicted value    Mean Change from Baseline    std    treatment difference
# ----------  ------------  -----------------  ---------------------------  -----  ----------------------
# Concordant  SGLT          SGLT               0.04                         0.11   0.07
# Discordant  DPP           SGLT               -0.02                        0.23
#
# Concordant  DPP           DPP                0.02                         0.28   0.02
# Discordant  SGLT          DPP                0.00                         0.24
#
#
# ====== Percentage =========
# Category    Real value    Predicted value    Mean Change from Baseline    std    treatment difference
# ----------  ------------  -----------------  ---------------------------  -----  ----------------------
# Concordant  SGLT          SGLT               -1.65                        2.37   -1.98
# Discordant  DPP           SGLT               0.33                         3.11
#
# Concordant  DPP           DPP                -0.12                        0.92   -0.67
# Discordant  SGLT          DPP                0.55                         3.82
#
# Running ensemble_models.ipynb
#
# ======= Majority vote model results =======
# Accuracy: 0.47
# F1 score: 0.45250881020305417
# Precision: 0.48484848484848486
# Recall: 0.6153846153846154
# Confusion Matrix:
# [[15 34]
#  [20 32]]
# ======= Model based on regression model weights =======
# Optimal Threshold: 1.628104318926101
# Accuracy: 0.43
# F1 score: 0.4196141353265762
# Precision: 0.425
# Recall: 0.3269230769230769
# Confusion Matrix:
# [[26 23]
#  [35 17]]
# =========== Total number of samples assigned by the model VS Total number of samples in original test data
# DPP samples  35 49
# SGLT samples  66 52
#
#
# Category    Real value    Predicted value    Count    Percentage of Predicted cases
# ----------  ------------  -----------------  -------  -------------------------------
# Concordant  SGLT          SGLT               32       48.48%
# Discordant  DPP           SGLT               34       57.14%
#
# Concordant  DPP           DPP                15       42.86%
# Discordant  SGLT          DPP                20       51.52%
#
#
#
# ============= HBA1C ===================
# Category    Real value    Predicted value    Mean Change from Baseline    std    treatment difference
# ----------  ------------  -----------------  ---------------------------  -----  ----------------------
# Concordant  SGLT          SGLT               -13.38                       17.40  -11.55
# Discordant  DPP           SGLT               -1.82                        10.86
#
# Concordant  DPP           DPP                -9.27                        17.82  -6.12
# Discordant  SGLT          DPP                -3.15                        6.49
#
# ============= LDL ===================
# Category    Real value    Predicted value    Mean Change from Baseline    std    treatment difference
# ----------  ------------  -----------------  ---------------------------  -----  ----------------------
# Concordant  SGLT          SGLT               -0.25                        0.82   -0.25
# Discordant  DPP           SGLT               0.00                         0.75
#
# Concordant  DPP           DPP                -0.53                        0.68   -0.22
# Discordant  SGLT          DPP                -0.31                        0.94
#
# ============= HDL ===================
# Category    Real value    Predicted value    Mean Change from Baseline    std    treatment difference
# ----------  ------------  -----------------  ---------------------------  -----  ----------------------
# Concordant  SGLT          SGLT               0.01                         0.21   0.03
# Discordant  DPP           SGLT               -0.01                        0.26
#
# Concordant  DPP           DPP                0.04                         0.27   0.03
# Discordant  SGLT          DPP                0.00                         0.25
#
# ============= BMI ===================
# Category    Real value    Predicted value    Mean Change from Baseline    std    treatment difference
# ----------  ------------  -----------------  ---------------------------  -----  ----------------------
# Concordant  SGLT          SGLT               -2.11                        2.23   -1.89
# Discordant  DPP           SGLT               -0.22                        2.58
#
# Concordant  DPP           DPP                1.21                         2.91   1.14
# Discordant  SGLT          DPP                0.07                         3.06
# =========== Total number of samples assigned by the model VS Total number of samples in original test data
# DPP samples  61 49
# SGLT samples  40 52
#
#
# Category    Real value    Predicted value    Count    Percentage of Predicted cases
# ----------  ------------  -----------------  -------  -------------------------------
# Concordant  SGLT          SGLT               17       42.50%
# Discordant  DPP           SGLT               23       57.38%
#
# Concordant  DPP           DPP                26       42.62%
# Discordant  SGLT          DPP                35       57.50%
#
#
#
# ============= HBA1C ===================
# Category    Real value    Predicted value    Mean Change from Baseline    std    treatment difference
# ----------  ------------  -----------------  ---------------------------  -----  ----------------------
# Concordant  SGLT          SGLT               -12.82                       18.74  -10.26
# Discordant  DPP           SGLT               -2.57                        12.31
#
# Concordant  DPP           DPP                -5.46                        14.81  2.34
# Discordant  SGLT          DPP                -7.80                        12.80
#
# ============= LDL ===================
# Category    Real value    Predicted value    Mean Change from Baseline    std    treatment difference
# ----------  ------------  -----------------  ---------------------------  -----  ----------------------
# Concordant  SGLT          SGLT               -0.43                        0.91   -0.46
# Discordant  DPP           SGLT               0.03                         0.70
#
# Concordant  DPP           DPP                -0.33                        0.79   -0.13
# Discordant  SGLT          DPP                -0.20                        0.84
#
# ============= HDL ===================
# Category    Real value    Predicted value    Mean Change from Baseline    std    treatment difference
# ----------  ------------  -----------------  ---------------------------  -----  ----------------------
# Concordant  SGLT          SGLT               0.03                         0.18   0.03
# Discordant  DPP           SGLT               -0.00                        0.21
#
# Concordant  DPP           DPP                0.01                         0.30   0.01
# Discordant  SGLT          DPP                0.00                         0.24
#
# ============= BMI ===================
# Category    Real value    Predicted value    Mean Change from Baseline    std    treatment difference
# ----------  ------------  -----------------  ---------------------------  -----  ----------------------
# Concordant  SGLT          SGLT               -1.73                        1.71   -1.54
# Discordant  DPP           SGLT               -0.20                        3.07
#
# Concordant  DPP           DPP                0.59                         2.40   1.63
# Discordant  SGLT          DPP                -1.04                        3.15
# ---------------------------------------------------------
#
#
# Running ../../src/models/notebooks/Model 6.ipynb
# R2 score Training : 0.9039086656104696
# R2 score Testing: 0.4681
# RMSE: 5.354380
# +----------------+-----------------+
# | Model          |   Test R2 Score |
# +================+=================+
# | RegressorChain |        0.468082 |
# +----------------+-----------------+
# ====== Percentage =========
# Category    Real value    Predicted value    Mean Change from Baseline    std    treatment difference
# ----------  ------------  -----------------  ---------------------------  -----  ----------------------
# Concordant  SGLT          SGLT               -13.15                       16.60  -10.68
# Discordant  DPP           SGLT               -2.47                        12.12
#
# Concordant  DPP           DPP                -7.22                        16.00  -4.22
# Discordant  SGLT          DPP                -3.00                        8.86
#
#
# ====== Percentage =========
# Category    Real value    Predicted value    Mean Change from Baseline    std    treatment difference
# ----------  ------------  -----------------  ---------------------------  -----  ----------------------
# Concordant  SGLT          SGLT               -0.41                        0.91   -0.22
# Discordant  DPP           SGLT               -0.19                        0.82
#
# Concordant  DPP           DPP                -0.04                        0.46   -0.21
# Discordant  SGLT          DPP                0.17                         0.45
#
#
# ====== Percentage =========
# Category    Real value    Predicted value    Mean Change from Baseline    std    treatment difference
# ----------  ------------  -----------------  ---------------------------  -----  ----------------------
# Concordant  SGLT          SGLT               0.10                         0.15   0.07
# Discordant  DPP           SGLT               0.03                         0.17
#
# Concordant  DPP           DPP                -0.00                        0.30   0.02
# Discordant  SGLT          DPP                -0.02                        0.24
#
#
# ====== Percentage =========
# Category    Real value    Predicted value    Mean Change from Baseline    std    treatment difference
# ----------  ------------  -----------------  ---------------------------  -----  ----------------------
# Concordant  SGLT          SGLT               -1.08                        2.71   -1.43
# Discordant  DPP           SGLT               0.35                         2.80
#
# Concordant  DPP           DPP                -0.90                        1.92   2.12
# Discordant  SGLT          DPP                -3.02                        2.90
#
# Running ensemble_models.ipynb
#
# ======= Majority vote model results =======
# Accuracy: 0.49
# F1 score: 0.4727862616770151
# Precision: 0.5
# Recall: 0.6346153846153846
# Confusion Matrix:
# [[16 33]
#  [19 33]]
# ======= Model based on regression model weights =======
# Optimal Threshold: 0.9943447692312207
# Accuracy: 0.46
# F1 score: 0.4532967650123994
# Precision: 0.47368421052631576
# Recall: 0.5192307692307693
# Confusion Matrix:
# [[19 30]
#  [25 27]]
# =========== Total number of samples assigned by the model VS Total number of samples in original test data
# DPP samples  35 49
# SGLT samples  66 52
#
#
# Category    Real value    Predicted value    Count    Percentage of Predicted cases
# ----------  ------------  -----------------  -------  -------------------------------
# Concordant  SGLT          SGLT               33       50.00%
# Discordant  DPP           SGLT               33       54.29%
#
# Concordant  DPP           DPP                16       45.71%
# Discordant  SGLT          DPP                19       50.00%
#
#
#
# ============= HBA1C ===================
# Category    Real value    Predicted value    Mean Change from Baseline    std    treatment difference
# ----------  ------------  -----------------  ---------------------------  -----  ----------------------
# Concordant  SGLT          SGLT               -12.79                       16.40  -9.70
# Discordant  DPP           SGLT               -3.09                        12.02
#
# Concordant  DPP           DPP                -6.19                        16.71  -2.56
# Discordant  SGLT          DPP                -3.63                        10.17
#
# ============= LDL ===================
# Category    Real value    Predicted value    Mean Change from Baseline    std    treatment difference
# ----------  ------------  -----------------  ---------------------------  -----  ----------------------
# Concordant  SGLT          SGLT               -0.19                        0.93   -0.16
# Discordant  DPP           SGLT               -0.03                        0.82
#
# Concordant  DPP           DPP                -0.43                        0.57   -0.01
# Discordant  SGLT          DPP                -0.42                        0.73
#
# ============= HDL ===================
# Category    Real value    Predicted value    Mean Change from Baseline    std    treatment difference
# ----------  ------------  -----------------  ---------------------------  -----  ----------------------
# Concordant  SGLT          SGLT               0.01                         0.25   0.01
# Discordant  DPP           SGLT               0.01                         0.28
#
# Concordant  DPP           DPP                -0.00                        0.24   -0.01
# Discordant  SGLT          DPP                0.01                         0.18
#
# ============= BMI ===================
# Category    Real value    Predicted value    Mean Change from Baseline    std    treatment difference
# ----------  ------------  -----------------  ---------------------------  -----  ----------------------
# Concordant  SGLT          SGLT               -1.70                        2.93   -1.84
# Discordant  DPP           SGLT               0.14                         3.25
#
# Concordant  DPP           DPP                0.39                         1.18   0.90
# Discordant  SGLT          DPP                -0.51                        2.33
# =========== Total number of samples assigned by the model VS Total number of samples in original test data
# DPP samples  44 49
# SGLT samples  57 52
#
#
# Category    Real value    Predicted value    Count    Percentage of Predicted cases
# ----------  ------------  -----------------  -------  -------------------------------
# Concordant  SGLT          SGLT               27       47.37%
# Discordant  DPP           SGLT               30       56.82%
#
# Concordant  DPP           DPP                19       43.18%
# Discordant  SGLT          DPP                25       52.63%
#
#
#
# ============= HBA1C ===================
# Category    Real value    Predicted value    Mean Change from Baseline    std    treatment difference
# ----------  ------------  -----------------  ---------------------------  -----  ----------------------
# Concordant  SGLT          SGLT               -12.85                       17.46  -9.25
# Discordant  DPP           SGLT               -3.60                        12.33
#
# Concordant  DPP           DPP                -4.89                        15.79  0.87
# Discordant  SGLT          DPP                -5.76                        10.99
#
# ============= LDL ===================
# Category    Real value    Predicted value    Mean Change from Baseline    std    treatment difference
# ----------  ------------  -----------------  ---------------------------  -----  ----------------------
# Concordant  SGLT          SGLT               -0.29                        0.98   -0.27
# Discordant  DPP           SGLT               -0.02                        0.86
#
# Concordant  DPP           DPP                -0.38                        0.54   -0.12
# Discordant  SGLT          DPP                -0.26                        0.74
#
# ============= HDL ===================
# Category    Real value    Predicted value    Mean Change from Baseline    std    treatment difference
# ----------  ------------  -----------------  ---------------------------  -----  ----------------------
# Concordant  SGLT          SGLT               0.06                         0.19   0.02
# Discordant  DPP           SGLT               0.04                         0.23
#
# Concordant  DPP           DPP                -0.05                        0.30   -0.01
# Discordant  SGLT          DPP                -0.04                        0.25
#
# ============= BMI ===================
# Category    Real value    Predicted value    Mean Change from Baseline    std    treatment difference
# ----------  ------------  -----------------  ---------------------------  -----  ----------------------
# Concordant  SGLT          SGLT               -1.97                        2.02   -2.19
# Discordant  DPP           SGLT               0.22                         3.33
#
# Concordant  DPP           DPP                0.22                         1.45   0.73
# Discordant  SGLT          DPP                -0.51                        3.27
# ---------------------------------------------------------
#
#
# Running ../../src/models/notebooks/Model 4.ipynb
# R2 score Training : 0.9059176930230368
# R2 score Testing: 0.4676
# RMSE: 5.382233
# +----------------+-----------------+
# | Model          |   Test R2 Score |
# +================+=================+
# | RegressorChain |        0.467612 |
# +----------------+-----------------+
# ====== Percentage =========
# Category    Real value    Predicted value    Mean Change from Baseline    std    treatment difference
# ----------  ------------  -----------------  ---------------------------  -----  ----------------------
# Concordant  SGLT          SGLT               -16.10                       15.93  -13.51
# Discordant  DPP           SGLT               -2.59                        11.74
#
# Concordant  DPP           DPP                -7.56                        16.99  -6.93
# Discordant  SGLT          DPP                -0.64                        8.11
#
#
# ====== Percentage =========
# Category    Real value    Predicted value    Mean Change from Baseline    std    treatment difference
# ----------  ------------  -----------------  ---------------------------  -----  ----------------------
# Concordant  SGLT          SGLT               -0.33                        0.96   -0.21
# Discordant  DPP           SGLT               -0.12                        0.80
#
# Concordant  DPP           DPP                -0.25                        0.70   -0.05
# Discordant  SGLT          DPP                -0.20                        0.71
#
#
# ====== Percentage =========
# Category    Real value    Predicted value    Mean Change from Baseline    std    treatment difference
# ----------  ------------  -----------------  ---------------------------  -----  ----------------------
# Concordant  SGLT          SGLT               0.03                         0.18   0.14
# Discordant  DPP           SGLT               -0.12                        0.33
#
# Concordant  DPP           DPP                0.04                         0.23   0.01
# Discordant  SGLT          DPP                0.03                         0.19
#
#
# ====== Percentage =========
# Category    Real value    Predicted value    Mean Change from Baseline    std    treatment difference
# ----------  ------------  -----------------  ---------------------------  -----  ----------------------
# Concordant  SGLT          SGLT               -1.20                        2.85   -1.42
# Discordant  DPP           SGLT               0.22                         2.90
#
# Concordant  DPP           DPP                0.19                         1.04   2.32
# Discordant  SGLT          DPP                -2.13                        1.13
#
# Running ensemble_models.ipynb
#
# ======= Majority vote model results =======
# Accuracy: 0.47
# F1 score: 0.4556996196812945
# Precision: 0.484375
# Recall: 0.5961538461538461
# Confusion Matrix:
# [[16 33]
#  [21 31]]
# ======= Model based on regression model weights =======
# Optimal Threshold: 0.9282513622891805
# Accuracy: 0.45
# F1 score: 0.44336509122610374
# Precision: 0.45454545454545453
# Recall: 0.38461538461538464
# Confusion Matrix:
# [[25 24]
#  [32 20]]
# =========== Total number of samples assigned by the model VS Total number of samples in original test data
# DPP samples  37 49
# SGLT samples  64 52
#
#
# Category    Real value    Predicted value    Count    Percentage of Predicted cases
# ----------  ------------  -----------------  -------  -------------------------------
# Concordant  SGLT          SGLT               31       48.44%
# Discordant  DPP           SGLT               33       56.76%
#
# Concordant  DPP           DPP                16       43.24%
# Discordant  SGLT          DPP                21       51.56%
#
#
#
# ============= HBA1C ===================
# Category    Real value    Predicted value    Mean Change from Baseline    std    treatment difference
# ...
# Concordant  SGLT          SGLT               0.08                         0.20   0.04
# Discordant  DPP           SGLT               0.04                         0.24
#
# Concordant  DPP           DPP                0.01                         0.24   0.01
# Discordant  SGLT          DPP                0.00                         0.17
#
#
# ====== Percentage =========
# Category    Real value    Predicted value    Mean Change from Baseline    std    treatment difference
# ----------  ------------  -----------------  ---------------------------  -----  ----------------------
# Concordant  SGLT          SGLT               -1.15                        2.72   -1.38
# Discordant  DPP           SGLT               0.23                         2.72
#
# Concordant  DPP           DPP                -0.41                        1.98   1.97
# Discordant  SGLT          DPP                -2.39                        3.21
#
# Running ensemble_models.ipynb
#
# ======= Majority vote model results =======
# Accuracy: 0.55
# F1 score: 0.5532305807900377
# Precision: 0.5777777777777777
# Recall: 0.5
# Confusion Matrix:
# [[30 19]
#  [26 26]]
# ======= Model based on regression model weights =======
# Optimal Threshold: 1.070854060595116
# Accuracy: 0.52
# F1 score: 0.5196806637185457
# Precision: 0.55
# Recall: 0.4230769230769231
# Confusion Matrix:
# [[31 18]
#  [30 22]]
# =========== Total number of samples assigned by the model VS Total number of samples in original test data
# DPP samples  56 49
# SGLT samples  45 52
#
#
# Category    Real value    Predicted value    Count    Percentage of Predicted cases
# ----------  ------------  -----------------  -------  -------------------------------
# Concordant  SGLT          SGLT               26       57.78%
# Discordant  DPP           SGLT               19       46.43%
#
# Concordant  DPP           DPP                30       53.57%
# Discordant  SGLT          DPP                26       42.22%
#
#
#
# ============= HBA1C ===================
# Category    Real value    Predicted value    Mean Change from Baseline    std    treatment difference
# ----------  ------------  -----------------  ---------------------------  -----  ----------------------
# Concordant  SGLT          SGLT               -17.00                       15.46  -14.68
# Discordant  DPP           SGLT               -2.32                        13.42
#
# Concordant  DPP           DPP                -5.23                        13.87  -3.35
# Discordant  SGLT          DPP                -1.88                        10.06
#
# ============= LDL ===================
# Category    Real value    Predicted value    Mean Change from Baseline    std    treatment difference
# ----------  ------------  -----------------  ---------------------------  -----  ----------------------
# Concordant  SGLT          SGLT               -0.27                        0.88   -0.20
# Discordant  DPP           SGLT               -0.06                        1.06
#
# Concordant  DPP           DPP                -0.22                        0.50   0.06
# Discordant  SGLT          DPP                -0.28                        0.86
#
# ============= HDL ===================
# Category    Real value    Predicted value    Mean Change from Baseline    std    treatment difference
# ----------  ------------  -----------------  ---------------------------  -----  ----------------------
# Concordant  SGLT          SGLT               0.03                         0.22   0.00
# Discordant  DPP           SGLT               0.02                         0.28
#
# Concordant  DPP           DPP                -0.01                        0.25   -0.00
# Discordant  SGLT          DPP                -0.01                        0.23
#
# ============= BMI ===================
# Category    Real value    Predicted value    Mean Change from Baseline    std    treatment difference
# ----------  ------------  -----------------  ---------------------------  -----  ----------------------
# Concordant  SGLT          SGLT               -2.28                        2.13   -2.38
# Discordant  DPP           SGLT               0.10                         3.31
#
# Concordant  DPP           DPP                0.14                         2.12   0.39
# Discordant  SGLT          DPP                -0.26                        2.98
# =========== Total number of samples assigned by the model VS Total number of samples in original test data
# DPP samples  61 49
# SGLT samples  40 52
#
#
# Category    Real value    Predicted value    Count    Percentage of Predicted cases
# ----------  ------------  -----------------  -------  -------------------------------
# Concordant  SGLT          SGLT               22       55.00%
# Discordant  DPP           SGLT               18       49.18%
#
# Concordant  DPP           DPP                31       50.82%
# Discordant  SGLT          DPP                30       45.00%
#
#
#
# ============= HBA1C ===================
# Category    Real value    Predicted value    Mean Change from Baseline    std    treatment difference
# ----------  ------------  -----------------  ---------------------------  -----  ----------------------
# Concordant  SGLT          SGLT               -12.82                       17.50  -5.82
# Discordant  DPP           SGLT               -7.00                        18.07
#
# Concordant  DPP           DPP                -2.42                        10.21  4.55
# Discordant  SGLT          DPP                -6.97                        12.61
#
# ============= LDL ===================
# Category    Real value    Predicted value    Mean Change from Baseline    std    treatment difference
# ----------  ------------  -----------------  ---------------------------  -----  ----------------------
# Concordant  SGLT          SGLT               -0.38                        0.91   0.03
# Discordant  DPP           SGLT               -0.41                        1.11
#
# Concordant  DPP           DPP                -0.02                        0.42   0.18
# Discordant  SGLT          DPP                -0.20                        0.83
#
# ============= HDL ===================
# Category    Real value    Predicted value    Mean Change from Baseline    std    treatment difference
# ----------  ------------  -----------------  ---------------------------  -----  ----------------------
# Concordant  SGLT          SGLT               0.05                         0.17   -0.01
# Discordant  DPP           SGLT               0.05                         0.26
#
# Concordant  DPP           DPP                -0.03                        0.26   -0.01
# Discordant  SGLT          DPP                -0.02                        0.25
#
# ============= BMI ===================
# Category    Real value    Predicted value    Mean Change from Baseline    std    treatment difference
# ----------  ------------  -----------------  ---------------------------  -----  ----------------------
# Concordant  SGLT          SGLT               -1.83                        1.96   -2.25
# Discordant  DPP           SGLT               0.42                         2.85
#
# Concordant  DPP           DPP                -0.05                        2.49   0.80
# Discordant  SGLT          DPP                -0.86                        3.20
# ---------------------------------------------------------
#
#
# Running ../../src/models/notebooks/Model 9.ipynb
# R2 score Training : 0.8119853858072292
# R2 score Testing: 0.4666
# RMSE: 5.329325
# +----------------+-----------------+
# | Model          |   Test R2 Score |
# +================+=================+
# | RegressorChain |        0.466637 |
# +----------------+-----------------+
# ====== Percentage =========
# Category    Real value    Predicted value    Mean Change from Baseline    std    treatment difference
# ----------  ------------  -----------------  ---------------------------  -----  ----------------------
# Concordant  SGLT          SGLT               -11.76                       15.67  -8.12
# Discordant  DPP           SGLT               -3.64                        11.75
#
# Concordant  DPP           DPP                -1.33                        9.01   -0.52
# Discordant  SGLT          DPP                -0.82                        7.86
#
#
# ====== Percentage =========
# Category    Real value    Predicted value    Mean Change from Baseline    std    treatment difference
# ----------  ------------  -----------------  ---------------------------  -----  ----------------------
# Concordant  SGLT          SGLT               -0.32                        0.91   -0.22
# Discordant  DPP           SGLT               -0.10                        0.66
#
# Concordant  DPP           DPP                -0.68                        1.38   -0.61
# Discordant  SGLT          DPP                -0.07                        0.59
#
#
# ====== Percentage =========
# Category    Real value    Predicted value    Mean Change from Baseline    std    treatment difference
# ----------  ------------  -----------------  ---------------------------  -----  ----------------------
# Concordant  SGLT          SGLT               0.07                         0.11   0.04
# Discordant  DPP           SGLT               0.04                         0.17
#
# Concordant  DPP           DPP                -0.01                        0.28   0.01
# Discordant  SGLT          DPP                -0.01                        0.26
#
#
# ====== Percentage =========
# Category    Real value    Predicted value    Mean Change from Baseline    std    treatment difference
# ----------  ------------  -----------------  ---------------------------  -----  ----------------------
# Concordant  SGLT          SGLT               -1.44                        2.43   -1.67
# Discordant  DPP           SGLT               0.23                         2.82
#
# Concordant  DPP           DPP                0.13                         0.71   0.44
# Discordant  SGLT          DPP                -0.31                        4.27
#
# Running ensemble_models.ipynb
#
# ======= Majority vote model results =======
# Accuracy: 0.56
# F1 score: 0.5345531174739097
# Precision: 0.5526315789473685
# Recall: 0.8076923076923077
# Confusion Matrix:
# [[15 34]
#  [10 42]]
# ======= Model based on regression model weights =======
# Optimal Threshold: 1.265009949306025
# Accuracy: 0.50
# F1 score: 0.48727715350245665
# Precision: 0.5079365079365079
# Recall: 0.6153846153846154
# Confusion Matrix:
# [[18 31]
#  [20 32]]
# =========== Total number of samples assigned by the model VS Total number of samples in original test data
# DPP samples  25 49
# SGLT samples  76 52
#
#
# Category    Real value    Predicted value    Count    Percentage of Predicted cases
# ----------  ------------  -----------------  -------  -------------------------------
# Concordant  SGLT          SGLT               42       55.26%
# Discordant  DPP           SGLT               34       40.00%
#
# Concordant  DPP           DPP                15       60.00%
# Discordant  SGLT          DPP                10       44.74%
#
#
#
# ============= HBA1C ===================
# Category    Real value    Predicted value    Mean Change from Baseline    std    treatment difference
# ----------  ------------  -----------------  ---------------------------  -----  ----------------------
# Concordant  SGLT          SGLT               -11.57                       15.52  -8.19
# Discordant  DPP           SGLT               -3.38                        11.67
#
# Concordant  DPP           DPP                -5.73                        17.66  -5.23
# Discordant  SGLT          DPP                -0.50                        8.21
#
# ============= LDL ===================
# Category    Real value    Predicted value    Mean Change from Baseline    std    treatment difference
# ----------  ------------  -----------------  ---------------------------  -----  ----------------------
# Concordant  SGLT          SGLT               -0.25                        0.91   -0.16
# Discordant  DPP           SGLT               -0.09                        0.84
#
# Concordant  DPP           DPP                -0.32                        0.56   0.05
# Discordant  SGLT          DPP                -0.37                        0.63
#
# ============= HDL ===================
# Category    Real value    Predicted value    Mean Change from Baseline    std    treatment difference
# ----------  ------------  -----------------  ---------------------------  -----  ----------------------
# Concordant  SGLT          SGLT               0.00                         0.24   0.01
# Discordant  DPP           SGLT               -0.00                        0.28
#
# Concordant  DPP           DPP                0.01                         0.23   -0.02
# Discordant  SGLT          DPP                0.03                         0.15
#
# ============= BMI ===================
# Category    Real value    Predicted value    Mean Change from Baseline    std    treatment difference
# ----------  ------------  -----------------  ---------------------------  -----  ----------------------
# Concordant  SGLT          SGLT               -1.48                        2.96   -1.59
# Discordant  DPP           SGLT               0.11                         3.18
#
# Concordant  DPP           DPP                0.47                         1.30   0.83
# Discordant  SGLT          DPP                -0.37                        1.51
# =========== Total number of samples assigned by the model VS Total number of samples in original test data
# DPP samples  38 49
# SGLT samples  63 52
#
#
# Category    Real value    Predicted value    Count    Percentage of Predicted cases
# ----------  ------------  -----------------  -------  -------------------------------
# Concordant  SGLT          SGLT               32       50.79%
# Discordant  DPP           SGLT               31       52.63%
#
# Concordant  DPP           DPP                18       47.37%
# Discordant  SGLT          DPP                20       49.21%
#
#
#
# ============= HBA1C ===================
# Category    Real value    Predicted value    Mean Change from Baseline    std    treatment difference
# ----------  ------------  -----------------  ---------------------------  -----  ----------------------
# Concordant  SGLT          SGLT               -11.59                       17.04  -8.72
# Discordant  DPP           SGLT               -2.87                        11.45
#
# Concordant  DPP           DPP                -6.22                        16.90  -0.22
# Discordant  SGLT          DPP                -6.00                        10.48
#
# ============= LDL ===================
# Category    Real value    Predicted value    Mean Change from Baseline    std    treatment difference
# ----------  ------------  -----------------  ---------------------------  -----  ----------------------
# Concordant  SGLT          SGLT               -0.20                        0.93   -0.16
# Discordant  DPP           SGLT               -0.04                        0.82
#
# Concordant  DPP           DPP                -0.37                        0.61   0.02
# Discordant  SGLT          DPP                -0.39                        0.75
#
# ============= HDL ===================
# Category    Real value    Predicted value    Mean Change from Baseline    std    treatment difference
# ----------  ------------  -----------------  ---------------------------  -----  ----------------------
# Concordant  SGLT          SGLT               0.05                         0.18   0.06
# Discordant  DPP           SGLT               -0.02                        0.28
#
# Concordant  DPP           DPP                0.03                         0.23   0.08
# Discordant  SGLT          DPP                -0.05                        0.27
#
# ============= BMI ===================
# Category    Real value    Predicted value    Mean Change from Baseline    std    treatment difference
# ----------  ------------  -----------------  ---------------------------  -----  ----------------------
# Concordant  SGLT          SGLT               -1.71                        2.64   -1.94
# Discordant  DPP           SGLT               0.23                         3.28
#
# Concordant  DPP           DPP                0.21                         1.45   0.77
# Discordant  SGLT          DPP                -0.56                        2.87
# ---------------------------------------------------------
